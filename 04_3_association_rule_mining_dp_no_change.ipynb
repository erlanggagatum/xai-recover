# %%
# from softcomputing_packages_bu import *
from apyori import apriori
import pandas as pd
import numpy as np
import copy
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Load dataset
hc_csv_raw = pd.read_csv('./datasets/2.0-discretized-v2-2-2-with-label-resampled-and-DLP-encoded.csv')
hc_csv_raw.head()
len(hc_csv_raw)
# Out:
# 41673

# %%
# Sampling (for Development)
n_sample = 30000
hc_csv = hc_csv_raw.sample(frac=1, random_state=42)
hc_csv = hc_csv.iloc[:n_sample]
hc_csv.head()
# Out:
#       global_active_power global_reactive_power    voltage global_intensity  \
# 35103              Medium             Very High  Very High           Medium
# 8049                  Low                  High  Very High              Low
# 22355                 Low                Medium     Medium              Low
# 21779              Medium             Very High     Medium           Medium
# 40302                 Low                Medium       High              Low
#
#          kitchen    laundry climate_control   other  weekend month_name  \
# 35103     Medium        Low            High    High     True      april
# 8049         Low        Low             Low  Medium    False      march
# 22355     Medium       High          Medium     Low    False  september
# 21779  Very High  Very High            High  Medium     True       june
# 40302       High       High          Medium  Medium    False      march
#
#       season_name   day_name        peak_label_pred attention_type_label  \
# 35103      spring     sunday       lower_than_usual                other
# 8049       spring    tuesday  no_significant_change                other
# 22355      autumn     friday           peak_warning                other
# 21779      summer   saturday           peak_warning      early_attention
# 40302      spring  wednesday       lower_than_usual                other
#
#       activation_type_label  peak_warning  no_significant_change  \
# 35103                 cam_2         False                  False
# 8049                  cam_2         False                   True
# 22355                 cam_2          True                  False
# 21779                 cam_1          True                  False
# 40302                 cam_2         False                  False
#
#        lower_than_usual
# 35103              True
# 8049              False
# 22355             False
# 21779             False
# 40302              True

# %%
# Preprocess dataset
for c in range(8):
    print(c)
    print("[%d] Column Preprocessing: %s" %(c, hc_csv.columns[c]))
    for r in range(hc_csv.shape[0]):
        if(hc_csv.iloc[r,c]=='Very High'):
            hc_csv.iloc[r,c] = hc_csv.columns[c]+' 75-100%'
        elif(hc_csv.iloc[r,c]=='High'):
            hc_csv.iloc[r,c] = hc_csv.columns[c]+' 50-75%'
        elif(hc_csv.iloc[r,c]=='Medium'):
            hc_csv.iloc[r,c] = hc_csv.columns[c]+' 25-50%'
        elif(hc_csv.iloc[r,c]=='Low'):
            # hc_csv.iloc[r,c] = '-1'
            hc_csv.iloc[r,c] = hc_csv.columns[c]+' 0-25%'
        else:
            hc_csv.iloc[r,c] = '-1'
print("Done.")
# Out:
# 0
# [0] Column Preprocessing: global_active_power
# 1
# [1] Column Preprocessing: global_reactive_power
# 2
# [2] Column Preprocessing: voltage
# 3
# [3] Column Preprocessing: global_intensity
# 4
# [4] Column Preprocessing: kitchen
# 5
# [5] Column Preprocessing: laundry
# 6
# [6] Column Preprocessing: climate_control
# 7
# [7] Column Preprocessing: other
# Done.

# %%
for c in hc_csv.columns:
  if c == 'weekend':
    for r in range(hc_csv.shape[0]):
      if hc_csv.iloc[r,list(hc_csv.columns).index('weekend')] == True:
        hc_csv.iloc[r,list(hc_csv.columns).index('weekend')] = 'weekend'
      else:
        hc_csv.iloc[r,list(hc_csv.columns).index('weekend')] = 'weekday'
      # break
# Out:
# C:\Users\sclab\AppData\Local\Temp\ipykernel_36340\1856367701.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'weekend' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   hc_csv.iloc[r,list(hc_csv.columns).index('weekend')] = 'weekend'

# %%
hc_csv.sample(5)
# Out:
#                global_active_power         global_reactive_power  \
# 10232   global_active_power 50-75%  global_reactive_power 50-75%
# 10741    global_active_power 0-25%   global_reactive_power 0-25%
# 11430   global_active_power 50-75%  global_reactive_power 25-50%
# 37827   global_active_power 25-50%  global_reactive_power 25-50%
# 10408  global_active_power 75-100%  global_reactive_power 50-75%
#
#                voltage          global_intensity         kitchen  \
# 10232    voltage 0-25%  global_intensity 75-100%  kitchen 25-50%
# 10741  voltage 75-100%    global_intensity 0-25%  kitchen 25-50%
# 11430   voltage 25-50%   global_intensity 50-75%   kitchen 0-25%
# 37827   voltage 25-50%   global_intensity 25-50%  kitchen 25-50%
# 10408  voltage 75-100%  global_intensity 75-100%  kitchen 50-75%
#
#               laundry          climate_control          other  weekend  \
# 10232  laundry 25-50%    climate_control 0-25%  other 75-100%  weekday
# 10741   laundry 0-25%   climate_control 25-50%    other 0-25%  weekday
# 11430   laundry 0-25%  climate_control 75-100%   other 50-75%  weekday
# 37827  laundry 25-50%   climate_control 50-75%   other 25-50%  weekday
# 10408  laundry 25-50%  climate_control 75-100%   other 50-75%  weekday
#
#       month_name season_name  day_name        peak_label_pred  \
# 10232   november      autumn    friday  no_significant_change
# 10741  september      autumn   tuesday  no_significant_change
# 11430    january      winter    monday  no_significant_change
# 37827    october      autumn  thursday       lower_than_usual
# 10408    january      winter   tuesday  no_significant_change
#
#       attention_type_label activation_type_label  peak_warning  \
# 10232      early_attention                 cam_1         False
# 10741                other                 cam_2         False
# 11430                other                 cam_1         False
# 37827       late_attention                 cam_2         False
# 10408      early_attention                 cam_1         False
#
#        no_significant_change  lower_than_usual
# 10232                   True             False
# 10741                   True             False
# 11430                   True             False
# 37827                  False              True
# 10408                   True             False

# %%
# targets_only = ['peak_label_pred', 'no_significant_change', 'lower_than_usual']

# %%
hc_csv_temp = copy.copy(hc_csv)
hc_csv_temp.drop(columns=['peak_label_pred', 'peak_warning', 'lower_than_usual', 'month_name', 'day_name'], inplace=True)

# %%
for i in range(len(hc_csv_temp)):
    if hc_csv_temp.iloc[i,-1] == True:
        hc_csv_temp.iloc[i,-1] = 'True'
    else:
        hc_csv_temp.iloc[i,-1] = 'False'
    # break
# Out:
# C:\Users\sclab\AppData\Local\Temp\ipykernel_36340\3489011138.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'False' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   hc_csv_temp.iloc[i,-1] = 'False'

# %%
# hc_csv_temp.iloc[:,12].name

for i in range(len(hc_csv_temp)):
    hc_csv_temp.iloc[i,-2] = hc_csv_temp.iloc[:,-2].name + " " + hc_csv_temp.iloc[i,-2]
    
for i in range(len(hc_csv_temp)):
    hc_csv_temp.iloc[i,-3] = hc_csv_temp.iloc[:,-3].name + " " + hc_csv_temp.iloc[i,-3]

# %%
hc_csv_temp.head(4)
# Out:
#               global_active_power          global_reactive_power  \
# 35103  global_active_power 25-50%  global_reactive_power 75-100%
# 8049    global_active_power 0-25%   global_reactive_power 50-75%
# 22355   global_active_power 0-25%   global_reactive_power 25-50%
# 21779  global_active_power 25-50%  global_reactive_power 75-100%
#
#                voltage         global_intensity          kitchen  \
# 35103  voltage 75-100%  global_intensity 25-50%   kitchen 25-50%
# 8049   voltage 75-100%   global_intensity 0-25%    kitchen 0-25%
# 22355   voltage 25-50%   global_intensity 0-25%   kitchen 25-50%
# 21779   voltage 25-50%  global_intensity 25-50%  kitchen 75-100%
#
#                laundry         climate_control         other  weekend  \
# 35103    laundry 0-25%  climate_control 50-75%  other 50-75%  weekend
# 8049     laundry 0-25%   climate_control 0-25%  other 25-50%  weekday
# 22355   laundry 50-75%  climate_control 25-50%   other 0-25%  weekday
# 21779  laundry 75-100%  climate_control 50-75%  other 25-50%  weekend
#
#       season_name                  attention_type_label  \
# 35103      spring            attention_type_label other
# 8049       spring            attention_type_label other
# 22355      autumn            attention_type_label other
# 21779      summer  attention_type_label early_attention
#
#              activation_type_label no_significant_change
# 35103  activation_type_label cam_2                 False
# 8049   activation_type_label cam_2                  True
# 22355  activation_type_label cam_2                 False
# 21779  activation_type_label cam_1                 False

# %%
# hc_csv to list
hc_list = []
for r in range(hc_csv_temp.shape[0]):
    rule_buffer = []
    for c in range(len(hc_csv_temp.iloc[r])):
        if(hc_csv_temp.iloc[r,c]!='-1'):
            rule_buffer.append(hc_csv_temp.iloc[r,c])
    hc_list.append(rule_buffer)

# %%
hc_list
# Out:
# [['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 50-75%',
#   'weekend',
#   'spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekend',
#   'summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekend',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'summer',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekday',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekend',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekend',
#   'winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'autumn',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 0-25%',
#   'weekday',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend',
#   'spring',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'spring',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekend',
#   'autumn',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekend',
#   'spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekday',
#   'winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekend',
#   'spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 0-25%',
#   'weekend',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend',
#   'summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekend',
#   'summer',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekday',
#   'summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 25-50%',
#   'other 50-75%',
#   'weekday',
#   'spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 75-100%',
#   'weekend',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'summer',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekday',
#   'summer',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekday',
#   'spring',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 0-25%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekend',
#   'spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekday',
#   'spring',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 0-25%',
#   'weekday',
#   'spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend',
#   'winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 0-25%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekday',
#   'summer',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend',
#   'spring',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 50-75%',
#   'weekend',
#   'spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 75-100%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'autumn',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend',
#   'winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekday',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekday',
#   'summer',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekday',
#   'winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekday',
#   'winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 75-100%',
#   'weekday',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'autumn',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 50-75%',
#   'weekend',
#   'winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 0-25%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'autumn',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend',
#   'spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekend',
#   'spring',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 0-25%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekday',
#   'spring',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend',
#   'autumn',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend',
#   'spring',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend',
#   'spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekday',
#   'winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 0-25%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend',
#   'summer',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekday',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekday',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 0-25%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 75-100%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 75-100%',
#   'weekday',
#   'winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 50-75%',
#   'weekday',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'autumn',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekend',
#   'spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekend',
#   'spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 75-100%',
#   'weekend',
#   'spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'autumn',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekday',
#   'summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend',
#   'spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend',
#   'spring',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
# ...
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 50-75%',
#   'weekend',
#   'spring',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekday',
#   'winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 50-75%',
#   'weekday',
#   'summer',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 75-100%',
#   'weekday',
#   'summer',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend',
#   'spring',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekday',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 75-100%',
#   'other 0-25%',
#   'weekday',
#   'autumn',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend',
#   'spring',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 0-25%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekday',
#   'spring',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend',
#   'summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'spring',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekend',
#   'summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekday',
#   'summer',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekday',
#   'summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekday',
#   'autumn',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 0-25%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekday',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend',
#   'autumn',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 50-75%',
#   'weekend',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend',
#   'spring',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekday',
#   'summer',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend',
#   'spring',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend',
#   'summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 50-75%',
#   'weekend',
#   'summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ...]

# %%
# Association Rule Mining (ARM) (Caution: extremly slow)
association_rules = list(apriori(hc_list, min_support=0.05, min_confidence=0.2))
print('Rule Mined: %d' %(len(association_rules)))
# Out:
# Rule Mined: 3418

# %%
# Rules to numpy structure
association_rules_np = []
for r in range(len(association_rules)):
    rule_buffer = []
    association_rule = association_rules[r]
    items = [x for x in association_rule[0]]
    n_items = len(items)
    support = association_rule[1]
    confidence = association_rule[2][0][2]
    lift = association_rule[2][0][3]
    rule_buffer.append(n_items), rule_buffer.append(np.array(items)), rule_buffer.append(round(support, 4)), rule_buffer.append(round(confidence, 4)), rule_buffer.append(round(lift, 4))
    print(rule_buffer)
    association_rules_np.append(rule_buffer)
# Fix later
# association_rules_np = np.array(association_rules_np)
# print(association_rules_np)
# np.save('./association_rules', association_rules_np)
# Length, Rule, Support, Confidence, Lift
# Out:
# [1, array(['False'], dtype='<U5'), 0.666, 0.666, 1.0]
# [1, array(['True'], dtype='<U4'), 0.334, 0.334, 1.0]
# [1, array(['activation_type_label cam_1'], dtype='<U27'), 0.3932, 0.3932, 1.0]
# [1, array(['activation_type_label cam_2'], dtype='<U27'), 0.6068, 0.6068, 1.0]
# [1, array(['attention_type_label early_attention'], dtype='<U36'), 0.2196, 0.2196, 1.0]
# [1, array(['attention_type_label late_attention'], dtype='<U35'), 0.2728, 0.2728, 1.0]
# [1, array(['attention_type_label other'], dtype='<U26'), 0.5076, 0.5076, 1.0]
# [1, array(['autumn'], dtype='<U6'), 0.2464, 0.2464, 1.0]
# [1, array(['climate_control 0-25%'], dtype='<U21'), 0.3145, 0.3145, 1.0]
# [1, array(['climate_control 25-50%'], dtype='<U22'), 0.2476, 0.2476, 1.0]
# [1, array(['climate_control 50-75%'], dtype='<U22'), 0.2261, 0.2261, 1.0]
# [1, array(['climate_control 75-100%'], dtype='<U23'), 0.2118, 0.2118, 1.0]
# [1, array(['global_active_power 0-25%'], dtype='<U25'), 0.3074, 0.3074, 1.0]
# [1, array(['global_active_power 25-50%'], dtype='<U26'), 0.2678, 0.2678, 1.0]
# [1, array(['global_active_power 50-75%'], dtype='<U26'), 0.2061, 0.2061, 1.0]
# [1, array(['global_active_power 75-100%'], dtype='<U27'), 0.2188, 0.2188, 1.0]
# [1, array(['global_intensity 0-25%'], dtype='<U22'), 0.3144, 0.3144, 1.0]
# [1, array(['global_intensity 25-50%'], dtype='<U23'), 0.2603, 0.2603, 1.0]
# [1, array(['global_intensity 50-75%'], dtype='<U23'), 0.2059, 0.2059, 1.0]
# [1, array(['global_intensity 75-100%'], dtype='<U24'), 0.2195, 0.2195, 1.0]
# [1, array(['global_reactive_power 0-25%'], dtype='<U27'), 0.2669, 0.2669, 1.0]
# [1, array(['global_reactive_power 25-50%'], dtype='<U28'), 0.2521, 0.2521, 1.0]
# [1, array(['global_reactive_power 50-75%'], dtype='<U28'), 0.2433, 0.2433, 1.0]
# [1, array(['global_reactive_power 75-100%'], dtype='<U29'), 0.2377, 0.2377, 1.0]
# [1, array(['kitchen 0-25%'], dtype='<U13'), 0.2811, 0.2811, 1.0]
# [1, array(['kitchen 25-50%'], dtype='<U14'), 0.2501, 0.2501, 1.0]
# [1, array(['kitchen 50-75%'], dtype='<U14'), 0.246, 0.246, 1.0]
# [1, array(['kitchen 75-100%'], dtype='<U15'), 0.2227, 0.2227, 1.0]
# [1, array(['laundry 0-25%'], dtype='<U13'), 0.2669, 0.2669, 1.0]
# [1, array(['laundry 25-50%'], dtype='<U14'), 0.251, 0.251, 1.0]
# [1, array(['laundry 50-75%'], dtype='<U14'), 0.2444, 0.2444, 1.0]
# [1, array(['laundry 75-100%'], dtype='<U15'), 0.2376, 0.2376, 1.0]
# [1, array(['other 0-25%'], dtype='<U11'), 0.2616, 0.2616, 1.0]
# [1, array(['other 25-50%'], dtype='<U12'), 0.29, 0.29, 1.0]
# [1, array(['other 50-75%'], dtype='<U12'), 0.2336, 0.2336, 1.0]
# [1, array(['other 75-100%'], dtype='<U13'), 0.2147, 0.2147, 1.0]
# [1, array(['spring'], dtype='<U6'), 0.2417, 0.2417, 1.0]
# [1, array(['summer'], dtype='<U6'), 0.2429, 0.2429, 1.0]
# [1, array(['voltage 0-25%'], dtype='<U13'), 0.2375, 0.2375, 1.0]
# [1, array(['voltage 25-50%'], dtype='<U14'), 0.2273, 0.2273, 1.0]
# [1, array(['voltage 50-75%'], dtype='<U14'), 0.2335, 0.2335, 1.0]
# [1, array(['voltage 75-100%'], dtype='<U15'), 0.3017, 0.3017, 1.0]
# [1, array(['weekday'], dtype='<U7'), 0.7117, 0.7117, 1.0]
# [1, array(['weekend'], dtype='<U7'), 0.2883, 0.2883, 1.0]
# [1, array(['winter'], dtype='<U6'), 0.2691, 0.2691, 1.0]
# [2, array(['False', 'activation_type_label cam_1'], dtype='<U27'), 0.2781, 0.2781, 1.0]
# [2, array(['activation_type_label cam_2', 'False'], dtype='<U27'), 0.3879, 0.3879, 1.0]
# [2, array(['False', 'attention_type_label early_attention'], dtype='<U36'), 0.1592, 0.239, 1.0883]
# [2, array(['False', 'attention_type_label late_attention'], dtype='<U35'), 0.1706, 0.2561, 0.9389]
# [2, array(['attention_type_label other', 'False'], dtype='<U26'), 0.3362, 0.3362, 1.0]
# [2, array(['autumn', 'False'], dtype='<U6'), 0.1592, 0.2391, 0.9703]
# [2, array(['climate_control 0-25%', 'False'], dtype='<U21'), 0.2264, 0.2264, 1.0]
# [2, array(['climate_control 25-50%', 'False'], dtype='<U22'), 0.1511, 0.2268, 0.9163]
# [2, array(['climate_control 50-75%', 'False'], dtype='<U22'), 0.1403, 0.2106, 0.9314]
# [2, array(['climate_control 75-100%', 'False'], dtype='<U23'), 0.1483, 0.2226, 1.051]
# [2, array(['False', 'global_active_power 0-25%'], dtype='<U25'), 0.2191, 0.2191, 1.0]
# [2, array(['global_active_power 25-50%', 'False'], dtype='<U26'), 0.1619, 0.2431, 0.9077]
# [2, array(['global_active_power 50-75%', 'False'], dtype='<U26'), 0.1195, 0.5801, 0.871]
# [2, array(['False', 'global_active_power 75-100%'], dtype='<U27'), 0.1655, 0.2485, 1.1358]
# [2, array(['global_intensity 0-25%', 'False'], dtype='<U22'), 0.226, 0.226, 1.0]
# [2, array(['global_intensity 25-50%', 'False'], dtype='<U23'), 0.1544, 0.2318, 0.8906]
# [2, array(['global_intensity 50-75%', 'False'], dtype='<U23'), 0.1189, 0.5774, 0.867]
# [2, array(['global_intensity 75-100%', 'False'], dtype='<U24'), 0.1668, 0.2504, 1.1408]
# [2, array(['False', 'global_reactive_power 0-25%'], dtype='<U27'), 0.1785, 0.268, 1.0042]
# [2, array(['global_reactive_power 25-50%', 'False'], dtype='<U28'), 0.1651, 0.248, 0.9837]
# [2, array(['global_reactive_power 50-75%', 'False'], dtype='<U28'), 0.161, 0.2418, 0.9937]
# [2, array(['False', 'global_reactive_power 75-100%'], dtype='<U29'), 0.1613, 0.2422, 1.0189]
# [2, array(['kitchen 0-25%', 'False'], dtype='<U13'), 0.201, 0.201, 1.0]
# [2, array(['kitchen 25-50%', 'False'], dtype='<U14'), 0.1657, 0.2488, 0.9945]
# [2, array(['kitchen 50-75%', 'False'], dtype='<U14'), 0.1564, 0.2348, 0.9543]
# [2, array(['kitchen 75-100%', 'False'], dtype='<U15'), 0.1429, 0.2146, 0.9637]
# [2, array(['laundry 0-25%', 'False'], dtype='<U13'), 0.1895, 0.2846, 1.0662]
# [2, array(['laundry 25-50%', 'False'], dtype='<U14'), 0.1614, 0.2424, 0.9658]
# [2, array(['laundry 50-75%', 'False'], dtype='<U14'), 0.1555, 0.2335, 0.9553]
# [2, array(['laundry 75-100%', 'False'], dtype='<U15'), 0.1595, 0.2395, 1.0079]
# [2, array(['False', 'other 0-25%'], dtype='<U11'), 0.1777, 0.2668, 1.0199]
# [2, array(['other 25-50%', 'False'], dtype='<U12'), 0.1949, 0.2927, 1.0092]
# [2, array(['other 50-75%', 'False'], dtype='<U12'), 0.1433, 0.2151, 0.9209]
# [2, array(['False', 'other 75-100%'], dtype='<U13'), 0.1501, 0.2253, 1.0494]
# [2, array(['spring', 'False'], dtype='<U6'), 0.1505, 0.226, 0.9351]
# [2, array(['summer', 'False'], dtype='<U6'), 0.1701, 0.2554, 1.0515]
# [2, array(['voltage 0-25%', 'False'], dtype='<U13'), 0.1772, 0.266, 1.1201]
# [2, array(['voltage 25-50%', 'False'], dtype='<U14'), 0.1468, 0.2205, 0.9701]
# [2, array(['False', 'voltage 50-75%'], dtype='<U14'), 0.1392, 0.209, 0.8952]
# [2, array(['voltage 75-100%', 'False'], dtype='<U15'), 0.2028, 0.2028, 1.0]
# [2, array(['False', 'weekday'], dtype='<U7'), 0.467, 0.467, 1.0]
# [2, array(['weekend', 'False'], dtype='<U7'), 0.199, 0.2988, 1.0363]
# [2, array(['winter', 'False'], dtype='<U6'), 0.1862, 0.2795, 1.0389]
# [2, array(['activation_type_label cam_1', 'True'], dtype='<U27'), 0.1151, 0.3446, 0.8764]
# [2, array(['activation_type_label cam_2', 'True'], dtype='<U27'), 0.2189, 0.2189, 1.0]
# [2, array(['attention_type_label early_attention', 'True'], dtype='<U36'), 0.0604, 0.2752, 0.8239]
# [2, array(['attention_type_label late_attention', 'True'], dtype='<U35'), 0.1022, 0.3061, 1.1219]
# [2, array(['attention_type_label other', 'True'], dtype='<U26'), 0.1714, 0.513, 1.0107]
# [2, array(['autumn', 'True'], dtype='<U6'), 0.0872, 0.261, 1.0592]
# [2, array(['climate_control 0-25%', 'True'], dtype='<U21'), 0.0881, 0.2637, 0.8387]
# [2, array(['climate_control 25-50%', 'True'], dtype='<U22'), 0.0965, 0.2889, 1.1669]
# [2, array(['climate_control 50-75%', 'True'], dtype='<U22'), 0.0859, 0.2571, 1.1368]
# [2, array(['climate_control 75-100%', 'True'], dtype='<U23'), 0.0636, 0.3001, 0.8983]
# [2, array(['global_active_power 0-25%', 'True'], dtype='<U25'), 0.0883, 0.2643, 0.86]
# [2, array(['global_active_power 25-50%', 'True'], dtype='<U26'), 0.1059, 0.317, 1.184]
# [2, array(['global_active_power 50-75%', 'True'], dtype='<U26'), 0.0865, 0.2591, 1.2571]
# [2, array(['global_active_power 75-100%', 'True'], dtype='<U27'), 0.0533, 0.2436, 0.7293]
# [2, array(['global_intensity 0-25%', 'True'], dtype='<U22'), 0.0884, 0.2646, 0.8418]
# [2, array(['global_intensity 25-50%', 'True'], dtype='<U23'), 0.1059, 0.317, 1.2181]
# [2, array(['global_intensity 50-75%', 'True'], dtype='<U23'), 0.087, 0.2605, 1.2652]
# [2, array(['global_intensity 75-100%', 'True'], dtype='<U24'), 0.0527, 0.2402, 0.7192]
# [2, array(['global_reactive_power 0-25%', 'True'], dtype='<U27'), 0.0884, 0.2646, 0.9915]
# [2, array(['global_reactive_power 25-50%', 'True'], dtype='<U28'), 0.0869, 0.2603, 1.0325]
# [2, array(['global_reactive_power 50-75%', 'True'], dtype='<U28'), 0.0823, 0.2464, 1.0125]
# [2, array(['global_reactive_power 75-100%', 'True'], dtype='<U29'), 0.0764, 0.2287, 0.9622]
# [2, array(['kitchen 0-25%', 'True'], dtype='<U13'), 0.0801, 0.2399, 0.8533]
# [2, array(['kitchen 25-50%', 'True'], dtype='<U14'), 0.0845, 0.2529, 1.0109]
# [2, array(['kitchen 50-75%', 'True'], dtype='<U14'), 0.0897, 0.2684, 1.0911]
# [2, array(['kitchen 75-100%', 'True'], dtype='<U15'), 0.0798, 0.2388, 1.0723]
# [2, array(['laundry 0-25%', 'True'], dtype='<U13'), 0.0774, 0.2317, 0.8681]
# [2, array(['laundry 25-50%', 'True'], dtype='<U14'), 0.0896, 0.2681, 1.0683]
# [2, array(['laundry 50-75%', 'True'], dtype='<U14'), 0.0889, 0.2662, 1.0892]
# [2, array(['laundry 75-100%', 'True'], dtype='<U15'), 0.0781, 0.2339, 0.9843]
# [2, array(['other 0-25%', 'True'], dtype='<U11'), 0.0839, 0.2513, 0.9604]
# [2, array(['other 25-50%', 'True'], dtype='<U12'), 0.0951, 0.2847, 0.9816]
# [2, array(['other 50-75%', 'True'], dtype='<U12'), 0.0903, 0.2704, 1.1577]
# [2, array(['other 75-100%', 'True'], dtype='<U13'), 0.0647, 0.3011, 0.9016]
# [2, array(['spring', 'True'], dtype='<U6'), 0.0912, 0.2729, 1.1294]
# [2, array(['summer', 'True'], dtype='<U6'), 0.0728, 0.2179, 0.8973]
# [2, array(['voltage 0-25%', 'True'], dtype='<U13'), 0.0603, 0.254, 0.7605]
# [2, array(['voltage 25-50%', 'True'], dtype='<U14'), 0.0804, 0.2408, 1.0595]
# [2, array(['voltage 50-75%', 'True'], dtype='<U14'), 0.0943, 0.2823, 1.209]
# [2, array(['voltage 75-100%', 'True'], dtype='<U15'), 0.099, 0.2963, 0.9819]
# [2, array(['weekday', 'True'], dtype='<U7'), 0.2447, 0.2447, 1.0]
# [2, array(['weekend', 'True'], dtype='<U7'), 0.0893, 0.2674, 0.9275]
# [2, array(['winter', 'True'], dtype='<U6'), 0.0829, 0.2482, 0.9224]
# [2, array(['attention_type_label early_attention',
#        'activation_type_label cam_1'], dtype='<U36'), 0.1466, 0.3729, 1.698]
# [2, array(['attention_type_label late_attention',
#        'activation_type_label cam_1'], dtype='<U35'), 0.0896, 0.2278, 0.8351]
# [2, array(['attention_type_label other', 'activation_type_label cam_1'],
#       dtype='<U27'), 0.157, 0.3993, 0.7867]
# [2, array(['autumn', 'activation_type_label cam_1'], dtype='<U27'), 0.1067, 0.2713, 1.1012]
# [2, array(['climate_control 50-75%', 'activation_type_label cam_1'],
#       dtype='<U27'), 0.1021, 0.2598, 1.1488]
# [2, array(['climate_control 75-100%', 'activation_type_label cam_1'],
#       dtype='<U27'), 0.2039, 0.2039, 1.0]
# [2, array(['global_active_power 50-75%', 'activation_type_label cam_1'],
#       dtype='<U27'), 0.1567, 0.3986, 1.9341]
# [2, array(['global_active_power 75-100%', 'activation_type_label cam_1'],
#       dtype='<U27'), 0.2121, 0.2121, 1.0]
# [2, array(['global_intensity 50-75%', 'activation_type_label cam_1'],
#       dtype='<U27'), 0.1566, 0.3982, 1.9344]
# [2, array(['global_intensity 75-100%', 'activation_type_label cam_1'],
#       dtype='<U27'), 0.2123, 0.2123, 1.0]
# [2, array(['global_reactive_power 0-25%', 'activation_type_label cam_1'],
#       dtype='<U27'), 0.086, 0.2187, 0.8195]
# [2, array(['global_reactive_power 25-50%', 'activation_type_label cam_1'],
#       dtype='<U28'), 0.0951, 0.2419, 0.9596]
# [2, array(['global_reactive_power 50-75%', 'activation_type_label cam_1'],
#       dtype='<U28'), 0.0905, 0.2303, 0.9463]
# [2, array(['global_reactive_power 75-100%', 'activation_type_label cam_1'],
#       dtype='<U29'), 0.1215, 0.3091, 1.3004]
# [2, array(['kitchen 0-25%', 'activation_type_label cam_1'], dtype='<U27'), 0.0874, 0.2223, 0.7907]
# [2, array(['kitchen 25-50%', 'activation_type_label cam_1'], dtype='<U27'), 0.0838, 0.2132, 0.8524]
# [2, array(['kitchen 50-75%', 'activation_type_label cam_1'], dtype='<U27'), 0.0887, 0.2256, 0.917]
# [2, array(['kitchen 75-100%', 'activation_type_label cam_1'], dtype='<U27'), 0.1332, 0.3389, 1.5217]
# [2, array(['laundry 0-25%', 'activation_type_label cam_1'], dtype='<U27'), 0.0864, 0.2198, 0.8233]
# [2, array(['laundry 25-50%', 'activation_type_label cam_1'], dtype='<U27'), 0.0991, 0.252, 1.0039]
# [2, array(['laundry 50-75%', 'activation_type_label cam_1'], dtype='<U27'), 0.0925, 0.2353, 0.9625]
# [2, array(['laundry 75-100%', 'activation_type_label cam_1'], dtype='<U27'), 0.1152, 0.293, 1.233]
# [2, array(['other 25-50%', 'activation_type_label cam_1'], dtype='<U27'), 0.0594, 0.2047, 0.5206]
# [2, array(['other 50-75%', 'activation_type_label cam_1'], dtype='<U27'), 0.1049, 0.2667, 1.1418]
# [2, array(['other 75-100%', 'activation_type_label cam_1'], dtype='<U27'), 0.1907, 0.485, 2.2584]
# [2, array(['spring', 'activation_type_label cam_1'], dtype='<U27'), 0.1042, 0.265, 1.0967]
# [2, array(['summer', 'activation_type_label cam_1'], dtype='<U27'), 0.0775, 0.3189, 0.8112]
# [2, array(['voltage 0-25%', 'activation_type_label cam_1'], dtype='<U27'), 0.1594, 0.4053, 1.7067]
# [2, array(['voltage 25-50%', 'activation_type_label cam_1'], dtype='<U27'), 0.112, 0.2849, 1.2534]
# [2, array(['voltage 50-75%', 'activation_type_label cam_1'], dtype='<U27'), 0.0732, 0.3133, 0.797]
# [2, array(['weekday', 'activation_type_label cam_1'], dtype='<U27'), 0.2733, 0.2733, 1.0]
# [2, array(['weekend', 'activation_type_label cam_1'], dtype='<U27'), 0.1198, 0.3048, 1.0571]
# [2, array(['winter', 'activation_type_label cam_1'], dtype='<U27'), 0.1048, 0.2666, 0.991]
# [2, array(['activation_type_label cam_2',
#        'attention_type_label early_attention'], dtype='<U36'), 0.073, 0.3324, 0.5478]
# [2, array(['activation_type_label cam_2',
#        'attention_type_label late_attention'], dtype='<U35'), 0.1832, 0.302, 1.1069]
# [2, array(['activation_type_label cam_2', 'attention_type_label other'],
#       dtype='<U27'), 0.3506, 0.3506, 1.0]
# [2, array(['activation_type_label cam_2', 'autumn'], dtype='<U27'), 0.1397, 0.2302, 0.9344]
# [2, array(['activation_type_label cam_2', 'climate_control 0-25%'],
#       dtype='<U27'), 0.2688, 0.2688, 1.0]
# [2, array(['activation_type_label cam_2', 'climate_control 25-50%'],
#       dtype='<U27'), 0.2061, 0.2061, 1.0]
# [2, array(['activation_type_label cam_2', 'climate_control 50-75%'],
#       dtype='<U27'), 0.124, 0.2043, 0.9036]
# [2, array(['activation_type_label cam_2', 'global_active_power 0-25%'],
#       dtype='<U27'), 0.3028, 0.3028, 1.0]
# [2, array(['activation_type_label cam_2', 'global_active_power 25-50%'],
#       dtype='<U27'), 0.248, 0.248, 1.0]
# [2, array(['activation_type_label cam_2', 'global_intensity 0-25%'],
#       dtype='<U27'), 0.3099, 0.3099, 1.0]
# [2, array(['activation_type_label cam_2', 'global_intensity 25-50%'],
#       dtype='<U27'), 0.2404, 0.2404, 1.0]
# [2, array(['activation_type_label cam_2', 'global_reactive_power 0-25%'],
#       dtype='<U27'), 0.1809, 0.2981, 1.1169]
# [2, array(['activation_type_label cam_2', 'global_reactive_power 25-50%'],
#       dtype='<U28'), 0.157, 0.2587, 1.0262]
# [2, array(['activation_type_label cam_2', 'global_reactive_power 50-75%'],
#       dtype='<U28'), 0.1528, 0.2518, 1.0348]
# [2, array(['activation_type_label cam_2', 'global_reactive_power 75-100%'],
#       dtype='<U29'), 0.1162, 0.4887, 0.8053]
# [2, array(['activation_type_label cam_2', 'kitchen 0-25%'], dtype='<U27'), 0.1937, 0.3193, 1.1356]
# [2, array(['activation_type_label cam_2', 'kitchen 25-50%'], dtype='<U27'), 0.1663, 0.274, 1.0956]
# [2, array(['activation_type_label cam_2', 'kitchen 50-75%'], dtype='<U27'), 0.1573, 0.2593, 1.0538]
# [2, array(['activation_type_label cam_2', 'kitchen 75-100%'], dtype='<U27'), 0.0895, 0.4017, 0.662]
# [2, array(['activation_type_label cam_2', 'laundry 0-25%'], dtype='<U27'), 0.1805, 0.2975, 1.1145]
# [2, array(['activation_type_label cam_2', 'laundry 25-50%'], dtype='<U27'), 0.1519, 0.2504, 0.9975]
# [2, array(['activation_type_label cam_2', 'laundry 50-75%'], dtype='<U27'), 0.1519, 0.2504, 1.0243]
# [2, array(['activation_type_label cam_2', 'laundry 75-100%'], dtype='<U27'), 0.1224, 0.2018, 0.849]
# [2, array(['activation_type_label cam_2', 'other 0-25%'], dtype='<U27'), 0.2234, 0.2234, 1.0]
# [2, array(['activation_type_label cam_2', 'other 25-50%'], dtype='<U27'), 0.2307, 0.2307, 1.0]
# [2, array(['activation_type_label cam_2', 'other 50-75%'], dtype='<U27'), 0.1287, 0.2121, 0.9081]
# [2, array(['activation_type_label cam_2', 'spring'], dtype='<U27'), 0.1375, 0.2265, 0.9374]
# [2, array(['activation_type_label cam_2', 'summer'], dtype='<U27'), 0.1654, 0.2726, 1.1223]
# [2, array(['activation_type_label cam_2', 'voltage 0-25%'], dtype='<U27'), 0.0781, 0.329, 0.5421]
# [2, array(['activation_type_label cam_2', 'voltage 25-50%'], dtype='<U27'), 0.1153, 0.5072, 0.8358]
# [2, array(['activation_type_label cam_2', 'voltage 50-75%'], dtype='<U27'), 0.1603, 0.2642, 1.1315]
# [2, array(['activation_type_label cam_2', 'voltage 75-100%'], dtype='<U27'), 0.2531, 0.2531, 1.0]
# [2, array(['activation_type_label cam_2', 'weekday'], dtype='<U27'), 0.4383, 0.4383, 1.0]
# [2, array(['activation_type_label cam_2', 'weekend'], dtype='<U27'), 0.1685, 0.2777, 0.963]
# [2, array(['activation_type_label cam_2', 'winter'], dtype='<U27'), 0.1642, 0.2706, 1.0058]
# [2, array(['autumn', 'attention_type_label early_attention'], dtype='<U36'), 0.0522, 0.2379, 0.9655]
# [2, array(['climate_control 50-75%', 'attention_type_label early_attention'],
#       dtype='<U36'), 0.0532, 0.2424, 1.072]
# [2, array(['climate_control 75-100%', 'attention_type_label early_attention'],
#       dtype='<U36'), 0.0876, 0.3988, 1.8824]
# [2, array(['global_active_power 50-75%',
#        'attention_type_label early_attention'], dtype='<U36'), 0.0655, 0.2983, 1.4474]
# [2, array(['global_active_power 75-100%',
#        'attention_type_label early_attention'], dtype='<U36'), 0.0821, 0.3737, 1.708]
# [2, array(['global_intensity 50-75%', 'attention_type_label early_attention'],
#       dtype='<U36'), 0.0653, 0.2974, 1.4444]
# [2, array(['global_intensity 75-100%', 'attention_type_label early_attention'],
#       dtype='<U36'), 0.0821, 0.374, 1.7039]
# [2, array(['global_reactive_power 0-25%',
#        'attention_type_label early_attention'], dtype='<U36'), 0.0527, 0.2398, 0.8986]
# [2, array(['global_reactive_power 25-50%',
#        'attention_type_label early_attention'], dtype='<U36'), 0.0538, 0.2448, 0.9713]
# [2, array(['global_reactive_power 50-75%',
#        'attention_type_label early_attention'], dtype='<U36'), 0.0512, 0.2333, 0.9588]
# [2, array(['global_reactive_power 75-100%',
#        'attention_type_label early_attention'], dtype='<U36'), 0.0619, 0.282, 1.1865]
# [2, array(['kitchen 0-25%', 'attention_type_label early_attention'],
#       dtype='<U36'), 0.0501, 0.228, 0.811]
# [2, array(['kitchen 25-50%', 'attention_type_label early_attention'],
#       dtype='<U36'), 0.0522, 0.2379, 0.9509]
# [2, array(['kitchen 50-75%', 'attention_type_label early_attention'],
#       dtype='<U36'), 0.0545, 0.248, 1.0081]
# [2, array(['kitchen 75-100%', 'attention_type_label early_attention'],
#       dtype='<U36'), 0.0628, 0.2861, 1.2848]
# [2, array(['laundry 25-50%', 'attention_type_label early_attention'],
#       dtype='<U36'), 0.0574, 0.2615, 1.042]
# [2, array(['laundry 50-75%', 'attention_type_label early_attention'],
#       dtype='<U36'), 0.0516, 0.2351, 0.9619]
# [2, array(['laundry 75-100%', 'attention_type_label early_attention'],
#       dtype='<U36'), 0.0609, 0.2775, 1.1677]
# [2, array(['other 25-50%', 'attention_type_label early_attention'],
#       dtype='<U36'), 0.054, 0.2457, 0.8473]
# [2, array(['other 50-75%', 'attention_type_label early_attention'],
#       dtype='<U36'), 0.0563, 0.2562, 1.0968]
# [2, array(['other 75-100%', 'attention_type_label early_attention'],
#       dtype='<U36'), 0.065, 0.2961, 1.3791]
# [2, array(['spring', 'attention_type_label early_attention'], dtype='<U36'), 0.0652, 0.2968, 1.2279]
# [2, array(['voltage 0-25%', 'attention_type_label early_attention'],
#       dtype='<U36'), 0.0726, 0.3304, 1.3914]
# [2, array(['voltage 25-50%', 'attention_type_label early_attention'],
#       dtype='<U36'), 0.0524, 0.2385, 1.0493]
# [2, array(['weekday', 'attention_type_label early_attention'], dtype='<U36'), 0.1434, 0.6529, 0.9174]
# [2, array(['weekend', 'attention_type_label early_attention'], dtype='<U36'), 0.0762, 0.3471, 1.204]
# [2, array(['winter', 'attention_type_label early_attention'], dtype='<U36'), 0.0537, 0.2444, 0.9083]
# [2, array(['autumn', 'attention_type_label late_attention'], dtype='<U35'), 0.0671, 0.2458, 0.9979]
# [2, array(['climate_control 0-25%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0889, 0.326, 1.0367]
# [2, array(['climate_control 25-50%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0728, 0.2667, 1.0774]
# [2, array(['climate_control 50-75%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0607, 0.2225, 0.984]
# [2, array(['climate_control 75-100%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0504, 0.2379, 0.8722]
# [2, array(['global_active_power 0-25%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0906, 0.3322, 1.0809]
# [2, array(['global_active_power 25-50%',
#        'attention_type_label late_attention'], dtype='<U35'), 0.0817, 0.2996, 1.1189]
# [2, array(['global_active_power 75-100%',
#        'attention_type_label late_attention'], dtype='<U35'), 0.0537, 0.2454, 0.8997]
# [2, array(['global_intensity 0-25%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0918, 0.3365, 1.0704]
# [2, array(['global_intensity 25-50%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.08, 0.2933, 1.1267]
# [2, array(['global_intensity 75-100%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0538, 0.245, 0.8979]
# [2, array(['global_reactive_power 0-25%',
#        'attention_type_label late_attention'], dtype='<U35'), 0.0738, 0.2704, 1.0131]
# [2, array(['global_reactive_power 25-50%',
#        'attention_type_label late_attention'], dtype='<U35'), 0.0692, 0.2535, 1.0059]
# [2, array(['global_reactive_power 50-75%',
#        'attention_type_label late_attention'], dtype='<U35'), 0.0686, 0.2516, 1.0339]
# [2, array(['global_reactive_power 75-100%',
#        'attention_type_label late_attention'], dtype='<U35'), 0.0612, 0.2245, 0.9443]
# [2, array(['kitchen 0-25%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0815, 0.2988, 1.0627]
# [2, array(['kitchen 25-50%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0663, 0.243, 0.9716]
# [2, array(['kitchen 50-75%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0672, 0.2463, 1.0012]
# [2, array(['kitchen 75-100%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0578, 0.2119, 0.9514]
# [2, array(['laundry 0-25%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0726, 0.2661, 0.997]
# [2, array(['laundry 25-50%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0669, 0.2452, 0.977]
# [2, array(['laundry 50-75%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0704, 0.2579, 1.0553]
# [2, array(['laundry 75-100%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0629, 0.2307, 0.9708]
# [2, array(['other 0-25%', 'attention_type_label late_attention'], dtype='<U35'), 0.0749, 0.2746, 1.0494]
# [2, array(['other 25-50%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0808, 0.2961, 1.0208]
# [2, array(['other 50-75%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0622, 0.228, 0.9761]
# [2, array(['other 75-100%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0549, 0.2014, 0.9378]
# [2, array(['spring', 'attention_type_label late_attention'], dtype='<U35'), 0.0617, 0.2262, 0.9359]
# [2, array(['summer', 'attention_type_label late_attention'], dtype='<U35'), 0.0681, 0.2495, 1.0272]
# [2, array(['voltage 0-25%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0596, 0.2185, 0.9199]
# [2, array(['voltage 25-50%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0664, 0.2433, 1.0705]
# [2, array(['voltage 50-75%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0665, 0.2438, 1.044]
# [2, array(['voltage 75-100%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0803, 0.2945, 0.976]
# [2, array(['weekday', 'attention_type_label late_attention'], dtype='<U35'), 0.1948, 0.714, 1.0032]
# [2, array(['weekend', 'attention_type_label late_attention'], dtype='<U35'), 0.078, 0.286, 0.9921]
# [2, array(['winter', 'attention_type_label late_attention'], dtype='<U35'), 0.076, 0.2785, 1.0349]
# [2, array(['autumn', 'attention_type_label other'], dtype='<U26'), 0.1271, 0.2503, 1.0161]
# [2, array(['climate_control 0-25%', 'attention_type_label other'],
#       dtype='<U26'), 0.1858, 0.3661, 1.1642]
# [2, array(['climate_control 25-50%', 'attention_type_label other'],
#       dtype='<U26'), 0.1357, 0.2673, 1.0799]
# [2, array(['climate_control 50-75%', 'attention_type_label other'],
#       dtype='<U26'), 0.1122, 0.221, 0.9775]
# [2, array(['climate_control 75-100%', 'attention_type_label other'],
#       dtype='<U26'), 0.0739, 0.3487, 0.687]
# [2, array(['attention_type_label other', 'global_active_power 0-25%'],
#       dtype='<U26'), 0.179, 0.3527, 1.1475]
# [2, array(['global_active_power 25-50%', 'attention_type_label other'],
#       dtype='<U26'), 0.1517, 0.2989, 1.1161]
# [2, array(['global_active_power 50-75%', 'attention_type_label other'],
#       dtype='<U26'), 0.0938, 0.4554, 0.8971]
# [2, array(['attention_type_label other', 'global_active_power 75-100%'],
#       dtype='<U27'), 0.083, 0.3795, 0.7476]
# [2, array(['global_intensity 0-25%', 'attention_type_label other'],
#       dtype='<U26'), 0.184, 0.3626, 1.1533]
# [2, array(['global_intensity 25-50%', 'attention_type_label other'],
#       dtype='<U26'), 0.1466, 0.2889, 1.1099]
# [2, array(['global_intensity 50-75%', 'attention_type_label other'],
#       dtype='<U26'), 0.0933, 0.4534, 0.8932]
# [2, array(['global_intensity 75-100%', 'attention_type_label other'],
#       dtype='<U26'), 0.0836, 0.3809, 0.7503]
# [2, array(['attention_type_label other', 'global_reactive_power 0-25%'],
#       dtype='<U27'), 0.1405, 0.2767, 1.0368]
# [2, array(['global_reactive_power 25-50%', 'attention_type_label other'],
#       dtype='<U28'), 0.1291, 0.2544, 1.0093]
# [2, array(['global_reactive_power 50-75%', 'attention_type_label other'],
#       dtype='<U28'), 0.1235, 0.2432, 0.9996]
# [2, array(['attention_type_label other', 'global_reactive_power 75-100%'],
#       dtype='<U29'), 0.1145, 0.2256, 0.9493]
# [2, array(['kitchen 0-25%', 'attention_type_label other'], dtype='<U26'), 0.1496, 0.2947, 1.0481]
# [2, array(['kitchen 25-50%', 'attention_type_label other'], dtype='<U26'), 0.1316, 0.2593, 1.0365]
# [2, array(['kitchen 50-75%', 'attention_type_label other'], dtype='<U26'), 0.1244, 0.245, 0.9958]
# [2, array(['kitchen 75-100%', 'attention_type_label other'], dtype='<U26'), 0.1021, 0.2011, 0.9029]
# [2, array(['laundry 0-25%', 'attention_type_label other'], dtype='<U26'), 0.1447, 0.2851, 1.0682]
# [2, array(['laundry 25-50%', 'attention_type_label other'], dtype='<U26'), 0.1267, 0.2495, 0.9942]
# [2, array(['laundry 50-75%', 'attention_type_label other'], dtype='<U26'), 0.1224, 0.2412, 0.9868]
# [2, array(['laundry 75-100%', 'attention_type_label other'], dtype='<U26'), 0.1138, 0.2241, 0.9432]
# [2, array(['attention_type_label other', 'other 0-25%'], dtype='<U26'), 0.1424, 0.2805, 1.0722]
# [2, array(['other 25-50%', 'attention_type_label other'], dtype='<U26'), 0.1553, 0.3059, 1.0549]
# [2, array(['other 50-75%', 'attention_type_label other'], dtype='<U26'), 0.1151, 0.2268, 0.971]
# [2, array(['attention_type_label other', 'other 75-100%'], dtype='<U26'), 0.0948, 0.4413, 0.8694]
# [2, array(['spring', 'attention_type_label other'], dtype='<U26'), 0.1148, 0.2262, 0.9358]
# [2, array(['summer', 'attention_type_label other'], dtype='<U26'), 0.1263, 0.2488, 1.0244]
# [2, array(['voltage 0-25%', 'attention_type_label other'], dtype='<U26'), 0.1053, 0.2075, 0.8737]
# [2, array(['voltage 25-50%', 'attention_type_label other'], dtype='<U26'), 0.1085, 0.2138, 0.9408]
# [2, array(['attention_type_label other', 'voltage 50-75%'], dtype='<U26'), 0.1221, 0.2405, 1.0302]
# [2, array(['voltage 75-100%', 'attention_type_label other'], dtype='<U26'), 0.1716, 0.3381, 1.1206]
# [2, array(['attention_type_label other', 'weekday'], dtype='<U26'), 0.3735, 0.3735, 1.0]
# [2, array(['weekend', 'attention_type_label other'], dtype='<U26'), 0.1341, 0.2641, 0.916]
# [2, array(['winter', 'attention_type_label other'], dtype='<U26'), 0.1394, 0.2747, 1.0209]
# [2, array(['climate_control 0-25%', 'autumn'], dtype='<U21'), 0.0636, 0.2583, 0.8213]
# [2, array(['autumn', 'climate_control 25-50%'], dtype='<U22'), 0.063, 0.2557, 1.0329]
# [2, array(['autumn', 'climate_control 50-75%'], dtype='<U22'), 0.061, 0.2475, 1.0943]
# [2, array(['autumn', 'climate_control 75-100%'], dtype='<U23'), 0.0588, 0.2385, 1.126]
# [2, array(['autumn', 'global_active_power 0-25%'], dtype='<U25'), 0.0669, 0.2714, 0.883]
# [2, array(['global_active_power 25-50%', 'autumn'], dtype='<U26'), 0.0637, 0.2584, 0.9651]
# [2, array(['autumn', 'global_active_power 50-75%'], dtype='<U26'), 0.0538, 0.2184, 1.0597]
# [2, array(['autumn', 'global_active_power 75-100%'], dtype='<U27'), 0.062, 0.2518, 1.1508]
# [2, array(['autumn', 'global_intensity 0-25%'], dtype='<U22'), 0.0698, 0.2832, 0.9008]
# [2, array(['global_intensity 25-50%', 'autumn'], dtype='<U23'), 0.0611, 0.2481, 0.9534]
# [2, array(['autumn', 'global_intensity 50-75%'], dtype='<U23'), 0.0536, 0.2177, 1.0575]
# [2, array(['autumn', 'global_intensity 75-100%'], dtype='<U24'), 0.0618, 0.251, 1.1434]
# [2, array(['autumn', 'global_reactive_power 0-25%'], dtype='<U27'), 0.0639, 0.2594, 0.9718]
# [2, array(['autumn', 'global_reactive_power 25-50%'], dtype='<U28'), 0.0695, 0.282, 1.1186]
# [2, array(['autumn', 'global_reactive_power 50-75%'], dtype='<U28'), 0.0592, 0.2404, 0.9881]
# [2, array(['autumn', 'global_reactive_power 75-100%'], dtype='<U29'), 0.0538, 0.2182, 0.9181]
# [2, array(['autumn', 'kitchen 0-25%'], dtype='<U13'), 0.0635, 0.2577, 0.9168]
# [2, array(['kitchen 25-50%', 'autumn'], dtype='<U14'), 0.0533, 0.2162, 0.8644]
# [2, array(['autumn', 'kitchen 50-75%'], dtype='<U14'), 0.0537, 0.2181, 0.8865]
# [2, array(['kitchen 75-100%', 'autumn'], dtype='<U15'), 0.0759, 0.3079, 1.3828]
# [2, array(['laundry 25-50%', 'autumn'], dtype='<U14'), 0.0603, 0.2449, 0.9757]
# [2, array(['laundry 50-75%', 'autumn'], dtype='<U14'), 0.0803, 0.3259, 1.3334]
# [2, array(['laundry 75-100%', 'autumn'], dtype='<U15'), 0.0615, 0.2495, 1.0499]
# [2, array(['autumn', 'other 0-25%'], dtype='<U11'), 0.0596, 0.2419, 0.9246]
# [2, array(['autumn', 'other 25-50%'], dtype='<U12'), 0.071, 0.2882, 0.9936]
# [2, array(['other 50-75%', 'autumn'], dtype='<U12'), 0.0529, 0.2147, 0.9192]
# [2, array(['autumn', 'other 75-100%'], dtype='<U13'), 0.0629, 0.2552, 1.1883]
# [2, array(['voltage 0-25%', 'autumn'], dtype='<U13'), 0.0604, 0.2453, 1.0328]
# [2, array(['voltage 25-50%', 'autumn'], dtype='<U14'), 0.0634, 0.2573, 1.1323]
# [2, array(['autumn', 'voltage 50-75%'], dtype='<U14'), 0.0627, 0.2545, 1.0899]
# [2, array(['voltage 75-100%', 'autumn'], dtype='<U15'), 0.0598, 0.2429, 0.8049]
# [2, array(['autumn', 'weekday'], dtype='<U7'), 0.1733, 0.7036, 0.9886]
# [2, array(['weekend', 'autumn'], dtype='<U7'), 0.073, 0.2964, 1.0281]
# [2, array(['climate_control 0-25%', 'global_active_power 0-25%'], dtype='<U25'), 0.1662, 0.5286, 1.7198]
# [2, array(['global_active_power 25-50%', 'climate_control 0-25%'],
#       dtype='<U26'), 0.0965, 0.3069, 1.146]
# [2, array(['climate_control 0-25%', 'global_intensity 0-25%'], dtype='<U22'), 0.1683, 0.5353, 1.7028]
# [2, array(['global_intensity 25-50%', 'climate_control 0-25%'], dtype='<U23'), 0.0942, 0.2997, 1.1514]
# [2, array(['climate_control 0-25%', 'global_reactive_power 0-25%'],
#       dtype='<U27'), 0.1075, 0.342, 1.2812]
# [2, array(['climate_control 0-25%', 'global_reactive_power 25-50%'],
#       dtype='<U28'), 0.0836, 0.2657, 1.0542]
# [2, array(['climate_control 0-25%', 'global_reactive_power 50-75%'],
#       dtype='<U28'), 0.0718, 0.2284, 0.9387]
# [2, array(['climate_control 0-25%', 'global_reactive_power 75-100%'],
#       dtype='<U29'), 0.0515, 0.2168, 0.6894]
# [2, array(['climate_control 0-25%', 'kitchen 0-25%'], dtype='<U21'), 0.2085, 0.2085, 1.0]
# [2, array(['kitchen 25-50%', 'climate_control 0-25%'], dtype='<U21'), 0.094, 0.299, 1.1955]
# [2, array(['laundry 0-25%', 'climate_control 0-25%'], dtype='<U21'), 0.1514, 0.4816, 1.804]
# [2, array(['laundry 50-75%', 'climate_control 0-25%'], dtype='<U21'), 0.0663, 0.2108, 0.8625]
# [2, array(['laundry 75-100%', 'climate_control 0-25%'], dtype='<U21'), 0.0574, 0.2417, 0.7686]
# [2, array(['climate_control 0-25%', 'other 0-25%'], dtype='<U21'), 0.0859, 0.2733, 1.0445]
# [2, array(['climate_control 0-25%', 'other 25-50%'], dtype='<U21'), 0.1121, 0.3565, 1.2291]
# [2, array(['other 50-75%', 'climate_control 0-25%'], dtype='<U21'), 0.0714, 0.2272, 0.9724]
# [2, array(['climate_control 0-25%', 'spring'], dtype='<U21'), 0.0634, 0.2016, 0.8343]
# [2, array(['summer', 'climate_control 0-25%'], dtype='<U21'), 0.0594, 0.2444, 0.7772]
# [2, array(['voltage 0-25%', 'climate_control 0-25%'], dtype='<U21'), 0.0738, 0.2347, 0.9881]
# [2, array(['climate_control 0-25%', 'voltage 50-75%'], dtype='<U21'), 0.0657, 0.2088, 0.8943]
# [2, array(['voltage 75-100%', 'climate_control 0-25%'], dtype='<U21'), 0.1254, 0.3988, 1.3216]
# [2, array(['climate_control 0-25%', 'weekday'], dtype='<U21'), 0.2305, 0.2305, 1.0]
# [2, array(['weekend', 'climate_control 0-25%'], dtype='<U21'), 0.084, 0.267, 0.9261]
# [2, array(['climate_control 0-25%', 'winter'], dtype='<U21'), 0.1281, 0.4073, 1.5136]
# [2, array(['climate_control 25-50%', 'global_active_power 0-25%'],
#       dtype='<U25'), 0.1113, 0.4496, 1.4627]
# [2, array(['global_active_power 25-50%', 'climate_control 25-50%'],
#       dtype='<U26'), 0.0933, 0.377, 1.408]
# [2, array(['climate_control 25-50%', 'global_intensity 0-25%'], dtype='<U22'), 0.1137, 0.4591, 1.4605]
# [2, array(['global_intensity 25-50%', 'climate_control 25-50%'], dtype='<U23'), 0.0911, 0.368, 1.4139]
# [2, array(['climate_control 25-50%', 'global_reactive_power 0-25%'],
#       dtype='<U27'), 0.0636, 0.2569, 0.9625]
# [2, array(['global_reactive_power 25-50%', 'climate_control 25-50%'],
#       dtype='<U28'), 0.0616, 0.2488, 0.9871]
# [2, array(['global_reactive_power 50-75%', 'climate_control 25-50%'],
#       dtype='<U28'), 0.0641, 0.2589, 1.0641]
# [2, array(['climate_control 25-50%', 'global_reactive_power 75-100%'],
#       dtype='<U29'), 0.0583, 0.2354, 0.9901]
# [2, array(['kitchen 25-50%', 'climate_control 25-50%'], dtype='<U22'), 0.0724, 0.2924, 1.1692]
# [2, array(['kitchen 50-75%', 'climate_control 25-50%'], dtype='<U22'), 0.1364, 0.5508, 2.2388]
# [2, array(['laundry 25-50%', 'climate_control 25-50%'], dtype='<U22'), 0.0965, 0.3897, 1.5524]
# [2, array(['laundry 50-75%', 'climate_control 25-50%'], dtype='<U22'), 0.0576, 0.2327, 0.9519]
# [2, array(['laundry 75-100%', 'climate_control 25-50%'], dtype='<U22'), 0.0588, 0.2375, 0.9995]
# [2, array(['climate_control 25-50%', 'other 0-25%'], dtype='<U22'), 0.0864, 0.3489, 1.3334]
# [2, array(['other 25-50%', 'climate_control 25-50%'], dtype='<U22'), 0.0777, 0.3139, 1.0821]
# [2, array(['other 50-75%', 'climate_control 25-50%'], dtype='<U22'), 0.0501, 0.2025, 0.8669]
# [2, array(['climate_control 25-50%', 'spring'], dtype='<U22'), 0.0677, 0.2735, 1.1316]
# [2, array(['summer', 'climate_control 25-50%'], dtype='<U22'), 0.0725, 0.2927, 1.2051]
# [2, array(['voltage 25-50%', 'climate_control 25-50%'], dtype='<U22'), 0.057, 0.2304, 1.0137]
# [2, array(['climate_control 25-50%', 'voltage 50-75%'], dtype='<U22'), 0.0707, 0.2854, 1.2225]
# [2, array(['voltage 75-100%', 'climate_control 25-50%'], dtype='<U22'), 0.0938, 0.3788, 1.2553]
# [2, array(['climate_control 25-50%', 'weekday'], dtype='<U22'), 0.1743, 0.7039, 0.9891]
# [2, array(['weekend', 'climate_control 25-50%'], dtype='<U22'), 0.0733, 0.2961, 1.0269]
# [2, array(['global_active_power 25-50%', 'climate_control 50-75%'],
#       dtype='<U26'), 0.0779, 0.3446, 1.2871]
# [2, array(['global_active_power 50-75%', 'climate_control 50-75%'],
#       dtype='<U26'), 0.0628, 0.2777, 1.3477]
# [2, array(['climate_control 50-75%', 'global_active_power 75-100%'],
#       dtype='<U27'), 0.0556, 0.2457, 1.1231]
# [2, array(['global_intensity 25-50%', 'climate_control 50-75%'], dtype='<U23'), 0.0749, 0.3314, 1.2732]
# [2, array(['global_intensity 50-75%', 'climate_control 50-75%'], dtype='<U23'), 0.0621, 0.2746, 1.334]
# [2, array(['climate_control 50-75%', 'global_intensity 75-100%'], dtype='<U24'), 0.0567, 0.2509, 1.143]
# [2, array(['global_reactive_power 25-50%', 'climate_control 50-75%'],
#       dtype='<U28'), 0.0522, 0.2308, 0.9158]
# [2, array(['global_reactive_power 50-75%', 'climate_control 50-75%'],
#       dtype='<U28'), 0.0578, 0.2555, 1.0498]
# [2, array(['climate_control 50-75%', 'global_reactive_power 75-100%'],
#       dtype='<U29'), 0.0701, 0.3098, 1.3035]
# [2, array(['kitchen 75-100%', 'climate_control 50-75%'], dtype='<U22'), 0.1015, 0.4487, 2.0148]
# [2, array(['laundry 50-75%', 'climate_control 50-75%'], dtype='<U22'), 0.0696, 0.3076, 1.2586]
# [2, array(['laundry 75-100%', 'climate_control 50-75%'], dtype='<U22'), 0.0658, 0.2908, 1.2239]
# [2, array(['climate_control 50-75%', 'other 0-25%'], dtype='<U22'), 0.0632, 0.2795, 1.0682]
# [2, array(['other 25-50%', 'climate_control 50-75%'], dtype='<U22'), 0.0559, 0.2471, 0.8518]
# [2, array(['climate_control 50-75%', 'other 75-100%'], dtype='<U22'), 0.0606, 0.2678, 1.2473]
# [2, array(['climate_control 50-75%', 'spring'], dtype='<U22'), 0.0541, 0.2394, 0.9906]
# [2, array(['summer', 'climate_control 50-75%'], dtype='<U22'), 0.0757, 0.3346, 1.3776]
# [2, array(['voltage 0-25%', 'climate_control 50-75%'], dtype='<U22'), 0.0695, 0.3075, 1.2947]
# [2, array(['climate_control 50-75%', 'voltage 50-75%'], dtype='<U22'), 0.0542, 0.2397, 1.0265]
# [2, array(['voltage 75-100%', 'climate_control 50-75%'], dtype='<U22'), 0.0549, 0.2428, 0.8046]
# [2, array(['climate_control 50-75%', 'weekday'], dtype='<U22'), 0.1553, 0.6868, 0.965]
# [2, array(['weekend', 'climate_control 50-75%'], dtype='<U22'), 0.0708, 0.3132, 1.0864]
# [2, array(['global_active_power 50-75%', 'climate_control 75-100%'],
#       dtype='<U26'), 0.0861, 0.4066, 1.9732]
# [2, array(['climate_control 75-100%', 'global_active_power 75-100%'],
#       dtype='<U27'), 0.1257, 0.5934, 2.712]
# [2, array(['global_intensity 50-75%', 'climate_control 75-100%'], dtype='<U23'), 0.0876, 0.4135, 2.0087]
# [2, array(['climate_control 75-100%', 'global_intensity 75-100%'],
#       dtype='<U24'), 0.1242, 0.5865, 2.6718]
# [2, array(['global_reactive_power 25-50%', 'climate_control 75-100%'],
#       dtype='<U28'), 0.0547, 0.2582, 1.0244]
# [2, array(['climate_control 75-100%', 'global_reactive_power 75-100%'],
#       dtype='<U29'), 0.0578, 0.273, 1.1486]
# [2, array(['kitchen 50-75%', 'climate_control 75-100%'], dtype='<U23'), 0.0602, 0.284, 1.1544]
# [2, array(['kitchen 75-100%', 'climate_control 75-100%'], dtype='<U23'), 0.0713, 0.3364, 1.5107]
# [2, array(['laundry 25-50%', 'climate_control 75-100%'], dtype='<U23'), 0.0674, 0.318, 1.267]
# [2, array(['laundry 50-75%', 'climate_control 75-100%'], dtype='<U23'), 0.051, 0.2406, 0.9843]
# [2, array(['laundry 75-100%', 'climate_control 75-100%'], dtype='<U23'), 0.0556, 0.2626, 1.1052]
# [2, array(['other 50-75%', 'climate_control 75-100%'], dtype='<U23'), 0.0655, 0.3094, 1.3243]
# [2, array(['climate_control 75-100%', 'other 75-100%'], dtype='<U23'), 0.0758, 0.3578, 1.6664]
# [2, array(['climate_control 75-100%', 'spring'], dtype='<U23'), 0.0564, 0.2664, 1.1024]
# [2, array(['voltage 0-25%', 'climate_control 75-100%'], dtype='<U23'), 0.0681, 0.3213, 1.3529]
# [2, array(['voltage 25-50%', 'climate_control 75-100%'], dtype='<U23'), 0.0731, 0.3452, 1.5191]
# [2, array(['climate_control 75-100%', 'weekday'], dtype='<U23'), 0.1516, 0.7157, 1.0056]
# [2, array(['weekend', 'climate_control 75-100%'], dtype='<U23'), 0.0602, 0.2843, 0.9862]
# [2, array(['winter', 'climate_control 75-100%'], dtype='<U23'), 0.0612, 0.2891, 1.0743]
# [2, array(['global_intensity 0-25%', 'global_active_power 0-25%'],
#       dtype='<U25'), 0.2915, 0.2915, 1.0]
# [2, array(['global_reactive_power 0-25%', 'global_active_power 0-25%'],
#       dtype='<U27'), 0.1391, 0.4527, 1.696]
# [2, array(['global_reactive_power 25-50%', 'global_active_power 0-25%'],
#       dtype='<U28'), 0.0891, 0.29, 1.1505]
# [2, array(['global_reactive_power 50-75%', 'global_active_power 0-25%'],
#       dtype='<U28'), 0.0553, 0.2271, 0.7389]
# [2, array(['kitchen 0-25%', 'global_active_power 0-25%'], dtype='<U25'), 0.1227, 0.3992, 1.42]
# [2, array(['kitchen 25-50%', 'global_active_power 0-25%'], dtype='<U25'), 0.0876, 0.285, 1.1394]
# [2, array(['kitchen 50-75%', 'global_active_power 0-25%'], dtype='<U25'), 0.0648, 0.2109, 0.8573]
# [2, array(['laundry 0-25%', 'global_active_power 0-25%'], dtype='<U25'), 0.1231, 0.4004, 1.5]
# [2, array(['laundry 25-50%', 'global_active_power 0-25%'], dtype='<U25'), 0.0756, 0.246, 0.9799]
# [2, array(['laundry 50-75%', 'global_active_power 0-25%'], dtype='<U25'), 0.0765, 0.2488, 1.0178]
# [2, array(['other 0-25%', 'global_active_power 0-25%'], dtype='<U25'), 0.1868, 0.6077, 2.3229]
# [2, array(['other 25-50%', 'global_active_power 0-25%'], dtype='<U25'), 0.1206, 0.3923, 1.3525]
# [2, array(['spring', 'global_active_power 0-25%'], dtype='<U25'), 0.0577, 0.2388, 0.7768]
# [2, array(['summer', 'global_active_power 0-25%'], dtype='<U25'), 0.1075, 0.3497, 1.4399]
# [2, array(['voltage 25-50%', 'global_active_power 0-25%'], dtype='<U25'), 0.059, 0.2598, 0.8451]
# [2, array(['voltage 50-75%', 'global_active_power 0-25%'], dtype='<U25'), 0.0794, 0.2583, 1.1063]
# [2, array(['voltage 75-100%', 'global_active_power 0-25%'], dtype='<U25'), 0.1214, 0.395, 1.309]
# [2, array(['weekday', 'global_active_power 0-25%'], dtype='<U25'), 0.2269, 0.2269, 1.0]
# [2, array(['weekend', 'global_active_power 0-25%'], dtype='<U25'), 0.0804, 0.2617, 0.9076]
# [2, array(['winter', 'global_active_power 0-25%'], dtype='<U25'), 0.0753, 0.245, 0.9105]
# [2, array(['global_active_power 25-50%', 'global_intensity 25-50%'],
#       dtype='<U26'), 0.2415, 0.2415, 1.0]
# [2, array(['global_active_power 25-50%', 'global_reactive_power 25-50%'],
#       dtype='<U28'), 0.0611, 0.2281, 0.9048]
# [2, array(['global_active_power 25-50%', 'global_reactive_power 50-75%'],
#       dtype='<U28'), 0.0905, 0.3379, 1.3885]
# [2, array(['global_active_power 25-50%', 'global_reactive_power 75-100%'],
#       dtype='<U29'), 0.0798, 0.2979, 1.2532]
# [2, array(['global_active_power 25-50%', 'kitchen 0-25%'], dtype='<U26'), 0.0619, 0.2312, 0.8223]
# [2, array(['global_active_power 25-50%', 'kitchen 25-50%'], dtype='<U26'), 0.0718, 0.2683, 1.0725]
# [2, array(['global_active_power 25-50%', 'kitchen 50-75%'], dtype='<U26'), 0.0855, 0.3192, 1.2973]
# [2, array(['global_active_power 25-50%', 'laundry 25-50%'], dtype='<U26'), 0.0685, 0.2559, 1.0197]
# [2, array(['global_active_power 25-50%', 'laundry 50-75%'], dtype='<U26'), 0.0677, 0.253, 1.0349]
# [2, array(['global_active_power 25-50%', 'laundry 75-100%'], dtype='<U26'), 0.0808, 0.3019, 1.2704]
# [2, array(['global_active_power 25-50%', 'other 25-50%'], dtype='<U26'), 0.1065, 0.3979, 1.3718]
# [2, array(['global_active_power 25-50%', 'other 50-75%'], dtype='<U26'), 0.1247, 0.4658, 1.9941]
# [2, array(['global_active_power 25-50%', 'spring'], dtype='<U26'), 0.0731, 0.2729, 1.1291]
# [2, array(['global_active_power 25-50%', 'summer'], dtype='<U26'), 0.0535, 0.2204, 0.8231]
# [2, array(['global_active_power 25-50%', 'voltage 50-75%'], dtype='<U26'), 0.0724, 0.2703, 1.1574]
# [2, array(['global_active_power 25-50%', 'voltage 75-100%'], dtype='<U26'), 0.122, 0.4556, 1.51]
# [2, array(['global_active_power 25-50%', 'weekday'], dtype='<U26'), 0.1882, 0.703, 0.9878]
# [2, array(['global_active_power 25-50%', 'weekend'], dtype='<U26'), 0.0795, 0.297, 1.0301]
# [2, array(['global_active_power 25-50%', 'winter'], dtype='<U26'), 0.0775, 0.2894, 1.0757]
# [2, array(['global_active_power 50-75%', 'global_intensity 50-75%'],
#       dtype='<U26'), 0.1995, 0.968, 4.7019]
# [2, array(['global_active_power 50-75%', 'global_reactive_power 0-25%'],
#       dtype='<U27'), 0.0536, 0.2601, 0.9746]
# [2, array(['global_active_power 50-75%', 'global_reactive_power 25-50%'],
#       dtype='<U28'), 0.0572, 0.2776, 1.1012]
# [2, array(['global_active_power 50-75%', 'kitchen 0-25%'], dtype='<U26'), 0.0514, 0.2494, 0.8872]
# [2, array(['global_active_power 50-75%', 'kitchen 50-75%'], dtype='<U26'), 0.0533, 0.2585, 1.0506]
# [2, array(['kitchen 75-100%', 'global_active_power 50-75%'], dtype='<U26'), 0.0528, 0.2561, 1.1498]
# [2, array(['laundry 25-50%', 'global_active_power 50-75%'], dtype='<U26'), 0.0556, 0.2698, 1.075]
# [2, array(['laundry 50-75%', 'global_active_power 50-75%'], dtype='<U26'), 0.0534, 0.2591, 1.0602]
# [2, array(['global_active_power 50-75%', 'other 25-50%'], dtype='<U26'), 0.0526, 0.2553, 0.8801]
# [2, array(['other 50-75%', 'global_active_power 50-75%'], dtype='<U26'), 0.0544, 0.2642, 1.1308]
# [2, array(['global_active_power 50-75%', 'other 75-100%'], dtype='<U26'), 0.0646, 0.3133, 1.4592]
# [2, array(['global_active_power 50-75%', 'spring'], dtype='<U26'), 0.0552, 0.268, 1.1091]
# [2, array(['summer', 'global_active_power 50-75%'], dtype='<U26'), 0.0519, 0.2519, 1.0369]
# [2, array(['voltage 0-25%', 'global_active_power 50-75%'], dtype='<U26'), 0.0582, 0.2823, 1.1885]
# [2, array(['voltage 25-50%', 'global_active_power 50-75%'], dtype='<U26'), 0.0584, 0.2832, 1.2463]
# [2, array(['global_active_power 50-75%', 'voltage 50-75%'], dtype='<U26'), 0.0502, 0.2438, 1.044]
# [2, array(['global_active_power 50-75%', 'weekday'], dtype='<U26'), 0.1538, 0.7462, 1.0485]
# [2, array(['weekend', 'global_active_power 50-75%'], dtype='<U26'), 0.0523, 0.2538, 0.8802]
# [2, array(['global_intensity 75-100%', 'global_active_power 75-100%'],
#       dtype='<U27'), 0.2158, 0.2158, 1.0]
# [2, array(['global_reactive_power 50-75%', 'global_active_power 75-100%'],
#       dtype='<U28'), 0.0501, 0.2291, 0.9416]
# [2, array(['global_reactive_power 75-100%', 'global_active_power 75-100%'],
#       dtype='<U29'), 0.0863, 0.3944, 1.6593]
# [2, array(['kitchen 75-100%', 'global_active_power 75-100%'], dtype='<U27'), 0.0891, 0.4074, 1.8292]
# [2, array(['laundry 25-50%', 'global_active_power 75-100%'], dtype='<U27'), 0.0513, 0.2343, 0.9335]
# [2, array(['laundry 75-100%', 'global_active_power 75-100%'], dtype='<U27'), 0.076, 0.3475, 1.4623]
# [2, array(['other 50-75%', 'global_active_power 75-100%'], dtype='<U27'), 0.0544, 0.2488, 1.065]
# [2, array(['other 75-100%', 'global_active_power 75-100%'], dtype='<U27'), 0.1501, 0.6862, 3.1954]
# [2, array(['spring', 'global_active_power 75-100%'], dtype='<U27'), 0.0557, 0.2544, 1.0528]
# [2, array(['voltage 0-25%', 'global_active_power 75-100%'], dtype='<U27'), 0.1082, 0.4947, 2.0828]
# [2, array(['voltage 25-50%', 'global_active_power 75-100%'], dtype='<U27'), 0.06, 0.2744, 1.2073]
# [2, array(['weekday', 'global_active_power 75-100%'], dtype='<U27'), 0.1427, 0.6523, 0.9166]
# [2, array(['weekend', 'global_active_power 75-100%'], dtype='<U27'), 0.0761, 0.3477, 1.2057]
# [2, array(['winter', 'global_active_power 75-100%'], dtype='<U27'), 0.0711, 0.3251, 1.2083]
# [2, array(['global_intensity 0-25%', 'global_reactive_power 0-25%'],
#       dtype='<U27'), 0.1437, 0.4572, 1.7131]
# [2, array(['global_reactive_power 25-50%', 'global_intensity 0-25%'],
#       dtype='<U28'), 0.0997, 0.317, 1.2578]
# [2, array(['global_reactive_power 50-75%', 'global_intensity 0-25%'],
#       dtype='<U28'), 0.0583, 0.2397, 0.7626]
# [2, array(['kitchen 0-25%', 'global_intensity 0-25%'], dtype='<U22'), 0.1204, 0.383, 1.3623]
# [2, array(['kitchen 25-50%', 'global_intensity 0-25%'], dtype='<U22'), 0.0917, 0.2917, 1.1662]
# [2, array(['kitchen 50-75%', 'global_intensity 0-25%'], dtype='<U22'), 0.0691, 0.2199, 0.8938]
# [2, array(['laundry 0-25%', 'global_intensity 0-25%'], dtype='<U22'), 0.1257, 0.4, 1.4983]
# [2, array(['laundry 25-50%', 'global_intensity 0-25%'], dtype='<U22'), 0.0847, 0.2695, 1.0739]
# [2, array(['laundry 50-75%', 'global_intensity 0-25%'], dtype='<U22'), 0.0772, 0.2457, 1.0051]
# ...
#        'other 25-50%', 'False', 'global_intensity 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0613, 0.2115, 1.7202]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'voltage 75-100%', 'False', 'global_intensity 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0566, 0.2502, 2.125]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%', 'False',
#        'global_intensity 0-25%', 'weekday', 'global_active_power 0-25%'],
#       dtype='<U27'), 0.0919, 0.2923, 1.9533]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'laundry 0-25%', 'kitchen 0-25%', 'False',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0626, 0.2038, 2.4861]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'kitchen 0-25%', 'False', 'other 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0524, 0.2002, 2.2011]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'kitchen 0-25%', 'False', 'weekday', 'global_active_power 0-25%'],
#       dtype='<U27'), 0.071, 0.2258, 3.1711]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'laundry 0-25%', 'False', 'weekday', 'global_active_power 0-25%'],
#       dtype='<U27'), 0.0549, 0.2057, 2.1619]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'laundry 0-25%', 'kitchen 0-25%', 'False',
#        'global_intensity 0-25%'], dtype='<U27'), 0.0635, 0.2018, 3.1717]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'kitchen 0-25%', 'False', 'global_intensity 0-25%', 'other 0-25%'],
#       dtype='<U27'), 0.0507, 0.2238, 3.311]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'kitchen 0-25%', 'False', 'global_intensity 0-25%', 'weekday'],
#       dtype='<U27'), 0.0697, 0.2218, 3.1709]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'laundry 0-25%', 'False', 'global_intensity 0-25%', 'weekday'],
#       dtype='<U27'), 0.0558, 0.209, 2.1685]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'laundry 0-25%', 'kitchen 0-25%', 'False', 'weekday'], dtype='<U27'), 0.0616, 0.219, 3.0206]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'voltage 75-100%', 'False', 'winter', 'weekday'], dtype='<U27'), 0.0507, 0.224, 2.4283]
# [6, array(['activation_type_label cam_2', 'False', 'global_intensity 0-25%',
#        'global_reactive_power 0-25%', 'other 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0581, 0.2178, 1.8181]
# [6, array(['activation_type_label cam_2', 'voltage 75-100%', 'False',
#        'global_intensity 0-25%', 'global_reactive_power 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0559, 0.2093, 2.2142]
# [6, array(['activation_type_label cam_2', 'False', 'global_intensity 0-25%',
#        'global_reactive_power 0-25%', 'weekday',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0719, 0.2339, 3.164]
# [6, array(['activation_type_label cam_2', 'laundry 0-25%', 'kitchen 0-25%',
#        'False', 'global_intensity 0-25%', 'global_active_power 0-25%'],
#       dtype='<U27'), 0.062, 0.2016, 3.1682]
# [6, array(['activation_type_label cam_2', 'kitchen 0-25%', 'False',
#        'global_intensity 0-25%', 'other 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0507, 0.2316, 3.4259]
# [6, array(['activation_type_label cam_2', 'kitchen 0-25%', 'False',
#        'global_intensity 0-25%', 'weekday', 'global_active_power 0-25%'],
#       dtype='<U27'), 0.0681, 0.2215, 3.1666]
# [6, array(['activation_type_label cam_2', 'laundry 0-25%', 'False',
#        'global_intensity 0-25%', 'other 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0524, 0.2003, 2.2512]
# [6, array(['activation_type_label cam_2', 'laundry 0-25%', 'False',
#        'global_intensity 0-25%', 'weekday', 'global_active_power 0-25%'],
#       dtype='<U27'), 0.0649, 0.211, 3.1577]
# [6, array(['activation_type_label cam_2', 'summer', 'False',
#        'global_active_power 0-25%', 'global_intensity 0-25%',
#        'other 0-25%'], dtype='<U27'), 0.0604, 0.231, 3.5627]
# [6, array(['activation_type_label cam_2', 'False',
#        'global_active_power 0-25%', 'global_intensity 0-25%', 'weekday',
#        'other 0-25%'], dtype='<U27'), 0.088, 0.2864, 3.2097]
# [6, array(['activation_type_label cam_2', 'voltage 75-100%', 'other 25-50%',
#        'False', 'global_intensity 0-25%', 'global_active_power 0-25%'],
#       dtype='<U27'), 0.0568, 0.2593, 3.2103]
# [6, array(['activation_type_label cam_2', 'other 25-50%', 'False',
#        'global_intensity 0-25%', 'weekday', 'global_active_power 0-25%'],
#       dtype='<U27'), 0.0616, 0.2005, 2.8632]
# [6, array(['activation_type_label cam_2', 'voltage 75-100%', 'False',
#        'global_intensity 0-25%', 'weekday', 'global_active_power 0-25%'],
#       dtype='<U27'), 0.0674, 0.2192, 2.9197]
# [6, array(['activation_type_label cam_2', 'voltage 75-100%', 'False',
#        'winter', 'global_intensity 0-25%', 'global_active_power 0-25%'],
#       dtype='<U27'), 0.0542, 0.2013, 2.1295]
# [6, array(['climate_control 0-25%', 'kitchen 0-25%', 'False',
#        'global_intensity 0-25%', 'attention_type_label other',
#        'global_active_power 0-25%'], dtype='<U26'), 0.0531, 0.2346, 3.3447]
# [6, array(['climate_control 0-25%', 'False', 'global_intensity 0-25%',
#        'attention_type_label other', 'weekday',
#        'global_active_power 0-25%'], dtype='<U26'), 0.0577, 0.255, 2.0019]
# [6, array(['False', 'global_active_power 0-25%', 'global_intensity 0-25%',
#        'attention_type_label other', 'weekday', 'other 0-25%'],
#       dtype='<U26'), 0.0512, 0.2337, 2.9647]
# [6, array(['climate_control 0-25%', 'laundry 0-25%', 'kitchen 0-25%', 'False',
#        'global_intensity 0-25%', 'global_active_power 0-25%'],
#       dtype='<U25'), 0.0627, 0.2041, 3.1709]
# [6, array(['climate_control 0-25%', 'kitchen 0-25%', 'False',
#        'global_intensity 0-25%', 'other 0-25%',
#        'global_active_power 0-25%'], dtype='<U25'), 0.0514, 0.2272, 3.3089]
# [6, array(['climate_control 0-25%', 'kitchen 0-25%', 'False',
#        'global_intensity 0-25%', 'weekday', 'global_active_power 0-25%'],
#       dtype='<U25'), 0.0688, 0.2187, 3.1662]
# [6, array(['climate_control 0-25%', 'laundry 0-25%', 'False',
#        'global_intensity 0-25%', 'weekday', 'global_active_power 0-25%'],
#       dtype='<U25'), 0.0548, 0.2052, 2.2085]
# [6, array(['climate_control 75-100%', 'global_intensity 75-100%',
#        'activation_type_label cam_1', 'global_active_power 75-100%',
#        'weekday', 'other 75-100%'], dtype='<U27'), 0.0504, 0.2379, 2.4835]
# [6, array(['global_intensity 75-100%', 'activation_type_label cam_1',
#        'voltage 0-25%', 'global_active_power 75-100%', 'weekday',
#        'other 75-100%'], dtype='<U27'), 0.05, 0.2285, 4.5431]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'kitchen 0-25%', 'global_intensity 0-25%',
#        'attention_type_label other', 'global_active_power 0-25%'],
#       dtype='<U27'), 0.0691, 0.2196, 3.1723]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'laundry 0-25%', 'global_intensity 0-25%',
#        'attention_type_label other', 'global_active_power 0-25%'],
#       dtype='<U27'), 0.0589, 0.2208, 2.2792]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'global_intensity 0-25%', 'attention_type_label other', 'weekday',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0748, 0.2379, 1.8853]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'kitchen 0-25%', 'attention_type_label other', 'weekday',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0577, 0.2052, 2.6426]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'laundry 0-25%', 'kitchen 0-25%', 'global_intensity 0-25%',
#        'attention_type_label other'], dtype='<U27'), 0.0505, 0.2605, 4.2197]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'kitchen 0-25%', 'global_intensity 0-25%',
#        'attention_type_label other', 'weekday'], dtype='<U27'), 0.0563, 0.2003, 2.5609]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'laundry 0-25%', 'kitchen 0-25%', 'attention_type_label other',
#        'weekday'], dtype='<U27'), 0.0521, 0.2688, 3.8157]
# [6, array(['activation_type_label cam_2', 'global_intensity 0-25%',
#        'global_reactive_power 0-25%', 'attention_type_label other',
#        'weekday', 'global_active_power 0-25%'], dtype='<U27'), 0.0607, 0.2273, 1.8016]
# [6, array(['activation_type_label cam_2', 'kitchen 0-25%',
#        'global_intensity 0-25%', 'attention_type_label other', 'weekday',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0551, 0.2846, 2.2338]
# [6, array(['activation_type_label cam_2', 'laundry 0-25%',
#        'global_intensity 0-25%', 'attention_type_label other', 'weekday',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0541, 0.2028, 1.6074]
# [6, array(['activation_type_label cam_2', 'global_active_power 0-25%',
#        'global_intensity 0-25%', 'attention_type_label other', 'weekday',
#        'other 0-25%'], dtype='<U27'), 0.0769, 0.2503, 3.2062]
# [6, array(['activation_type_label cam_2', 'voltage 75-100%',
#        'global_intensity 0-25%', 'attention_type_label other', 'weekday',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0529, 0.2089, 1.6395]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'kitchen 0-25%', 'global_intensity 0-25%',
#        'global_reactive_power 0-25%', 'global_active_power 0-25%'],
#       dtype='<U27'), 0.0517, 0.286, 2.4632]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'laundry 0-25%', 'global_intensity 0-25%',
#        'global_reactive_power 0-25%', 'global_active_power 0-25%'],
#       dtype='<U27'), 0.0524, 0.2895, 3.0102]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'global_intensity 0-25%', 'global_reactive_power 0-25%', 'weekday',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0588, 0.2202, 1.8498]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'laundry 0-25%', 'kitchen 0-25%', 'global_intensity 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.081, 0.2576, 3.1722]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'kitchen 0-25%', 'global_intensity 0-25%', 'other 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0672, 0.2137, 3.1674]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'kitchen 0-25%', 'global_intensity 0-25%', 'weekday',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0885, 0.2814, 3.1704]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'laundry 0-25%', 'global_intensity 0-25%', 'weekday',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0711, 0.2262, 2.5647]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'global_active_power 0-25%', 'global_intensity 0-25%', 'weekday',
#        'other 0-25%'], dtype='<U27'), 0.0627, 0.2039, 3.2483]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'other 25-50%', 'global_intensity 0-25%', 'weekday',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0564, 0.2097, 2.5278]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'laundry 0-25%', 'kitchen 0-25%', 'weekday',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0622, 0.2023, 2.4427]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'kitchen 0-25%', 'global_active_power 0-25%', 'weekday',
#        'other 0-25%'], dtype='<U27'), 0.0556, 0.2125, 2.2802]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'laundry 0-25%', 'kitchen 0-25%', 'global_intensity 0-25%',
#        'weekday'], dtype='<U27'), 0.0626, 0.2228, 3.038]
# [6, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'kitchen 0-25%', 'global_intensity 0-25%', 'weekday',
#        'other 0-25%'], dtype='<U27'), 0.0535, 0.2044, 2.2473]
# [6, array(['activation_type_label cam_2', 'global_active_power 0-25%',
#        'global_intensity 0-25%', 'weekday', 'climate_control 25-50%',
#        'other 0-25%'], dtype='<U27'), 0.0519, 0.2095, 1.6066]
# [6, array(['activation_type_label cam_2', 'global_active_power 0-25%',
#        'global_intensity 0-25%', 'global_reactive_power 0-25%', 'weekday',
#        'other 0-25%'], dtype='<U27'), 0.061, 0.2284, 1.7517]
# [6, array(['activation_type_label cam_2', 'laundry 0-25%', 'kitchen 0-25%',
#        'global_intensity 0-25%', 'weekday', 'global_active_power 0-25%'],
#       dtype='<U27'), 0.0614, 0.2183, 2.4749]
# [6, array(['activation_type_label cam_2', 'kitchen 0-25%',
#        'global_active_power 0-25%', 'global_intensity 0-25%', 'weekday',
#        'other 0-25%'], dtype='<U27'), 0.0536, 0.2047, 2.3065]
# [6, array(['activation_type_label cam_2', 'laundry 0-25%',
#        'global_active_power 0-25%', 'global_intensity 0-25%', 'weekday',
#        'other 0-25%'], dtype='<U27'), 0.0531, 0.2031, 2.3025]
# [6, array(['activation_type_label cam_2', 'summer',
#        'global_active_power 0-25%', 'global_intensity 0-25%', 'weekday',
#        'other 0-25%'], dtype='<U27'), 0.066, 0.2148, 3.2453]
# [6, array(['climate_control 0-25%', 'kitchen 0-25%', 'global_intensity 0-25%',
#        'attention_type_label other', 'weekday',
#        'global_active_power 0-25%'], dtype='<U26'), 0.0555, 0.2988, 3.3204]
# [6, array(['climate_control 0-25%', 'laundry 0-25%', 'kitchen 0-25%',
#        'global_intensity 0-25%', 'weekday', 'global_active_power 0-25%'],
#       dtype='<U25'), 0.0619, 0.2015, 3.1799]
# [6, array(['climate_control 0-25%', 'kitchen 0-25%',
#        'global_active_power 0-25%', 'global_intensity 0-25%', 'weekday',
#        'other 0-25%'], dtype='<U25'), 0.0541, 0.2067, 2.3072]
# [7, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'kitchen 0-25%', 'False', 'attention_type_label other',
#        'global_intensity 0-25%', 'global_active_power 0-25%'],
#       dtype='<U27'), 0.0524, 0.2313, 3.3414]
# [7, array(['activation_type_label cam_2', 'climate_control 0-25%', 'False',
#        'attention_type_label other', 'global_intensity 0-25%', 'weekday',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0573, 0.253, 2.0051]
# [7, array(['activation_type_label cam_2', 'False', 'global_intensity 0-25%',
#        'attention_type_label other', 'weekday', 'other 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0505, 0.2305, 2.9529]
# [7, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'laundry 0-25%', 'kitchen 0-25%', 'False',
#        'global_intensity 0-25%', 'global_active_power 0-25%'],
#       dtype='<U27'), 0.0618, 0.2012, 3.1697]
# [7, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'kitchen 0-25%', 'False', 'global_intensity 0-25%', 'other 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0505, 0.2232, 3.3088]
# [7, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'kitchen 0-25%', 'False', 'global_intensity 0-25%', 'weekday',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0679, 0.2158, 3.1706]
# [7, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'laundry 0-25%', 'False', 'global_intensity 0-25%', 'weekday',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0542, 0.2029, 2.2073]
# [7, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'kitchen 0-25%', 'global_intensity 0-25%',
#        'attention_type_label other', 'weekday',
#        'global_active_power 0-25%'], dtype='<U27'), 0.055, 0.2045, 3.6695]
# [7, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'laundry 0-25%', 'kitchen 0-25%', 'global_intensity 0-25%',
#        'weekday', 'global_active_power 0-25%'], dtype='<U27'), 0.0612, 0.2177, 3.0603]
# [7, array(['activation_type_label cam_2', 'climate_control 0-25%',
#        'kitchen 0-25%', 'global_intensity 0-25%', 'weekday',
#        'other 0-25%', 'global_active_power 0-25%'], dtype='<U27'), 0.0534, 0.204, 2.3048]

# %%
# Filter by rhs=='Power Pattern *'
filter_RHS_ECP = True
if(filter_RHS_ECP):
    association_rules_np_rhs = []
    for r in range(len(association_rules_np)):
        # rhs = association_rules_np[r, 1][-1] # old
        rhs = association_rules_np[r][1][-1]
        if(rhs=='True' or rhs=='False'):
            association_rules_np_rhs.append(association_rules_np[r])
    association_rules_np_rhs = np.array(association_rules_np_rhs, dtype=object)
else:
    association_rules_np_rhs = association_rules_np
print('Rule Filtered: %d' %(len(association_rules_np_rhs)))
# Out:
# Rule Filtered: 430

# %%
# Sort rules by confidence
association_rules_np_rhs_sorted = association_rules_np_rhs[association_rules_np_rhs[:, 3].argsort()][::-1]
print(len(association_rules_np_rhs_sorted))
print(association_rules_np_rhs_sorted[:10])

# Length, Rule, Support, Confidence, Lift
# Out:
# 430
# [[1 array(['False'], dtype='<U5') 0.666 0.666 1.0]
#  [2 array(['global_active_power 50-75%', 'False'], dtype='<U26') 0.1195
#   0.5801 0.871]
#  [2 array(['global_intensity 50-75%', 'False'], dtype='<U23') 0.1189
#   0.5774 0.867]
#  [2 array(['attention_type_label other', 'True'], dtype='<U26') 0.1714
#   0.513 1.0107]
#  [3
#   array(['activation_type_label cam_2', 'weekday', 'True'], dtype='<U27')
#   0.1644 0.4921 1.1226]
#  [3
#   array(['climate_control 75-100%', 'global_intensity 75-100%', 'False'],
#         dtype='<U24')
#   0.0952 0.4493 2.6939]
#  [3 array(['activation_type_label cam_2', 'kitchen 25-50%', 'False'],
#           dtype='<U27')
#   0.1086 0.4342 1.1193]
#  [3
#   array(['voltage 0-25%', 'global_intensity 75-100%', 'False'], dtype='<U24')
#   0.0916 0.4172 2.3546]
#  [3 array(['global_intensity 0-25%', 'climate_control 0-25%', 'False'],
#           dtype='<U22')
#   0.1311 0.417 1.8454]
#  [3 array(['laundry 0-25%', 'kitchen 0-25%', 'False'], dtype='<U13')
#   0.1162 0.4133 2.1808]]

# %%
# Filter by rhs=='No change - True'
top_k = 10

filtered_rules_individual = []
filtered_rules = []

rule_states = set({'attention_type_label other'})
# rule_states = set({})
rule_counter = {}
association_rules_np_rhs_buffer = []
for r in range(len(association_rules_np_rhs_sorted)):
    rhs = association_rules_np_rhs_sorted[r, 1][-1]
    if(rhs=='True' and association_rules_np_rhs_sorted[r, 0]>1):
        association_rules_np_rhs_buffer.append(association_rules_np_rhs_sorted[r])
association_rules_np_rhs_buffer = np.array(association_rules_np_rhs_buffer)

# print(association_rules_np_rhs_buffer[:top_k])
for rule in association_rules_np_rhs_buffer:
    
    # print(rule)
    if top_k < 1:
        break
    if rule[0] == 0 or rule[-1] < 1:
        continue
    print('mined rule: ', rule[1].tolist())
    
    # cek masing2 rule di rule[1], apakah ada duplikatnya atau enggak
    save = True
    for r in rule[1].tolist():
        # rule_states_vars = [i.split(' ')[0] for i in rule_states]
        rule_states_temp = rule_states | {r}
        # rule_states = rule_states | {r}
        # print(rule_states_temp)
        len_tmp = [i.split(' ')[0] for i in rule_states_temp]
        len_ori = [i.split(' ')[0] for i in rule_states]
        print(len_tmp, len_ori)
        print(len(len_tmp), len(len_ori))
        if (len(len_tmp) == len(len_ori)):
        # if (len(rule_states_temp) == len(rule_states)):
            print('Duplicate found', r)
            save = False
            continue
        
    if save != True:
        continue
    # rule_states = rule_states | 
    top_k = top_k - 1
    filtered_rules_individual.extend(rule[1].tolist())
    filtered_rules.append(rule[1].tolist())
    print('next search')
    print()
# filtered_rules_individual
filtered_rules
set(filtered_rules_individual) - {'True'}
# Out:
# mined rule:  ['attention_type_label other', 'True']
# ['attention_type_label'] ['attention_type_label']
# 1 1
# Duplicate found attention_type_label other
# ['attention_type_label', 'True'] ['attention_type_label']
# 2 1
# mined rule:  ['activation_type_label cam_2', 'weekday', 'True']
# ['activation_type_label', 'attention_type_label'] ['attention_type_label']
# 2 1
# ['attention_type_label', 'weekday'] ['attention_type_label']
# 2 1
# ['attention_type_label', 'True'] ['attention_type_label']
# 2 1
# next search
#
# mined rule:  ['weekday', 'attention_type_label other', 'True']
# ['attention_type_label', 'weekday'] ['attention_type_label']
# 2 1
# ['attention_type_label'] ['attention_type_label']
# 1 1
# Duplicate found attention_type_label other
# ['attention_type_label', 'True'] ['attention_type_label']
# 2 1
# mined rule:  ['activation_type_label cam_2', 'attention_type_label other', 'True']
# ['activation_type_label', 'attention_type_label'] ['attention_type_label']
# 2 1
# ['attention_type_label'] ['attention_type_label']
# 1 1
# Duplicate found attention_type_label other
# ['attention_type_label', 'True'] ['attention_type_label']
# 2 1
# mined rule:  ['global_intensity 25-50%', 'True']
# ['global_intensity', 'attention_type_label'] ['attention_type_label']
# 2 1
# ['attention_type_label', 'True'] ['attention_type_label']
# 2 1
# next search
#
# mined rule:  ['global_active_power 25-50%', 'True']
# ['global_active_power', 'attention_type_label'] ['attention_type_label']
# 2 1
# ['attention_type_label', 'True'] ['attention_type_label']
# 2 1
# next search
#
# mined rule:  ['global_intensity 0-25%', 'attention_type_label other', 'True']
# ['global_intensity', 'attention_type_label'] ['attention_type_label']
# 2 1
# ['attention_type_label'] ['attention_type_label']
# 1 1
# Duplicate found attention_type_label other
# ['attention_type_label', 'True'] ['attention_type_label']
# 2 1
# mined rule:  ['weekday', 'global_intensity 50-75%', 'True']
# ['attention_type_label', 'weekday'] ['attention_type_label']
# 2 1
# ['global_intensity', 'attention_type_label'] ['attention_type_label']
# 2 1
# ['attention_type_label', 'True'] ['attention_type_label']
# 2 1
# next search
#
# mined rule:  ['global_active_power 0-25%', 'attention_type_label other', 'True']
# ['attention_type_label', 'global_active_power'] ['attention_type_label']
# 2 1
# ['attention_type_label'] ['attention_type_label']
# 1 1
# Duplicate found attention_type_label other
# ['attention_type_label', 'True'] ['attention_type_label']
# 2 1
# mined rule:  ['weekday', 'global_active_power 50-75%', 'True']
# ['attention_type_label', 'weekday'] ['attention_type_label']
# 2 1
# ['global_active_power', 'attention_type_label'] ['attention_type_label']
# 2 1
# ['attention_type_label', 'True'] ['attention_type_label']
# 2 1
# next search
#
# mined rule:  ['voltage 75-100%', 'attention_type_label other', 'True']
# ['voltage', 'attention_type_label'] ['attention_type_label']
# 2 1
# ['attention_type_label'] ['attention_type_label']
# 1 1
# Duplicate found attention_type_label other
# ['attention_type_label', 'True'] ['attention_type_label']
# 2 1
# mined rule:  ['attention_type_label late_attention', 'True']
# ['attention_type_label', 'attention_type_label'] ['attention_type_label']
# 2 1
# ['attention_type_label', 'True'] ['attention_type_label']
# 2 1
# next search
#
# mined rule:  ['global_intensity 50-75%', 'weekday', 'global_active_power 50-75%', 'True']
# ['global_intensity', 'attention_type_label'] ['attention_type_label']
# 2 1
# ['attention_type_label', 'weekday'] ['attention_type_label']
# 2 1
# ['global_active_power', 'attention_type_label'] ['attention_type_label']
# 2 1
# ['attention_type_label', 'True'] ['attention_type_label']
# 2 1
# next search
#
# mined rule:  ['activation_type_label cam_2', 'global_active_power 25-50%', 'True']
# ['activation_type_label', 'attention_type_label'] ['attention_type_label']
# 2 1
# ['global_active_power', 'attention_type_label'] ['attention_type_label']
# 2 1
# ['attention_type_label', 'True'] ['attention_type_label']
# 2 1
# next search
#
# mined rule:  ['activation_type_label cam_2', 'global_intensity 25-50%', 'True']
# ['activation_type_label', 'attention_type_label'] ['attention_type_label']
# 2 1
# ['global_intensity', 'attention_type_label'] ['attention_type_label']
# 2 1
# ['attention_type_label', 'True'] ['attention_type_label']
# 2 1
# next search
#
# mined rule:  ['global_active_power 25-50%', 'global_intensity 25-50%', 'True']
# ['global_active_power', 'attention_type_label'] ['attention_type_label']
# 2 1
# ['global_intensity', 'attention_type_label'] ['attention_type_label']
# 2 1
# ['attention_type_label', 'True'] ['attention_type_label']
# 2 1
# next search
# {'activation_type_label cam_2',
#  'attention_type_label late_attention',
#  'global_active_power 25-50%',
#  'global_active_power 50-75%',
#  'global_intensity 25-50%',
#  'global_intensity 50-75%',
#  'weekday'}

# %% [markdown]
# OLD

# %%
# Filter by rhs=='No change - True'
top_k = 10

filtered_rules = []
rule_states = set({})
rule_counter = {}
association_rules_np_rhs_buffer = []
for r in range(len(association_rules_np_rhs_sorted)):
    rhs = association_rules_np_rhs_sorted[r, 1][-1]
    if(rhs=='True' and association_rules_np_rhs_sorted[r, 0]>1):
        association_rules_np_rhs_buffer.append(association_rules_np_rhs_sorted[r])
association_rules_np_rhs_buffer = np.array(association_rules_np_rhs_buffer)
# print(association_rules_np_rhs_buffer[:top_k])
for rule in association_rules_np_rhs_buffer:
    # print(rule)
    if top_k < 1:
        break
    if rule[0] == 0 or rule[-1] < 1:
        continue
    
    print('Mined rule: ',rule)
    # rule_states = rule_states | (set(rule[1].tolist()) - {'True'})
    break_inside = False
    for r in set(rule[1].tolist()) - {'True'}:
        if r not in rule_counter:
            if (len(rule_counter) == False):
                rule_counter[r] = 1
            else:
                rules = rule_counter.keys()
                # cek data duplikat ngga
                rule_counter_temp = rule_counter.copy()
                rule_counter_temp[r] = 1
                fr = set(rule_counter_temp.keys()) - {'True'}
                # fr
                frs = [r.split(" ")[0] for r in fr]
                print('copy rule', rule_counter_temp)
                # if (len(frs) == )
                print('frs ', frs, list(set(frs)))
                # if set is same, then no duplicate
                if len(frs) != len(list(set(frs))):
                    print('found duplicate')
                    break_inside = True
                    break
                # print()
                rule_counter[r] = 1
        else:
            rule_counter[r] += 1
    if break_inside:
        continue
    filtered_rules.extend(rule[1].tolist())
    
    top_k = top_k - 1
    print('Found! k=', top_k)
    print('Filtered rules: ', filtered_rules)
    print('Rules counter: ', rule_counter)
    print('rule:', rule[1].tolist())
    print('')

print('unique vars')
print(set(filtered_rules) - {'True'})
print(rule_states)
print('Rule counter:')
print(rule_counter)
# Out:
# Mined rule:  [2 array(['attention_type_label other', 'True'], dtype='<U26') 0.1714
#  0.513 1.0107]
# Found! k= 9
# Filtered rules:  ['attention_type_label other', 'True']
# Rules counter:  {'attention_type_label other': 1}
# rule: ['attention_type_label other', 'True']
#
# Mined rule:  [3 array(['activation_type_label cam_2', 'weekday', 'True'], dtype='<U27')
#  0.1644 0.4921 1.1226]
# copy rule {'attention_type_label other': 1, 'activation_type_label cam_2': 1}
# frs  ['activation_type_label', 'attention_type_label'] ['attention_type_label', 'activation_type_label']
# copy rule {'attention_type_label other': 1, 'activation_type_label cam_2': 1, 'weekday': 1}
# frs  ['activation_type_label', 'attention_type_label', 'weekday'] ['attention_type_label', 'activation_type_label', 'weekday']
# Found! k= 8
# Filtered rules:  ['attention_type_label other', 'True', 'activation_type_label cam_2', 'weekday', 'True']
# Rules counter:  {'attention_type_label other': 1, 'activation_type_label cam_2': 1, 'weekday': 1}
# rule: ['activation_type_label cam_2', 'weekday', 'True']
#
# Mined rule:  [3 array(['weekday', 'attention_type_label other', 'True'], dtype='<U26')
#  0.1296 0.3881 1.039]
# Found! k= 7
# Filtered rules:  ['attention_type_label other', 'True', 'activation_type_label cam_2', 'weekday', 'True', 'weekday', 'attention_type_label other', 'True']
# Rules counter:  {'attention_type_label other': 2, 'activation_type_label cam_2': 1, 'weekday': 2}
# rule: ['weekday', 'attention_type_label other', 'True']
#
# Mined rule:  [3 array(['activation_type_label cam_2', 'attention_type_label other',
#           'True'], dtype='<U27')
#  0.1268 0.3795 1.0824]
# Found! k= 6
# Filtered rules:  ['attention_type_label other', 'True', 'activation_type_label cam_2', 'weekday', 'True', 'weekday', 'attention_type_label other', 'True', 'activation_type_label cam_2', 'attention_type_label other', 'True']
# Rules counter:  {'attention_type_label other': 3, 'activation_type_label cam_2': 2, 'weekday': 2}
# rule: ['activation_type_label cam_2', 'attention_type_label other', 'True']
#
# Mined rule:  [3 array(['weekday', 'monday', 'True'], dtype='<U7') 0.0524 0.3664 1.4972]
# copy rule {'attention_type_label other': 3, 'activation_type_label cam_2': 2, 'weekday': 2, 'monday': 1}
# frs  ['activation_type_label', 'monday', 'attention_type_label', 'weekday'] ['attention_type_label', 'activation_type_label', 'monday', 'weekday']
# Found! k= 5
# Filtered rules:  ['attention_type_label other', 'True', 'activation_type_label cam_2', 'weekday', 'True', 'weekday', 'attention_type_label other', 'True', 'activation_type_label cam_2', 'attention_type_label other', 'True', 'weekday', 'monday', 'True']
# Rules counter:  {'attention_type_label other': 3, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 1}
# rule: ['weekday', 'monday', 'True']
#
# Mined rule:  [2 array(['monday', 'True'], dtype='<U6') 0.0524 0.3664 1.0968]
# Found! k= 4
# Filtered rules:  ['attention_type_label other', 'True', 'activation_type_label cam_2', 'weekday', 'True', 'weekday', 'attention_type_label other', 'True', 'activation_type_label cam_2', 'attention_type_label other', 'True', 'weekday', 'monday', 'True', 'monday', 'True']
# Rules counter:  {'attention_type_label other': 3, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2}
# rule: ['monday', 'True']
#
# Mined rule:  [2 array(['global_intensity 25-50%', 'True'], dtype='<U23') 0.1059 0.317
#  1.2181]
# copy rule {'attention_type_label other': 3, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1}
# frs  ['activation_type_label', 'global_intensity', 'monday', 'attention_type_label', 'weekday'] ['monday', 'weekday', 'attention_type_label', 'activation_type_label', 'global_intensity']
# Found! k= 3
# Filtered rules:  ['attention_type_label other', 'True', 'activation_type_label cam_2', 'weekday', 'True', 'weekday', 'attention_type_label other', 'True', 'activation_type_label cam_2', 'attention_type_label other', 'True', 'weekday', 'monday', 'True', 'monday', 'True', 'global_intensity 25-50%', 'True']
# Rules counter:  {'attention_type_label other': 3, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1}
# rule: ['global_intensity 25-50%', 'True']
#
# Mined rule:  [2 array(['global_active_power 25-50%', 'True'], dtype='<U26') 0.1059
#  0.317 1.184]
# copy rule {'attention_type_label other': 3, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1, 'global_active_power 25-50%': 1}
# frs  ['activation_type_label', 'global_intensity', 'monday', 'global_active_power', 'attention_type_label', 'weekday'] ['global_active_power', 'monday', 'weekday', 'attention_type_label', 'activation_type_label', 'global_intensity']
# Found! k= 2
# Filtered rules:  ['attention_type_label other', 'True', 'activation_type_label cam_2', 'weekday', 'True', 'weekday', 'attention_type_label other', 'True', 'activation_type_label cam_2', 'attention_type_label other', 'True', 'weekday', 'monday', 'True', 'monday', 'True', 'global_intensity 25-50%', 'True', 'global_active_power 25-50%', 'True']
# Rules counter:  {'attention_type_label other': 3, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1, 'global_active_power 25-50%': 1}
# rule: ['global_active_power 25-50%', 'True']
#
# Mined rule:  [3 array(['global_intensity 0-25%', 'attention_type_label other', 'True'],
#          dtype='<U26')
#  0.0541 0.3159 1.0049]
# copy rule {'attention_type_label other': 3, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1, 'global_active_power 25-50%': 1, 'global_intensity 0-25%': 1}
# frs  ['activation_type_label', 'global_intensity', 'monday', 'global_active_power', 'attention_type_label', 'weekday', 'global_intensity'] ['global_active_power', 'monday', 'weekday', 'attention_type_label', 'activation_type_label', 'global_intensity']
# found duplicate
# Mined rule:  [3 array(['weekday', 'global_intensity 50-75%', 'True'], dtype='<U23')
#  0.0648 0.3148 1.2863]
# copy rule {'attention_type_label other': 3, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1, 'global_active_power 25-50%': 1, 'global_intensity 50-75%': 1}
# frs  ['activation_type_label', 'global_intensity', 'global_intensity', 'monday', 'global_active_power', 'attention_type_label', 'weekday'] ['global_active_power', 'monday', 'weekday', 'attention_type_label', 'activation_type_label', 'global_intensity']
# found duplicate
# Mined rule:  [3
#  array(['global_active_power 0-25%', 'attention_type_label other', 'True'],
#        dtype='<U26')
#  0.0538 0.3141 1.022]
# copy rule {'attention_type_label other': 4, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1, 'global_active_power 25-50%': 1, 'global_active_power 0-25%': 1}
# frs  ['activation_type_label', 'global_intensity', 'monday', 'global_active_power', 'attention_type_label', 'weekday', 'global_active_power'] ['global_active_power', 'monday', 'weekday', 'attention_type_label', 'activation_type_label', 'global_intensity']
# found duplicate
# Mined rule:  [3 array(['weekday', 'global_active_power 50-75%', 'True'], dtype='<U26')
#  0.0647 0.3138 1.2824]
# copy rule {'attention_type_label other': 4, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1, 'global_active_power 25-50%': 1, 'global_active_power 50-75%': 1}
# frs  ['activation_type_label', 'global_intensity', 'monday', 'global_active_power', 'global_active_power', 'attention_type_label', 'weekday'] ['global_active_power', 'monday', 'weekday', 'attention_type_label', 'activation_type_label', 'global_intensity']
# found duplicate
# Mined rule:  [3 array(['voltage 75-100%', 'attention_type_label other', 'True'],
#          dtype='<U26')                                              0.0533
#  0.311 1.0308]
# copy rule {'attention_type_label other': 4, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1, 'global_active_power 25-50%': 1, 'voltage 75-100%': 1}
# frs  ['activation_type_label', 'global_intensity', 'voltage', 'monday', 'global_active_power', 'attention_type_label', 'weekday'] ['global_active_power', 'monday', 'weekday', 'attention_type_label', 'voltage', 'activation_type_label', 'global_intensity']
# Found! k= 1
# Filtered rules:  ['attention_type_label other', 'True', 'activation_type_label cam_2', 'weekday', 'True', 'weekday', 'attention_type_label other', 'True', 'activation_type_label cam_2', 'attention_type_label other', 'True', 'weekday', 'monday', 'True', 'monday', 'True', 'global_intensity 25-50%', 'True', 'global_active_power 25-50%', 'True', 'voltage 75-100%', 'attention_type_label other', 'True']
# Rules counter:  {'attention_type_label other': 5, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1, 'global_active_power 25-50%': 1, 'voltage 75-100%': 1}
# rule: ['voltage 75-100%', 'attention_type_label other', 'True']
#
# Mined rule:  [2 array(['attention_type_label late_attention', 'True'], dtype='<U35')
#  0.1022 0.3061 1.1219]
# copy rule {'attention_type_label other': 5, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1, 'global_active_power 25-50%': 1, 'voltage 75-100%': 1, 'attention_type_label late_attention': 1}
# frs  ['activation_type_label', 'attention_type_label', 'global_intensity', 'voltage', 'monday', 'global_active_power', 'attention_type_label', 'weekday'] ['global_active_power', 'monday', 'weekday', 'attention_type_label', 'voltage', 'activation_type_label', 'global_intensity']
# found duplicate
# Mined rule:  [4
#  array(['global_intensity 50-75%', 'weekday', 'global_active_power 50-75%',
#         'True'], dtype='<U26')
#  0.0625 0.3031 4.6781]
# copy rule {'attention_type_label other': 5, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1, 'global_active_power 25-50%': 1, 'voltage 75-100%': 1, 'global_intensity 50-75%': 1}
# frs  ['activation_type_label', 'global_intensity', 'global_intensity', 'voltage', 'monday', 'global_active_power', 'attention_type_label', 'weekday'] ['global_active_power', 'monday', 'weekday', 'attention_type_label', 'voltage', 'activation_type_label', 'global_intensity']
# found duplicate
# Mined rule:  [3 array(['activation_type_label cam_2', 'global_active_power 25-50%',
#           'True'], dtype='<U27')
#  0.0996 0.2981 1.2019]
# Found! k= 0
# Filtered rules:  ['attention_type_label other', 'True', 'activation_type_label cam_2', 'weekday', 'True', 'weekday', 'attention_type_label other', 'True', 'activation_type_label cam_2', 'attention_type_label other', 'True', 'weekday', 'monday', 'True', 'monday', 'True', 'global_intensity 25-50%', 'True', 'global_active_power 25-50%', 'True', 'voltage 75-100%', 'attention_type_label other', 'True', 'activation_type_label cam_2', 'global_active_power 25-50%', 'True']
# Rules counter:  {'attention_type_label other': 5, 'activation_type_label cam_2': 3, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1, 'global_active_power 25-50%': 2, 'voltage 75-100%': 1}
# rule: ['activation_type_label cam_2', 'global_active_power 25-50%', 'True']
#
# unique vars
# {'activation_type_label cam_2', 'global_intensity 25-50%', 'voltage 75-100%', 'monday', 'global_active_power 25-50%', 'attention_type_label other', 'weekday'}
# set()
# Rule counter:
# {'attention_type_label other': 5, 'activation_type_label cam_2': 3, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1, 'global_active_power 25-50%': 2, 'voltage 75-100%': 1}

# %%
# Out:
# ['other',
#  'global_intensity 0-25%',
#  'True',
#  'other',
#  'global_active_power 0-25%',
#  'True',
#  'other',
#  'climate_control 0-25%',
#  'True',
#  'other',
#  'True',
#  'cam_2',
#  'weekday',
#  'True',
#  'other',
#  'weekday',
#  'True',
#  'cam_2',
#  'other',
#  'True',
#  'monday',
#  'True',
#  'weekday',
#  'monday',
#  'True',
#  'other',
#  'voltage 75-100%',
#  'True']

# %%
dup = ['other', 'climate_control', 'monday', 'global_active_power', 'cam_2', 'global_intensity', 'weekday'] 
# ['other', 'global_active_power', 'monday', 'climate_control', 'cam_2', 'weekday', 'global_intensity']
len(set(dup)), len(dup) # (7, 8) duplicate
len(set(dup)), len(dup) # (7, 7) aman banget
# Out:
# (7, 7)

# %%
rule_counter = {'other': 1, 'climate_control 0-25%':1, 'monday':1, 'global_active_power 25-50%':1, 'cam_2':1, 'global_intensity 0-25%':1, 'weekday':1, 'global_active_power 0-25%':1}
list(rule_counter.keys())
# Out:
# ['other',
#  'climate_control 0-25%',
#  'monday',
#  'global_active_power 25-50%',
#  'cam_2',
#  'global_intensity 0-25%',
#  'weekday',
#  'global_active_power 0-25%']

# %%
fr = set(rule_counter.keys()) - {'True'}
# fr
frs = [r.split(" ")[0] for r in fr]

frs, list(set(frs))
# Out:
# (['other',
#   'climate_control',
#   'monday',
#   'global_active_power',
#   'cam_2',
#   'global_intensity',
#   'weekday',
#   'global_active_power'],
#  ['other',
#   'global_active_power',
#   'monday',
#   'climate_control',
#   'cam_2',
#   'weekday',
#   'global_intensity'])
