# %%
# from softcomputing_packages_bu import *
from apyori import apriori
import pandas as pd
import numpy as np
import copy
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Load dataset
hc_csv_raw = pd.read_csv('./datasets/2.0-discretized-v2-2-2-with-label-resampled-and-DLP-encoded.csv')
hc_csv_raw.head()
len(hc_csv_raw)
# Out:
# 41673

# %%
# Sampling (for Development)
n_sample = 30000
hc_csv = hc_csv_raw.sample(frac=1, random_state=42)
hc_csv = hc_csv.iloc[:n_sample]
hc_csv.head()
# Out:
#       global_active_power global_reactive_power    voltage global_intensity  \
# 35103              Medium             Very High  Very High           Medium
# 8049                  Low                  High  Very High              Low
# 22355                 Low                Medium     Medium              Low
# 21779              Medium             Very High     Medium           Medium
# 40302                 Low                Medium       High              Low
#
#          kitchen    laundry climate_control   other  weekend month_name  \
# 35103     Medium        Low            High    High     True      april
# 8049         Low        Low             Low  Medium    False      march
# 22355     Medium       High          Medium     Low    False  september
# 21779  Very High  Very High            High  Medium     True       june
# 40302       High       High          Medium  Medium    False      march
#
#       season_name   day_name        peak_label_pred attention_type_label  \
# 35103      spring     sunday       lower_than_usual                other
# 8049       spring    tuesday  no_significant_change                other
# 22355      autumn     friday           peak_warning                other
# 21779      summer   saturday           peak_warning      early_attention
# 40302      spring  wednesday       lower_than_usual                other
#
#       activation_type_label  peak_warning  no_significant_change  \
# 35103                 cam_2         False                  False
# 8049                  cam_2         False                   True
# 22355                 cam_2          True                  False
# 21779                 cam_1          True                  False
# 40302                 cam_2         False                  False
#
#        lower_than_usual
# 35103              True
# 8049              False
# 22355             False
# 21779             False
# 40302              True

# %%
# Preprocess dataset
for c in range(8):
    print(c)
    print("[%d] Column Preprocessing: %s" %(c, hc_csv.columns[c]))
    for r in range(hc_csv.shape[0]):
        if(hc_csv.iloc[r,c]=='Very High'):
            hc_csv.iloc[r,c] = hc_csv.columns[c]+' 75-100%'
        elif(hc_csv.iloc[r,c]=='High'):
            hc_csv.iloc[r,c] = hc_csv.columns[c]+' 50-75%'
        elif(hc_csv.iloc[r,c]=='Medium'):
            hc_csv.iloc[r,c] = hc_csv.columns[c]+' 25-50%'
        elif(hc_csv.iloc[r,c]=='Low'):
            # hc_csv.iloc[r,c] = '-1'
            hc_csv.iloc[r,c] = hc_csv.columns[c]+' 0-25%'
        else:
            hc_csv.iloc[r,c] = '-1'
print("Done.")
# Out:
# 0
# [0] Column Preprocessing: global_active_power
# 1
# [1] Column Preprocessing: global_reactive_power
# 2
# [2] Column Preprocessing: voltage
# 3
# [3] Column Preprocessing: global_intensity
# 4
# [4] Column Preprocessing: kitchen
# 5
# [5] Column Preprocessing: laundry
# 6
# [6] Column Preprocessing: climate_control
# 7
# [7] Column Preprocessing: other
# Done.

# %%
for c in hc_csv.columns:
  if c == 'weekend':
    for r in range(hc_csv.shape[0]):
      if hc_csv.iloc[r,list(hc_csv.columns).index('weekend')] == True:
        hc_csv.iloc[r,list(hc_csv.columns).index('weekend')] = 'weekend True'
      else:
        hc_csv.iloc[r,list(hc_csv.columns).index('weekend')] = 'weekend False'
      # break
# Out:
# C:\Users\sclab\AppData\Local\Temp\ipykernel_34172\2109154175.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'weekend True' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   hc_csv.iloc[r,list(hc_csv.columns).index('weekend')] = 'weekend True'

# %%
hc_csv.sample(5)
# Out:
#                global_active_power         global_reactive_power  \
# 30713    global_active_power 0-25%  global_reactive_power 50-75%
# 20838    global_active_power 0-25%   global_reactive_power 0-25%
# 29346    global_active_power 0-25%  global_reactive_power 25-50%
# 26135  global_active_power 75-100%   global_reactive_power 0-25%
# 30051    global_active_power 0-25%  global_reactive_power 25-50%
#
#                voltage          global_intensity          kitchen  \
# 30713   voltage 50-75%    global_intensity 0-25%   kitchen 50-75%
# 20838    voltage 0-25%    global_intensity 0-25%    kitchen 0-25%
# 29346    voltage 0-25%    global_intensity 0-25%    kitchen 0-25%
# 26135    voltage 0-25%  global_intensity 75-100%  kitchen 75-100%
# 30051  voltage 75-100%    global_intensity 0-25%   kitchen 50-75%
#
#               laundry         climate_control          other        weekend  \
# 30713  laundry 25-50%  climate_control 25-50%    other 0-25%  weekend False
# 20838   laundry 0-25%   climate_control 0-25%    other 0-25%   weekend True
# 29346  laundry 50-75%   climate_control 0-25%    other 0-25%  weekend False
# 26135   laundry 0-25%  climate_control 25-50%  other 75-100%  weekend False
# 30051  laundry 25-50%  climate_control 25-50%   other 25-50%   weekend True
#
#       month_name season_name  day_name   peak_label_pred attention_type_label  \
# 30713     august      summer    monday  lower_than_usual                other
# 20838     august      summer    sunday      peak_warning       late_attention
# 29346       july      summer    friday  lower_than_usual       late_attention
# 26135  september      autumn    friday      peak_warning       late_attention
# 30051      april      spring  saturday  lower_than_usual      early_attention
#
#       activation_type_label  peak_warning  no_significant_change  \
# 30713                 cam_2         False                  False
# 20838                 cam_2          True                  False
# 29346                 cam_2         False                  False
# 26135                 cam_1          True                  False
# 30051                 cam_2         False                  False
#
#        lower_than_usual
# 30713              True
# 20838             False
# 29346              True
# 26135             False
# 30051              True

# %%
# targets_only = ['peak_label_pred', 'no_significant_change', 'lower_than_usual']

# %%
hc_csv_temp = copy.copy(hc_csv)
hc_csv_temp.drop(columns=['peak_label_pred', 'no_significant_change', 'lower_than_usual', 'month_name', 'day_name'], inplace=True)

# %%
for i in range(len(hc_csv_temp)):
    if hc_csv_temp.iloc[i,-1] == True:
        hc_csv_temp.iloc[i,-1] = 'True'
    else:
        hc_csv_temp.iloc[i,-1] = 'False'
    # break
# Out:
# C:\Users\sclab\AppData\Local\Temp\ipykernel_34172\3489011138.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'False' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   hc_csv_temp.iloc[i,-1] = 'False'

# %%
# hc_csv_temp.iloc[:,12].name

for i in range(len(hc_csv_temp)):
    hc_csv_temp.iloc[i,9] = hc_csv_temp.iloc[:,9].name + " " + hc_csv_temp.iloc[i,9]
    
for i in range(len(hc_csv_temp)):
    hc_csv_temp.iloc[i,-3] = hc_csv_temp.iloc[:,-3].name + " " + hc_csv_temp.iloc[i,-3]

# %%
# Season
for i in range(len(hc_csv_temp)):
    hc_csv_temp.iloc[i,9] = hc_csv_temp.iloc[:,9].name + " " + hc_csv_temp.iloc[i,9]

# %%
hc_csv_temp.head(4)
# Out:
#               global_active_power          global_reactive_power  \
# 35103  global_active_power 25-50%  global_reactive_power 75-100%
# 8049    global_active_power 0-25%   global_reactive_power 50-75%
# 22355   global_active_power 0-25%   global_reactive_power 25-50%
# 21779  global_active_power 25-50%  global_reactive_power 75-100%
#
#                voltage         global_intensity          kitchen  \
# 35103  voltage 75-100%  global_intensity 25-50%   kitchen 25-50%
# 8049   voltage 75-100%   global_intensity 0-25%    kitchen 0-25%
# 22355   voltage 25-50%   global_intensity 0-25%   kitchen 25-50%
# 21779   voltage 25-50%  global_intensity 25-50%  kitchen 75-100%
#
#                laundry         climate_control         other        weekend  \
# 35103    laundry 0-25%  climate_control 50-75%  other 50-75%   weekend True
# 8049     laundry 0-25%   climate_control 0-25%  other 25-50%  weekend False
# 22355   laundry 50-75%  climate_control 25-50%   other 0-25%  weekend False
# 21779  laundry 75-100%  climate_control 50-75%  other 25-50%   weekend True
#
#               season_name                  attention_type_label  \
# 35103  season_name spring            attention_type_label other
# 8049   season_name spring            attention_type_label other
# 22355  season_name autumn            attention_type_label other
# 21779  season_name summer  attention_type_label early_attention
#
#              activation_type_label peak_warning
# 35103  activation_type_label cam_2        False
# 8049   activation_type_label cam_2        False
# 22355  activation_type_label cam_2         True
# 21779  activation_type_label cam_1         True

# %%
# hc_csv to list
hc_list = []
for r in range(hc_csv_temp.shape[0]):
    rule_buffer = []
    for c in range(len(hc_csv_temp.iloc[r])):
        if(hc_csv_temp.iloc[r,c]!='-1'):
            rule_buffer.append(hc_csv_temp.iloc[r,c])
    hc_list.append(rule_buffer)

# %%
hc_list
# Out:
# [['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 50-75%',
#   'weekend True',
#   'season_name spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekend True',
#   'season_name summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekend True',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekend True',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend True',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekend True',
#   'season_name winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 0-25%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend True',
#   'season_name spring',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend True',
#   'season_name winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend True',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 50-75%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekend True',
#   'season_name autumn',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekend True',
#   'season_name spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 75-100%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekend True',
#   'season_name spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 0-25%',
#   'weekend True',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend True',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend True',
#   'season_name summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekend True',
#   'season_name summer',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend True',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend True',
#   'season_name winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 25-50%',
#   'other 50-75%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 75-100%',
#   'weekend True',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 0-25%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekend True',
#   'season_name spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend True',
#   'season_name winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend True',
#   'season_name winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 0-25%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend True',
#   'season_name winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 0-25%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend True',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend True',
#   'season_name spring',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 50-75%',
#   'weekend True',
#   'season_name spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekend True',
#   'season_name winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 75-100%',
#   'other 0-25%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 50-75%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend True',
#   'season_name winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend True',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend True',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 75-100%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 50-75%',
#   'weekend True',
#   'season_name winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 0-25%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend True',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 50-75%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend True',
#   'season_name spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekend True',
#   'season_name spring',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 0-25%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend True',
#   'season_name winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend True',
#   'season_name autumn',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend True',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend True',
#   'season_name spring',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend True',
#   'season_name spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 0-25%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend True',
#   'season_name summer',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend True',
#   'season_name winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 0-25%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend True',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 75-100%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 75-100%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 50-75%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 50-75%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekend True',
#   'season_name winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekend True',
#   'season_name spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekend True',
#   'season_name winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 0-25%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekend True',
#   'season_name spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 75-100%',
#   'weekend True',
# ...
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend True',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 50-75%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend True',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 75-100%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend True',
#   'season_name spring',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 75-100%',
#   'other 0-25%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend True',
#   'season_name spring',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 0-25%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend True',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend True',
#   'season_name summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekend True',
#   'season_name summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend True',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 0-25%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend True',
#   'season_name autumn',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend False',
#   'season_name spring',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 50-75%',
#   'weekend True',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend False',
#   'season_name autumn',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend True',
#   'season_name spring',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label other',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend True',
#   'season_name spring',
#   'attention_type_label other',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend True',
#   'season_name summer',
#   'attention_type_label early_attention',
#   'activation_type_label cam_1',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label early_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 50-75%',
#   'weekend True',
#   'season_name summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_1',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekend False',
#   'season_name summer',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend False',
#   'season_name winter',
#   'attention_type_label late_attention',
#   'activation_type_label cam_2',
#   'False'],
#  ...]

# %%
# Association Rule Mining (ARM) (Caution: extremly slow)
association_rules = list(apriori(hc_list, min_support=0.05, min_confidence=0.2))
print('Rule Mined: %d' %(len(association_rules)))
# Out:
# Rule Mined: 3863

# %%
# Rules to numpy structure
association_rules_np = []
for r in range(len(association_rules)):
    rule_buffer = []
    association_rule = association_rules[r]
    items = [x for x in association_rule[0]]
    n_items = len(items)
    support = association_rule[1]
    confidence = association_rule[2][0][2]
    lift = association_rule[2][0][3]
    rule_buffer.append(n_items), rule_buffer.append(np.array(items)), rule_buffer.append(round(support, 4)), rule_buffer.append(round(confidence, 4)), rule_buffer.append(round(lift, 4))
    print(rule_buffer)
    association_rules_np.append(rule_buffer)
# Fix later
# association_rules_np = np.array(association_rules_np)
# print(association_rules_np)
# np.save('./association_rules', association_rules_np)
# Length, Rule, Support, Confidence, Lift
# Out:
# [1, array(['False'], dtype='<U5'), 0.6677, 0.6677, 1.0]
# [1, array(['True'], dtype='<U4'), 0.3323, 0.3323, 1.0]
# [1, array(['activation_type_label cam_1'], dtype='<U27'), 0.3932, 0.3932, 1.0]
# [1, array(['activation_type_label cam_2'], dtype='<U27'), 0.6068, 0.6068, 1.0]
# [1, array(['attention_type_label early_attention'], dtype='<U36'), 0.2196, 0.2196, 1.0]
# [1, array(['attention_type_label late_attention'], dtype='<U35'), 0.2728, 0.2728, 1.0]
# [1, array(['attention_type_label other'], dtype='<U26'), 0.5076, 0.5076, 1.0]
# [1, array(['climate_control 0-25%'], dtype='<U21'), 0.3145, 0.3145, 1.0]
# [1, array(['climate_control 25-50%'], dtype='<U22'), 0.2476, 0.2476, 1.0]
# [1, array(['climate_control 50-75%'], dtype='<U22'), 0.2261, 0.2261, 1.0]
# [1, array(['climate_control 75-100%'], dtype='<U23'), 0.2118, 0.2118, 1.0]
# [1, array(['global_active_power 0-25%'], dtype='<U25'), 0.3074, 0.3074, 1.0]
# [1, array(['global_active_power 25-50%'], dtype='<U26'), 0.2678, 0.2678, 1.0]
# [1, array(['global_active_power 50-75%'], dtype='<U26'), 0.2061, 0.2061, 1.0]
# [1, array(['global_active_power 75-100%'], dtype='<U27'), 0.2188, 0.2188, 1.0]
# [1, array(['global_intensity 0-25%'], dtype='<U22'), 0.3144, 0.3144, 1.0]
# [1, array(['global_intensity 25-50%'], dtype='<U23'), 0.2603, 0.2603, 1.0]
# [1, array(['global_intensity 50-75%'], dtype='<U23'), 0.2059, 0.2059, 1.0]
# [1, array(['global_intensity 75-100%'], dtype='<U24'), 0.2195, 0.2195, 1.0]
# [1, array(['global_reactive_power 0-25%'], dtype='<U27'), 0.2669, 0.2669, 1.0]
# [1, array(['global_reactive_power 25-50%'], dtype='<U28'), 0.2521, 0.2521, 1.0]
# [1, array(['global_reactive_power 50-75%'], dtype='<U28'), 0.2433, 0.2433, 1.0]
# [1, array(['global_reactive_power 75-100%'], dtype='<U29'), 0.2377, 0.2377, 1.0]
# [1, array(['kitchen 0-25%'], dtype='<U13'), 0.2811, 0.2811, 1.0]
# [1, array(['kitchen 25-50%'], dtype='<U14'), 0.2501, 0.2501, 1.0]
# [1, array(['kitchen 50-75%'], dtype='<U14'), 0.246, 0.246, 1.0]
# [1, array(['kitchen 75-100%'], dtype='<U15'), 0.2227, 0.2227, 1.0]
# [1, array(['laundry 0-25%'], dtype='<U13'), 0.2669, 0.2669, 1.0]
# [1, array(['laundry 25-50%'], dtype='<U14'), 0.251, 0.251, 1.0]
# [1, array(['laundry 50-75%'], dtype='<U14'), 0.2444, 0.2444, 1.0]
# [1, array(['laundry 75-100%'], dtype='<U15'), 0.2376, 0.2376, 1.0]
# [1, array(['other 0-25%'], dtype='<U11'), 0.2616, 0.2616, 1.0]
# [1, array(['other 25-50%'], dtype='<U12'), 0.29, 0.29, 1.0]
# [1, array(['other 50-75%'], dtype='<U12'), 0.2336, 0.2336, 1.0]
# [1, array(['other 75-100%'], dtype='<U13'), 0.2147, 0.2147, 1.0]
# [1, array(['season_name autumn'], dtype='<U18'), 0.2464, 0.2464, 1.0]
# [1, array(['season_name spring'], dtype='<U18'), 0.2417, 0.2417, 1.0]
# [1, array(['season_name summer'], dtype='<U18'), 0.2429, 0.2429, 1.0]
# [1, array(['season_name winter'], dtype='<U18'), 0.2691, 0.2691, 1.0]
# [1, array(['voltage 0-25%'], dtype='<U13'), 0.2375, 0.2375, 1.0]
# [1, array(['voltage 25-50%'], dtype='<U14'), 0.2273, 0.2273, 1.0]
# [1, array(['voltage 50-75%'], dtype='<U14'), 0.2335, 0.2335, 1.0]
# [1, array(['voltage 75-100%'], dtype='<U15'), 0.3017, 0.3017, 1.0]
# [1, array(['weekend False'], dtype='<U13'), 0.7117, 0.7117, 1.0]
# [1, array(['weekend True'], dtype='<U12'), 0.2883, 0.2883, 1.0]
# [2, array(['False', 'activation_type_label cam_1'], dtype='<U27'), 0.1242, 0.3159, 0.4731]
# [2, array(['activation_type_label cam_2', 'False'], dtype='<U27'), 0.5435, 0.5435, 1.0]
# [2, array(['False', 'attention_type_label early_attention'], dtype='<U36'), 0.104, 0.4737, 0.7095]
# [2, array(['False', 'attention_type_label late_attention'], dtype='<U35'), 0.1976, 0.2959, 1.0846]
# [2, array(['False', 'attention_type_label other'], dtype='<U26'), 0.3661, 0.3661, 1.0]
# [2, array(['False', 'climate_control 0-25%'], dtype='<U21'), 0.2717, 0.2717, 1.0]
# [2, array(['False', 'climate_control 25-50%'], dtype='<U22'), 0.1924, 0.2881, 1.1637]
# [2, array(['climate_control 50-75%', 'False'], dtype='<U22'), 0.1345, 0.2014, 0.8907]
# [2, array(['climate_control 75-100%', 'False'], dtype='<U23'), 0.0692, 0.3267, 0.4892]
# [2, array(['False', 'global_active_power 0-25%'], dtype='<U25'), 0.2636, 0.2636, 1.0]
# [2, array(['False', 'global_active_power 25-50%'], dtype='<U26'), 0.2391, 0.2391, 1.0]
# [2, array(['global_active_power 50-75%', 'False'], dtype='<U26'), 0.1076, 0.5223, 0.7822]
# [2, array(['False', 'global_active_power 75-100%'], dtype='<U27'), 0.0575, 0.2626, 0.3933]
# [2, array(['False', 'global_intensity 0-25%'], dtype='<U22'), 0.2733, 0.2733, 1.0]
# [2, array(['False', 'global_intensity 25-50%'], dtype='<U23'), 0.2294, 0.2294, 1.0]
# [2, array(['False', 'global_intensity 50-75%'], dtype='<U23'), 0.108, 0.5248, 0.7859]
# [2, array(['False', 'global_intensity 75-100%'], dtype='<U24'), 0.057, 0.2598, 0.3891]
# [2, array(['False', 'global_reactive_power 0-25%'], dtype='<U27'), 0.1983, 0.2969, 1.1125]
# [2, array(['False', 'global_reactive_power 25-50%'], dtype='<U28'), 0.178, 0.2666, 1.0576]
# [2, array(['False', 'global_reactive_power 50-75%'], dtype='<U28'), 0.1644, 0.2462, 1.0116]
# [2, array(['False', 'global_reactive_power 75-100%'], dtype='<U29'), 0.1271, 0.5347, 0.8008]
# [2, array(['False', 'kitchen 0-25%'], dtype='<U13'), 0.21, 0.21, 1.0]
# [2, array(['False', 'kitchen 25-50%'], dtype='<U14'), 0.1719, 0.2575, 1.0294]
# [2, array(['False', 'kitchen 50-75%'], dtype='<U14'), 0.176, 0.2635, 1.0711]
# [2, array(['False', 'kitchen 75-100%'], dtype='<U15'), 0.1098, 0.493, 0.7384]
# [2, array(['False', 'laundry 0-25%'], dtype='<U13'), 0.183, 0.2741, 1.0267]
# [2, array(['laundry 25-50%', 'False'], dtype='<U14'), 0.1799, 0.2695, 1.0736]
# [2, array(['laundry 50-75%', 'False'], dtype='<U14'), 0.1665, 0.2493, 1.0199]
# [2, array(['False', 'laundry 75-100%'], dtype='<U15'), 0.1383, 0.2072, 0.8718]
# [2, array(['False', 'other 0-25%'], dtype='<U11'), 0.189, 0.283, 1.0817]
# [2, array(['False', 'other 25-50%'], dtype='<U12'), 0.246, 0.246, 1.0]
# [2, array(['False', 'other 50-75%'], dtype='<U12'), 0.1585, 0.2373, 1.0159]
# [2, array(['False', 'other 75-100%'], dtype='<U13'), 0.0743, 0.3459, 0.518]
# [2, array(['season_name autumn', 'False'], dtype='<U18'), 0.1648, 0.2468, 1.0018]
# [2, array(['False', 'season_name spring'], dtype='<U18'), 0.1635, 0.2449, 1.0134]
# [2, array(['False', 'season_name summer'], dtype='<U18'), 0.1261, 0.519, 0.7773]
# [2, array(['False', 'season_name winter'], dtype='<U18'), 0.2133, 0.2133, 1.0]
# [2, array(['voltage 0-25%', 'False'], dtype='<U13'), 0.1014, 0.4271, 0.6396]
# [2, array(['False', 'voltage 25-50%'], dtype='<U14'), 0.1255, 0.5521, 0.8268]
# [2, array(['False', 'voltage 50-75%'], dtype='<U14'), 0.1673, 0.2505, 1.073]
# [2, array(['False', 'voltage 75-100%'], dtype='<U15'), 0.2735, 0.2735, 1.0]
# [2, array(['weekend False', 'False'], dtype='<U13'), 0.481, 0.481, 1.0]
# [2, array(['False', 'weekend True'], dtype='<U12'), 0.1867, 0.2796, 0.9697]
# [2, array(['True', 'activation_type_label cam_1'], dtype='<U27'), 0.269, 0.269, 1.0]
# [2, array(['attention_type_label early_attention', 'True'], dtype='<U36'), 0.1156, 0.3478, 1.5838]
# [2, array(['attention_type_label late_attention', 'True'], dtype='<U35'), 0.0752, 0.2264, 0.83]
# [2, array(['attention_type_label other', 'True'], dtype='<U26'), 0.1415, 0.4258, 0.8388]
# [2, array(['True', 'climate_control 25-50%'], dtype='<U22'), 0.0552, 0.223, 0.6711]
# [2, array(['climate_control 50-75%', 'True'], dtype='<U22'), 0.0916, 0.2758, 1.2196]
# [2, array(['climate_control 75-100%', 'True'], dtype='<U23'), 0.1426, 0.4293, 2.0265]
# [2, array(['global_active_power 50-75%', 'True'], dtype='<U26'), 0.0984, 0.2962, 1.4376]
# [2, array(['True', 'global_active_power 75-100%'], dtype='<U27'), 0.1613, 0.4856, 2.2192]
# [2, array(['True', 'global_intensity 50-75%'], dtype='<U23'), 0.0978, 0.2944, 1.4303]
# [2, array(['True', 'global_intensity 75-100%'], dtype='<U24'), 0.1625, 0.489, 2.2276]
# [2, array(['True', 'global_reactive_power 0-25%'], dtype='<U27'), 0.0686, 0.2066, 0.7739]
# [2, array(['global_reactive_power 25-50%', 'True'], dtype='<U28'), 0.0741, 0.2229, 0.8843]
# [2, array(['True', 'global_reactive_power 50-75%'], dtype='<U28'), 0.079, 0.2377, 0.9767]
# [2, array(['True', 'global_reactive_power 75-100%'], dtype='<U29'), 0.1106, 0.3329, 1.4004]
# [2, array(['True', 'kitchen 0-25%'], dtype='<U13'), 0.0711, 0.214, 0.7612]
# [2, array(['True', 'kitchen 25-50%'], dtype='<U14'), 0.0782, 0.2354, 0.9409]
# [2, array(['True', 'kitchen 50-75%'], dtype='<U14'), 0.0701, 0.2109, 0.8571]
# [2, array(['True', 'kitchen 75-100%'], dtype='<U15'), 0.1129, 0.3398, 1.5258]
# [2, array(['True', 'laundry 0-25%'], dtype='<U13'), 0.0839, 0.2526, 0.9463]
# [2, array(['laundry 25-50%', 'True'], dtype='<U14'), 0.0711, 0.2139, 0.8521]
# [2, array(['laundry 50-75%', 'True'], dtype='<U14'), 0.078, 0.2347, 0.96]
# [2, array(['True', 'laundry 75-100%'], dtype='<U15'), 0.0993, 0.2989, 1.2576]
# [2, array(['True', 'other 0-25%'], dtype='<U11'), 0.0727, 0.2187, 0.8359]
# [2, array(['other 50-75%', 'True'], dtype='<U12'), 0.0751, 0.2261, 0.968]
# [2, array(['True', 'other 75-100%'], dtype='<U13'), 0.1405, 0.4228, 1.9687]
# [2, array(['season_name autumn', 'True'], dtype='<U18'), 0.0816, 0.2455, 0.9964]
# [2, array(['True', 'season_name spring'], dtype='<U18'), 0.0781, 0.2352, 0.973]
# [2, array(['True', 'season_name summer'], dtype='<U18'), 0.1168, 0.3516, 1.4476]
# [2, array(['True', 'season_name winter'], dtype='<U18'), 0.0557, 0.2071, 0.6234]
# [2, array(['voltage 0-25%', 'True'], dtype='<U13'), 0.1361, 0.4095, 1.7243]
# [2, array(['True', 'voltage 25-50%'], dtype='<U14'), 0.1018, 0.3064, 1.3481]
# [2, array(['True', 'voltage 50-75%'], dtype='<U14'), 0.0662, 0.2835, 0.8533]
# [2, array(['weekend False', 'True'], dtype='<U13'), 0.2306, 0.2306, 1.0]
# [2, array(['True', 'weekend True'], dtype='<U12'), 0.1016, 0.3059, 1.0609]
# [2, array(['attention_type_label early_attention',
#        'activation_type_label cam_1'], dtype='<U36'), 0.1466, 0.3729, 1.698]
# [2, array(['attention_type_label late_attention',
#        'activation_type_label cam_1'], dtype='<U35'), 0.0896, 0.2278, 0.8351]
# [2, array(['attention_type_label other', 'activation_type_label cam_1'],
#       dtype='<U27'), 0.157, 0.3993, 0.7867]
# [2, array(['climate_control 50-75%', 'activation_type_label cam_1'],
#       dtype='<U27'), 0.1021, 0.2598, 1.1488]
# [2, array(['climate_control 75-100%', 'activation_type_label cam_1'],
#       dtype='<U27'), 0.2039, 0.2039, 1.0]
# [2, array(['global_active_power 50-75%', 'activation_type_label cam_1'],
#       dtype='<U27'), 0.1567, 0.3986, 1.9341]
# [2, array(['activation_type_label cam_1', 'global_active_power 75-100%'],
#       dtype='<U27'), 0.2121, 0.2121, 1.0]
# [2, array(['activation_type_label cam_1', 'global_intensity 50-75%'],
#       dtype='<U27'), 0.1566, 0.3982, 1.9344]
# [2, array(['activation_type_label cam_1', 'global_intensity 75-100%'],
#       dtype='<U27'), 0.2123, 0.2123, 1.0]
# [2, array(['activation_type_label cam_1', 'global_reactive_power 0-25%'],
#       dtype='<U27'), 0.086, 0.2187, 0.8195]
# [2, array(['global_reactive_power 25-50%', 'activation_type_label cam_1'],
#       dtype='<U28'), 0.0951, 0.2419, 0.9596]
# [2, array(['activation_type_label cam_1', 'global_reactive_power 50-75%'],
#       dtype='<U28'), 0.0905, 0.2303, 0.9463]
# [2, array(['activation_type_label cam_1', 'global_reactive_power 75-100%'],
#       dtype='<U29'), 0.1215, 0.3091, 1.3004]
# [2, array(['activation_type_label cam_1', 'kitchen 0-25%'], dtype='<U27'), 0.0874, 0.2223, 0.7907]
# [2, array(['activation_type_label cam_1', 'kitchen 25-50%'], dtype='<U27'), 0.0838, 0.2132, 0.8524]
# [2, array(['activation_type_label cam_1', 'kitchen 50-75%'], dtype='<U27'), 0.0887, 0.2256, 0.917]
# [2, array(['activation_type_label cam_1', 'kitchen 75-100%'], dtype='<U27'), 0.1332, 0.3389, 1.5217]
# [2, array(['activation_type_label cam_1', 'laundry 0-25%'], dtype='<U27'), 0.0864, 0.2198, 0.8233]
# [2, array(['laundry 25-50%', 'activation_type_label cam_1'], dtype='<U27'), 0.0991, 0.252, 1.0039]
# [2, array(['laundry 50-75%', 'activation_type_label cam_1'], dtype='<U27'), 0.0925, 0.2353, 0.9625]
# [2, array(['activation_type_label cam_1', 'laundry 75-100%'], dtype='<U27'), 0.1152, 0.293, 1.233]
# [2, array(['activation_type_label cam_1', 'other 25-50%'], dtype='<U27'), 0.0594, 0.2047, 0.5206]
# [2, array(['other 50-75%', 'activation_type_label cam_1'], dtype='<U27'), 0.1049, 0.2667, 1.1418]
# [2, array(['activation_type_label cam_1', 'other 75-100%'], dtype='<U27'), 0.1907, 0.485, 2.2584]
# [2, array(['season_name autumn', 'activation_type_label cam_1'], dtype='<U27'), 0.1067, 0.2713, 1.1012]
# [2, array(['activation_type_label cam_1', 'season_name spring'], dtype='<U27'), 0.1042, 0.265, 1.0967]
# [2, array(['activation_type_label cam_1', 'season_name summer'], dtype='<U27'), 0.0775, 0.3189, 0.8112]
# [2, array(['activation_type_label cam_1', 'season_name winter'], dtype='<U27'), 0.1048, 0.2666, 0.991]
# [2, array(['voltage 0-25%', 'activation_type_label cam_1'], dtype='<U27'), 0.1594, 0.4053, 1.7067]
# [2, array(['activation_type_label cam_1', 'voltage 25-50%'], dtype='<U27'), 0.112, 0.2849, 1.2534]
# [2, array(['activation_type_label cam_1', 'voltage 50-75%'], dtype='<U27'), 0.0732, 0.3133, 0.797]
# [2, array(['weekend False', 'activation_type_label cam_1'], dtype='<U27'), 0.2733, 0.2733, 1.0]
# [2, array(['activation_type_label cam_1', 'weekend True'], dtype='<U27'), 0.1198, 0.3048, 1.0571]
# [2, array(['activation_type_label cam_2',
#        'attention_type_label early_attention'], dtype='<U36'), 0.073, 0.3324, 0.5478]
# [2, array(['activation_type_label cam_2',
#        'attention_type_label late_attention'], dtype='<U35'), 0.1832, 0.302, 1.1069]
# [2, array(['activation_type_label cam_2', 'attention_type_label other'],
#       dtype='<U27'), 0.3506, 0.3506, 1.0]
# [2, array(['activation_type_label cam_2', 'climate_control 0-25%'],
#       dtype='<U27'), 0.2688, 0.2688, 1.0]
# [2, array(['activation_type_label cam_2', 'climate_control 25-50%'],
#       dtype='<U27'), 0.2061, 0.2061, 1.0]
# [2, array(['activation_type_label cam_2', 'climate_control 50-75%'],
#       dtype='<U27'), 0.124, 0.2043, 0.9036]
# [2, array(['activation_type_label cam_2', 'global_active_power 0-25%'],
#       dtype='<U27'), 0.3028, 0.3028, 1.0]
# [2, array(['activation_type_label cam_2', 'global_active_power 25-50%'],
#       dtype='<U27'), 0.248, 0.248, 1.0]
# [2, array(['activation_type_label cam_2', 'global_intensity 0-25%'],
#       dtype='<U27'), 0.3099, 0.3099, 1.0]
# [2, array(['activation_type_label cam_2', 'global_intensity 25-50%'],
#       dtype='<U27'), 0.2404, 0.2404, 1.0]
# [2, array(['activation_type_label cam_2', 'global_reactive_power 0-25%'],
#       dtype='<U27'), 0.1809, 0.2981, 1.1169]
# [2, array(['activation_type_label cam_2', 'global_reactive_power 25-50%'],
#       dtype='<U28'), 0.157, 0.2587, 1.0262]
# [2, array(['activation_type_label cam_2', 'global_reactive_power 50-75%'],
#       dtype='<U28'), 0.1528, 0.2518, 1.0348]
# [2, array(['activation_type_label cam_2', 'global_reactive_power 75-100%'],
#       dtype='<U29'), 0.1162, 0.4887, 0.8053]
# [2, array(['activation_type_label cam_2', 'kitchen 0-25%'], dtype='<U27'), 0.1937, 0.3193, 1.1356]
# [2, array(['activation_type_label cam_2', 'kitchen 25-50%'], dtype='<U27'), 0.1663, 0.274, 1.0956]
# [2, array(['activation_type_label cam_2', 'kitchen 50-75%'], dtype='<U27'), 0.1573, 0.2593, 1.0538]
# [2, array(['activation_type_label cam_2', 'kitchen 75-100%'], dtype='<U27'), 0.0895, 0.4017, 0.662]
# [2, array(['activation_type_label cam_2', 'laundry 0-25%'], dtype='<U27'), 0.1805, 0.2975, 1.1145]
# [2, array(['laundry 25-50%', 'activation_type_label cam_2'], dtype='<U27'), 0.1519, 0.2504, 0.9975]
# [2, array(['activation_type_label cam_2', 'laundry 50-75%'], dtype='<U27'), 0.1519, 0.2504, 1.0243]
# [2, array(['activation_type_label cam_2', 'laundry 75-100%'], dtype='<U27'), 0.1224, 0.2018, 0.849]
# [2, array(['activation_type_label cam_2', 'other 0-25%'], dtype='<U27'), 0.2234, 0.2234, 1.0]
# [2, array(['activation_type_label cam_2', 'other 25-50%'], dtype='<U27'), 0.2307, 0.2307, 1.0]
# [2, array(['activation_type_label cam_2', 'other 50-75%'], dtype='<U27'), 0.1287, 0.2121, 0.9081]
# [2, array(['activation_type_label cam_2', 'season_name autumn'], dtype='<U27'), 0.1397, 0.2302, 0.9344]
# [2, array(['activation_type_label cam_2', 'season_name spring'], dtype='<U27'), 0.1375, 0.2265, 0.9374]
# [2, array(['activation_type_label cam_2', 'season_name summer'], dtype='<U27'), 0.1654, 0.2726, 1.1223]
# [2, array(['activation_type_label cam_2', 'season_name winter'], dtype='<U27'), 0.1642, 0.2706, 1.0058]
# [2, array(['activation_type_label cam_2', 'voltage 0-25%'], dtype='<U27'), 0.0781, 0.329, 0.5421]
# [2, array(['activation_type_label cam_2', 'voltage 25-50%'], dtype='<U27'), 0.1153, 0.5072, 0.8358]
# [2, array(['activation_type_label cam_2', 'voltage 50-75%'], dtype='<U27'), 0.1603, 0.2642, 1.1315]
# [2, array(['activation_type_label cam_2', 'voltage 75-100%'], dtype='<U27'), 0.2531, 0.2531, 1.0]
# [2, array(['weekend False', 'activation_type_label cam_2'], dtype='<U27'), 0.4383, 0.4383, 1.0]
# [2, array(['activation_type_label cam_2', 'weekend True'], dtype='<U27'), 0.1685, 0.2777, 0.963]
# [2, array(['climate_control 50-75%', 'attention_type_label early_attention'],
#       dtype='<U36'), 0.0532, 0.2424, 1.072]
# [2, array(['climate_control 75-100%', 'attention_type_label early_attention'],
#       dtype='<U36'), 0.0876, 0.3988, 1.8824]
# [2, array(['global_active_power 50-75%',
#        'attention_type_label early_attention'], dtype='<U36'), 0.0655, 0.2983, 1.4474]
# [2, array(['attention_type_label early_attention',
#        'global_active_power 75-100%'], dtype='<U36'), 0.0821, 0.3737, 1.708]
# [2, array(['attention_type_label early_attention', 'global_intensity 50-75%'],
#       dtype='<U36'), 0.0653, 0.2974, 1.4444]
# [2, array(['attention_type_label early_attention', 'global_intensity 75-100%'],
#       dtype='<U36'), 0.0821, 0.374, 1.7039]
# [2, array(['attention_type_label early_attention',
#        'global_reactive_power 0-25%'], dtype='<U36'), 0.0527, 0.2398, 0.8986]
# [2, array(['global_reactive_power 25-50%',
#        'attention_type_label early_attention'], dtype='<U36'), 0.0538, 0.2448, 0.9713]
# [2, array(['attention_type_label early_attention',
#        'global_reactive_power 50-75%'], dtype='<U36'), 0.0512, 0.2333, 0.9588]
# [2, array(['attention_type_label early_attention',
#        'global_reactive_power 75-100%'], dtype='<U36'), 0.0619, 0.282, 1.1865]
# [2, array(['attention_type_label early_attention', 'kitchen 0-25%'],
#       dtype='<U36'), 0.0501, 0.228, 0.811]
# [2, array(['attention_type_label early_attention', 'kitchen 25-50%'],
#       dtype='<U36'), 0.0522, 0.2379, 0.9509]
# [2, array(['attention_type_label early_attention', 'kitchen 50-75%'],
#       dtype='<U36'), 0.0545, 0.248, 1.0081]
# [2, array(['attention_type_label early_attention', 'kitchen 75-100%'],
#       dtype='<U36'), 0.0628, 0.2861, 1.2848]
# [2, array(['laundry 25-50%', 'attention_type_label early_attention'],
#       dtype='<U36'), 0.0574, 0.2615, 1.042]
# [2, array(['laundry 50-75%', 'attention_type_label early_attention'],
#       dtype='<U36'), 0.0516, 0.2351, 0.9619]
# [2, array(['attention_type_label early_attention', 'laundry 75-100%'],
#       dtype='<U36'), 0.0609, 0.2775, 1.1677]
# [2, array(['attention_type_label early_attention', 'other 25-50%'],
#       dtype='<U36'), 0.054, 0.2457, 0.8473]
# [2, array(['other 50-75%', 'attention_type_label early_attention'],
#       dtype='<U36'), 0.0563, 0.2562, 1.0968]
# [2, array(['attention_type_label early_attention', 'other 75-100%'],
#       dtype='<U36'), 0.065, 0.2961, 1.3791]
# [2, array(['season_name autumn', 'attention_type_label early_attention'],
#       dtype='<U36'), 0.0522, 0.2379, 0.9655]
# [2, array(['attention_type_label early_attention', 'season_name spring'],
#       dtype='<U36'), 0.0652, 0.2968, 1.2279]
# [2, array(['attention_type_label early_attention', 'season_name winter'],
#       dtype='<U36'), 0.0537, 0.2444, 0.9083]
# [2, array(['voltage 0-25%', 'attention_type_label early_attention'],
#       dtype='<U36'), 0.0726, 0.3304, 1.3914]
# [2, array(['attention_type_label early_attention', 'voltage 25-50%'],
#       dtype='<U36'), 0.0524, 0.2385, 1.0493]
# [2, array(['weekend False', 'attention_type_label early_attention'],
#       dtype='<U36'), 0.1434, 0.6529, 0.9174]
# [2, array(['attention_type_label early_attention', 'weekend True'],
#       dtype='<U36'), 0.0762, 0.3471, 1.204]
# [2, array(['attention_type_label late_attention', 'climate_control 0-25%'],
#       dtype='<U35'), 0.0889, 0.326, 1.0367]
# [2, array(['attention_type_label late_attention', 'climate_control 25-50%'],
#       dtype='<U35'), 0.0728, 0.2667, 1.0774]
# [2, array(['climate_control 50-75%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0607, 0.2225, 0.984]
# [2, array(['climate_control 75-100%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0504, 0.2379, 0.8722]
# [2, array(['attention_type_label late_attention', 'global_active_power 0-25%'],
#       dtype='<U35'), 0.0906, 0.3322, 1.0809]
# [2, array(['global_active_power 25-50%',
#        'attention_type_label late_attention'], dtype='<U35'), 0.0817, 0.2996, 1.1189]
# [2, array(['attention_type_label late_attention',
#        'global_active_power 75-100%'], dtype='<U35'), 0.0537, 0.2454, 0.8997]
# [2, array(['attention_type_label late_attention', 'global_intensity 0-25%'],
#       dtype='<U35'), 0.0918, 0.3365, 1.0704]
# [2, array(['global_intensity 25-50%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.08, 0.2933, 1.1267]
# [2, array(['attention_type_label late_attention', 'global_intensity 75-100%'],
#       dtype='<U35'), 0.0538, 0.245, 0.8979]
# [2, array(['attention_type_label late_attention',
#        'global_reactive_power 0-25%'], dtype='<U35'), 0.0738, 0.2704, 1.0131]
# [2, array(['global_reactive_power 25-50%',
#        'attention_type_label late_attention'], dtype='<U35'), 0.0692, 0.2535, 1.0059]
# [2, array(['attention_type_label late_attention',
#        'global_reactive_power 50-75%'], dtype='<U35'), 0.0686, 0.2516, 1.0339]
# [2, array(['attention_type_label late_attention',
#        'global_reactive_power 75-100%'], dtype='<U35'), 0.0612, 0.2245, 0.9443]
# [2, array(['attention_type_label late_attention', 'kitchen 0-25%'],
#       dtype='<U35'), 0.0815, 0.2988, 1.0627]
# [2, array(['attention_type_label late_attention', 'kitchen 25-50%'],
#       dtype='<U35'), 0.0663, 0.243, 0.9716]
# [2, array(['attention_type_label late_attention', 'kitchen 50-75%'],
#       dtype='<U35'), 0.0672, 0.2463, 1.0012]
# [2, array(['attention_type_label late_attention', 'kitchen 75-100%'],
#       dtype='<U35'), 0.0578, 0.2119, 0.9514]
# [2, array(['attention_type_label late_attention', 'laundry 0-25%'],
#       dtype='<U35'), 0.0726, 0.2661, 0.997]
# [2, array(['laundry 25-50%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0669, 0.2452, 0.977]
# [2, array(['laundry 50-75%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0704, 0.2579, 1.0553]
# [2, array(['attention_type_label late_attention', 'laundry 75-100%'],
#       dtype='<U35'), 0.0629, 0.2307, 0.9708]
# [2, array(['attention_type_label late_attention', 'other 0-25%'], dtype='<U35'), 0.0749, 0.2746, 1.0494]
# [2, array(['attention_type_label late_attention', 'other 25-50%'],
#       dtype='<U35'), 0.0808, 0.2961, 1.0208]
# [2, array(['other 50-75%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0622, 0.228, 0.9761]
# [2, array(['attention_type_label late_attention', 'other 75-100%'],
#       dtype='<U35'), 0.0549, 0.2014, 0.9378]
# [2, array(['season_name autumn', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0671, 0.2458, 0.9979]
# [2, array(['attention_type_label late_attention', 'season_name spring'],
#       dtype='<U35'), 0.0617, 0.2262, 0.9359]
# [2, array(['attention_type_label late_attention', 'season_name summer'],
#       dtype='<U35'), 0.0681, 0.2495, 1.0272]
# [2, array(['attention_type_label late_attention', 'season_name winter'],
#       dtype='<U35'), 0.076, 0.2785, 1.0349]
# [2, array(['voltage 0-25%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0596, 0.2185, 0.9199]
# [2, array(['attention_type_label late_attention', 'voltage 25-50%'],
#       dtype='<U35'), 0.0664, 0.2433, 1.0705]
# [2, array(['attention_type_label late_attention', 'voltage 50-75%'],
#       dtype='<U35'), 0.0665, 0.2438, 1.044]
# [2, array(['voltage 75-100%', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.0803, 0.2945, 0.976]
# [2, array(['weekend False', 'attention_type_label late_attention'],
#       dtype='<U35'), 0.1948, 0.714, 1.0032]
# [2, array(['attention_type_label late_attention', 'weekend True'],
#       dtype='<U35'), 0.078, 0.286, 0.9921]
# [2, array(['attention_type_label other', 'climate_control 0-25%'],
#       dtype='<U26'), 0.1858, 0.3661, 1.1642]
# [2, array(['attention_type_label other', 'climate_control 25-50%'],
#       dtype='<U26'), 0.1357, 0.2673, 1.0799]
# [2, array(['climate_control 50-75%', 'attention_type_label other'],
#       dtype='<U26'), 0.1122, 0.221, 0.9775]
# [2, array(['climate_control 75-100%', 'attention_type_label other'],
#       dtype='<U26'), 0.0739, 0.3487, 0.687]
# [2, array(['attention_type_label other', 'global_active_power 0-25%'],
#       dtype='<U26'), 0.179, 0.3527, 1.1475]
# [2, array(['global_active_power 25-50%', 'attention_type_label other'],
#       dtype='<U26'), 0.1517, 0.2989, 1.1161]
# [2, array(['global_active_power 50-75%', 'attention_type_label other'],
#       dtype='<U26'), 0.0938, 0.4554, 0.8971]
# [2, array(['attention_type_label other', 'global_active_power 75-100%'],
#       dtype='<U27'), 0.083, 0.3795, 0.7476]
# [2, array(['attention_type_label other', 'global_intensity 0-25%'],
#       dtype='<U26'), 0.184, 0.3626, 1.1533]
# [2, array(['global_intensity 25-50%', 'attention_type_label other'],
#       dtype='<U26'), 0.1466, 0.2889, 1.1099]
# [2, array(['attention_type_label other', 'global_intensity 50-75%'],
#       dtype='<U26'), 0.0933, 0.4534, 0.8932]
# [2, array(['attention_type_label other', 'global_intensity 75-100%'],
#       dtype='<U26'), 0.0836, 0.3809, 0.7503]
# [2, array(['attention_type_label other', 'global_reactive_power 0-25%'],
#       dtype='<U27'), 0.1405, 0.2767, 1.0368]
# [2, array(['global_reactive_power 25-50%', 'attention_type_label other'],
#       dtype='<U28'), 0.1291, 0.2544, 1.0093]
# [2, array(['attention_type_label other', 'global_reactive_power 50-75%'],
#       dtype='<U28'), 0.1235, 0.2432, 0.9996]
# [2, array(['attention_type_label other', 'global_reactive_power 75-100%'],
#       dtype='<U29'), 0.1145, 0.2256, 0.9493]
# [2, array(['attention_type_label other', 'kitchen 0-25%'], dtype='<U26'), 0.1496, 0.2947, 1.0481]
# [2, array(['attention_type_label other', 'kitchen 25-50%'], dtype='<U26'), 0.1316, 0.2593, 1.0365]
# [2, array(['attention_type_label other', 'kitchen 50-75%'], dtype='<U26'), 0.1244, 0.245, 0.9958]
# [2, array(['attention_type_label other', 'kitchen 75-100%'], dtype='<U26'), 0.1021, 0.2011, 0.9029]
# [2, array(['attention_type_label other', 'laundry 0-25%'], dtype='<U26'), 0.1447, 0.2851, 1.0682]
# [2, array(['laundry 25-50%', 'attention_type_label other'], dtype='<U26'), 0.1267, 0.2495, 0.9942]
# [2, array(['laundry 50-75%', 'attention_type_label other'], dtype='<U26'), 0.1224, 0.2412, 0.9868]
# [2, array(['attention_type_label other', 'laundry 75-100%'], dtype='<U26'), 0.1138, 0.2241, 0.9432]
# [2, array(['attention_type_label other', 'other 0-25%'], dtype='<U26'), 0.1424, 0.2805, 1.0722]
# [2, array(['attention_type_label other', 'other 25-50%'], dtype='<U26'), 0.1553, 0.3059, 1.0549]
# [2, array(['other 50-75%', 'attention_type_label other'], dtype='<U26'), 0.1151, 0.2268, 0.971]
# [2, array(['attention_type_label other', 'other 75-100%'], dtype='<U26'), 0.0948, 0.4413, 0.8694]
# [2, array(['season_name autumn', 'attention_type_label other'], dtype='<U26'), 0.1271, 0.2503, 1.0161]
# [2, array(['attention_type_label other', 'season_name spring'], dtype='<U26'), 0.1148, 0.2262, 0.9358]
# [2, array(['attention_type_label other', 'season_name summer'], dtype='<U26'), 0.1263, 0.2488, 1.0244]
# [2, array(['attention_type_label other', 'season_name winter'], dtype='<U26'), 0.1394, 0.2747, 1.0209]
# [2, array(['voltage 0-25%', 'attention_type_label other'], dtype='<U26'), 0.1053, 0.2075, 0.8737]
# [2, array(['attention_type_label other', 'voltage 25-50%'], dtype='<U26'), 0.1085, 0.2138, 0.9408]
# [2, array(['attention_type_label other', 'voltage 50-75%'], dtype='<U26'), 0.1221, 0.2405, 1.0302]
# [2, array(['voltage 75-100%', 'attention_type_label other'], dtype='<U26'), 0.1716, 0.3381, 1.1206]
# [2, array(['weekend False', 'attention_type_label other'], dtype='<U26'), 0.3735, 0.3735, 1.0]
# [2, array(['attention_type_label other', 'weekend True'], dtype='<U26'), 0.1341, 0.2641, 0.916]
# [2, array(['global_active_power 0-25%', 'climate_control 0-25%'], dtype='<U25'), 0.1662, 0.5286, 1.7198]
# [2, array(['global_active_power 25-50%', 'climate_control 0-25%'],
#       dtype='<U26'), 0.0965, 0.3069, 1.146]
# [2, array(['global_intensity 0-25%', 'climate_control 0-25%'], dtype='<U22'), 0.1683, 0.5353, 1.7028]
# [2, array(['global_intensity 25-50%', 'climate_control 0-25%'], dtype='<U23'), 0.0942, 0.2997, 1.1514]
# [2, array(['global_reactive_power 0-25%', 'climate_control 0-25%'],
#       dtype='<U27'), 0.1075, 0.342, 1.2812]
# [2, array(['global_reactive_power 25-50%', 'climate_control 0-25%'],
#       dtype='<U28'), 0.0836, 0.2657, 1.0542]
# [2, array(['global_reactive_power 50-75%', 'climate_control 0-25%'],
#       dtype='<U28'), 0.0718, 0.2284, 0.9387]
# [2, array(['global_reactive_power 75-100%', 'climate_control 0-25%'],
#       dtype='<U29'), 0.0515, 0.2168, 0.6894]
# [2, array(['kitchen 0-25%', 'climate_control 0-25%'], dtype='<U21'), 0.2085, 0.2085, 1.0]
# [2, array(['kitchen 25-50%', 'climate_control 0-25%'], dtype='<U21'), 0.094, 0.299, 1.1955]
# [2, array(['laundry 0-25%', 'climate_control 0-25%'], dtype='<U21'), 0.1514, 0.4816, 1.804]
# [2, array(['laundry 50-75%', 'climate_control 0-25%'], dtype='<U21'), 0.0663, 0.2108, 0.8625]
# [2, array(['laundry 75-100%', 'climate_control 0-25%'], dtype='<U21'), 0.0574, 0.2417, 0.7686]
# [2, array(['other 0-25%', 'climate_control 0-25%'], dtype='<U21'), 0.0859, 0.2733, 1.0445]
# [2, array(['other 25-50%', 'climate_control 0-25%'], dtype='<U21'), 0.1121, 0.3565, 1.2291]
# [2, array(['other 50-75%', 'climate_control 0-25%'], dtype='<U21'), 0.0714, 0.2272, 0.9724]
# [2, array(['season_name autumn', 'climate_control 0-25%'], dtype='<U21'), 0.0636, 0.2024, 0.8213]
# [2, array(['season_name spring', 'climate_control 0-25%'], dtype='<U21'), 0.0634, 0.2016, 0.8343]
# [2, array(['season_name summer', 'climate_control 0-25%'], dtype='<U21'), 0.0594, 0.2444, 0.7772]
# [2, array(['season_name winter', 'climate_control 0-25%'], dtype='<U21'), 0.1281, 0.4073, 1.5136]
# [2, array(['voltage 0-25%', 'climate_control 0-25%'], dtype='<U21'), 0.0738, 0.2347, 0.9881]
# [2, array(['voltage 50-75%', 'climate_control 0-25%'], dtype='<U21'), 0.0657, 0.2088, 0.8943]
# [2, array(['voltage 75-100%', 'climate_control 0-25%'], dtype='<U21'), 0.1254, 0.3988, 1.3216]
# [2, array(['weekend False', 'climate_control 0-25%'], dtype='<U21'), 0.2305, 0.2305, 1.0]
# [2, array(['weekend True', 'climate_control 0-25%'], dtype='<U21'), 0.084, 0.267, 0.9261]
# [2, array(['climate_control 25-50%', 'global_active_power 0-25%'],
#       dtype='<U25'), 0.1113, 0.4496, 1.4627]
# [2, array(['global_active_power 25-50%', 'climate_control 25-50%'],
#       dtype='<U26'), 0.0933, 0.377, 1.408]
# [2, array(['climate_control 25-50%', 'global_intensity 0-25%'], dtype='<U22'), 0.1137, 0.4591, 1.4605]
# [2, array(['global_intensity 25-50%', 'climate_control 25-50%'], dtype='<U23'), 0.0911, 0.368, 1.4139]
# [2, array(['climate_control 25-50%', 'global_reactive_power 0-25%'],
#       dtype='<U27'), 0.0636, 0.2569, 0.9625]
# [2, array(['global_reactive_power 25-50%', 'climate_control 25-50%'],
#       dtype='<U28'), 0.0616, 0.2488, 0.9871]
# [2, array(['climate_control 25-50%', 'global_reactive_power 50-75%'],
#       dtype='<U28'), 0.0641, 0.2589, 1.0641]
# [2, array(['climate_control 25-50%', 'global_reactive_power 75-100%'],
#       dtype='<U29'), 0.0583, 0.2354, 0.9901]
# [2, array(['climate_control 25-50%', 'kitchen 25-50%'], dtype='<U22'), 0.0724, 0.2924, 1.1692]
# [2, array(['climate_control 25-50%', 'kitchen 50-75%'], dtype='<U22'), 0.1364, 0.5508, 2.2388]
# [2, array(['laundry 25-50%', 'climate_control 25-50%'], dtype='<U22'), 0.0965, 0.3897, 1.5524]
# [2, array(['laundry 50-75%', 'climate_control 25-50%'], dtype='<U22'), 0.0576, 0.2327, 0.9519]
# [2, array(['climate_control 25-50%', 'laundry 75-100%'], dtype='<U22'), 0.0588, 0.2375, 0.9995]
# [2, array(['climate_control 25-50%', 'other 0-25%'], dtype='<U22'), 0.0864, 0.3489, 1.3334]
# [2, array(['climate_control 25-50%', 'other 25-50%'], dtype='<U22'), 0.0777, 0.3139, 1.0821]
# [2, array(['other 50-75%', 'climate_control 25-50%'], dtype='<U22'), 0.0501, 0.2025, 0.8669]
# [2, array(['season_name autumn', 'climate_control 25-50%'], dtype='<U22'), 0.063, 0.2545, 1.0329]
# [2, array(['climate_control 25-50%', 'season_name spring'], dtype='<U22'), 0.0677, 0.2735, 1.1316]
# [2, array(['climate_control 25-50%', 'season_name summer'], dtype='<U22'), 0.0725, 0.2927, 1.2051]
# [2, array(['climate_control 25-50%', 'voltage 25-50%'], dtype='<U22'), 0.057, 0.2304, 1.0137]
# [2, array(['climate_control 25-50%', 'voltage 50-75%'], dtype='<U22'), 0.0707, 0.2854, 1.2225]
# [2, array(['voltage 75-100%', 'climate_control 25-50%'], dtype='<U22'), 0.0938, 0.3788, 1.2553]
# [2, array(['weekend False', 'climate_control 25-50%'], dtype='<U22'), 0.1743, 0.7039, 0.9891]
# [2, array(['climate_control 25-50%', 'weekend True'], dtype='<U22'), 0.0733, 0.2961, 1.0269]
# [2, array(['climate_control 50-75%', 'global_active_power 25-50%'],
#       dtype='<U26'), 0.0779, 0.3446, 1.2871]
# [2, array(['climate_control 50-75%', 'global_active_power 50-75%'],
#       dtype='<U26'), 0.0628, 0.2777, 1.3477]
# [2, array(['climate_control 50-75%', 'global_active_power 75-100%'],
#       dtype='<U27'), 0.0556, 0.2457, 1.1231]
# [2, array(['climate_control 50-75%', 'global_intensity 25-50%'], dtype='<U23'), 0.0749, 0.3314, 1.2732]
# [2, array(['climate_control 50-75%', 'global_intensity 50-75%'], dtype='<U23'), 0.0621, 0.2746, 1.334]
# [2, array(['climate_control 50-75%', 'global_intensity 75-100%'], dtype='<U24'), 0.0567, 0.2509, 1.143]
# [2, array(['climate_control 50-75%', 'global_reactive_power 25-50%'],
#       dtype='<U28'), 0.0522, 0.2308, 0.9158]
# [2, array(['climate_control 50-75%', 'global_reactive_power 50-75%'],
#       dtype='<U28'), 0.0578, 0.2555, 1.0498]
# [2, array(['climate_control 50-75%', 'global_reactive_power 75-100%'],
#       dtype='<U29'), 0.0701, 0.3098, 1.3035]
# [2, array(['climate_control 50-75%', 'kitchen 75-100%'], dtype='<U22'), 0.1015, 0.4487, 2.0148]
# [2, array(['climate_control 50-75%', 'laundry 50-75%'], dtype='<U22'), 0.0696, 0.3076, 1.2586]
# [2, array(['climate_control 50-75%', 'laundry 75-100%'], dtype='<U22'), 0.0658, 0.2908, 1.2239]
# [2, array(['climate_control 50-75%', 'other 0-25%'], dtype='<U22'), 0.0632, 0.2795, 1.0682]
# [2, array(['climate_control 50-75%', 'other 25-50%'], dtype='<U22'), 0.0559, 0.2471, 0.8518]
# [2, array(['climate_control 50-75%', 'other 75-100%'], dtype='<U22'), 0.0606, 0.2678, 1.2473]
# [2, array(['climate_control 50-75%', 'season_name autumn'], dtype='<U22'), 0.061, 0.2696, 1.0943]
# [2, array(['climate_control 50-75%', 'season_name spring'], dtype='<U22'), 0.0541, 0.2394, 0.9906]
# [2, array(['climate_control 50-75%', 'season_name summer'], dtype='<U22'), 0.0757, 0.3346, 1.3776]
# [2, array(['climate_control 50-75%', 'voltage 0-25%'], dtype='<U22'), 0.0695, 0.3075, 1.2947]
# [2, array(['climate_control 50-75%', 'voltage 50-75%'], dtype='<U22'), 0.0542, 0.2397, 1.0265]
# [2, array(['climate_control 50-75%', 'voltage 75-100%'], dtype='<U22'), 0.0549, 0.2428, 0.8046]
# [2, array(['weekend False', 'climate_control 50-75%'], dtype='<U22'), 0.1553, 0.6868, 0.965]
# [2, array(['climate_control 50-75%', 'weekend True'], dtype='<U22'), 0.0708, 0.3132, 1.0864]
# [2, array(['climate_control 75-100%', 'global_active_power 50-75%'],
#       dtype='<U26'), 0.0861, 0.4066, 1.9732]
# [2, array(['climate_control 75-100%', 'global_active_power 75-100%'],
#       dtype='<U27'), 0.1257, 0.5934, 2.712]
# [2, array(['climate_control 75-100%', 'global_intensity 50-75%'], dtype='<U23'), 0.0876, 0.4135, 2.0087]
# [2, array(['climate_control 75-100%', 'global_intensity 75-100%'],
#       dtype='<U24'), 0.1242, 0.5865, 2.6718]
# [2, array(['climate_control 75-100%', 'global_reactive_power 25-50%'],
#       dtype='<U28'), 0.0547, 0.2582, 1.0244]
# [2, array(['climate_control 75-100%', 'global_reactive_power 75-100%'],
#       dtype='<U29'), 0.0578, 0.273, 1.1486]
# [2, array(['climate_control 75-100%', 'kitchen 50-75%'], dtype='<U23'), 0.0602, 0.284, 1.1544]
# [2, array(['climate_control 75-100%', 'kitchen 75-100%'], dtype='<U23'), 0.0713, 0.3364, 1.5107]
# [2, array(['laundry 25-50%', 'climate_control 75-100%'], dtype='<U23'), 0.0674, 0.318, 1.267]
# [2, array(['climate_control 75-100%', 'laundry 50-75%'], dtype='<U23'), 0.051, 0.2406, 0.9843]
# [2, array(['climate_control 75-100%', 'laundry 75-100%'], dtype='<U23'), 0.0556, 0.2626, 1.1052]
# [2, array(['climate_control 75-100%', 'other 50-75%'], dtype='<U23'), 0.0655, 0.3094, 1.3243]
# [2, array(['climate_control 75-100%', 'other 75-100%'], dtype='<U23'), 0.0758, 0.3578, 1.6664]
# [2, array(['climate_control 75-100%', 'season_name autumn'], dtype='<U23'), 0.0588, 0.2774, 1.126]
# [2, array(['climate_control 75-100%', 'season_name spring'], dtype='<U23'), 0.0564, 0.2664, 1.1024]
# [2, array(['climate_control 75-100%', 'season_name winter'], dtype='<U23'), 0.0612, 0.2891, 1.0743]
# [2, array(['climate_control 75-100%', 'voltage 0-25%'], dtype='<U23'), 0.0681, 0.3213, 1.3529]
# [2, array(['climate_control 75-100%', 'voltage 25-50%'], dtype='<U23'), 0.0731, 0.3452, 1.5191]
# [2, array(['weekend False', 'climate_control 75-100%'], dtype='<U23'), 0.1516, 0.7157, 1.0056]
# [2, array(['climate_control 75-100%', 'weekend True'], dtype='<U23'), 0.0602, 0.2843, 0.9862]
# [2, array(['global_intensity 0-25%', 'global_active_power 0-25%'],
#       dtype='<U25'), 0.2915, 0.2915, 1.0]
# [2, array(['global_active_power 0-25%', 'global_reactive_power 0-25%'],
#       dtype='<U27'), 0.1391, 0.4527, 1.696]
# [2, array(['global_reactive_power 25-50%', 'global_active_power 0-25%'],
#       dtype='<U28'), 0.0891, 0.29, 1.1505]
# [2, array(['global_active_power 0-25%', 'global_reactive_power 50-75%'],
#       dtype='<U28'), 0.0553, 0.2271, 0.7389]
# [2, array(['kitchen 0-25%', 'global_active_power 0-25%'], dtype='<U25'), 0.1227, 0.3992, 1.42]
# [2, array(['kitchen 25-50%', 'global_active_power 0-25%'], dtype='<U25'), 0.0876, 0.285, 1.1394]
# [2, array(['kitchen 50-75%', 'global_active_power 0-25%'], dtype='<U25'), 0.0648, 0.2109, 0.8573]
# [2, array(['laundry 0-25%', 'global_active_power 0-25%'], dtype='<U25'), 0.1231, 0.4004, 1.5]
# [2, array(['laundry 25-50%', 'global_active_power 0-25%'], dtype='<U25'), 0.0756, 0.246, 0.9799]
# [2, array(['laundry 50-75%', 'global_active_power 0-25%'], dtype='<U25'), 0.0765, 0.2488, 1.0178]
# [2, array(['global_active_power 0-25%', 'other 0-25%'], dtype='<U25'), 0.1868, 0.6077, 2.3229]
# [2, array(['other 25-50%', 'global_active_power 0-25%'], dtype='<U25'), 0.1206, 0.3923, 1.3525]
# [2, array(['season_name autumn', 'global_active_power 0-25%'], dtype='<U25'), 0.0669, 0.2175, 0.883]
# [2, array(['season_name spring', 'global_active_power 0-25%'], dtype='<U25'), 0.0577, 0.2388, 0.7768]
# [2, array(['season_name summer', 'global_active_power 0-25%'], dtype='<U25'), 0.1075, 0.3497, 1.4399]
# [2, array(['season_name winter', 'global_active_power 0-25%'], dtype='<U25'), 0.0753, 0.245, 0.9105]
# [2, array(['global_active_power 0-25%', 'voltage 25-50%'], dtype='<U25'), 0.059, 0.2598, 0.8451]
# [2, array(['global_active_power 0-25%', 'voltage 50-75%'], dtype='<U25'), 0.0794, 0.2583, 1.1063]
# [2, array(['voltage 75-100%', 'global_active_power 0-25%'], dtype='<U25'), 0.1214, 0.395, 1.309]
# [2, array(['weekend False', 'global_active_power 0-25%'], dtype='<U25'), 0.2269, 0.2269, 1.0]
# [2, array(['weekend True', 'global_active_power 0-25%'], dtype='<U25'), 0.0804, 0.2617, 0.9076]
# [2, array(['global_active_power 25-50%', 'global_intensity 25-50%'],
#       dtype='<U26'), 0.2415, 0.2415, 1.0]
# [2, array(['global_active_power 25-50%', 'global_reactive_power 25-50%'],
#       dtype='<U28'), 0.0611, 0.2281, 0.9048]
# [2, array(['global_active_power 25-50%', 'global_reactive_power 50-75%'],
#       dtype='<U28'), 0.0905, 0.3379, 1.3885]
# [2, array(['global_active_power 25-50%', 'global_reactive_power 75-100%'],
#       dtype='<U29'), 0.0798, 0.2979, 1.2532]
# [2, array(['global_active_power 25-50%', 'kitchen 0-25%'], dtype='<U26'), 0.0619, 0.2312, 0.8223]
# [2, array(['global_active_power 25-50%', 'kitchen 25-50%'], dtype='<U26'), 0.0718, 0.2683, 1.0725]
# [2, array(['global_active_power 25-50%', 'kitchen 50-75%'], dtype='<U26'), 0.0855, 0.3192, 1.2973]
# [2, array(['laundry 25-50%', 'global_active_power 25-50%'], dtype='<U26'), 0.0685, 0.2559, 1.0197]
# [2, array(['laundry 50-75%', 'global_active_power 25-50%'], dtype='<U26'), 0.0677, 0.253, 1.0349]
# [2, array(['global_active_power 25-50%', 'laundry 75-100%'], dtype='<U26'), 0.0808, 0.3019, 1.2704]
# [2, array(['global_active_power 25-50%', 'other 25-50%'], dtype='<U26'), 0.1065, 0.3979, 1.3718]
# [2, array(['global_active_power 25-50%', 'other 50-75%'], dtype='<U26'), 0.1247, 0.4658, 1.9941]
# [2, array(['season_name autumn', 'global_active_power 25-50%'], dtype='<U26'), 0.0637, 0.2378, 0.9651]
# [2, array(['global_active_power 25-50%', 'season_name spring'], dtype='<U26'), 0.0731, 0.2729, 1.1291]
# [2, array(['global_active_power 25-50%', 'season_name summer'], dtype='<U26'), 0.0535, 0.2204, 0.8231]
# [2, array(['global_active_power 25-50%', 'season_name winter'], dtype='<U26'), 0.0775, 0.2894, 1.0757]
# [2, array(['global_active_power 25-50%', 'voltage 50-75%'], dtype='<U26'), 0.0724, 0.2703, 1.1574]
# [2, array(['global_active_power 25-50%', 'voltage 75-100%'], dtype='<U26'), 0.122, 0.4556, 1.51]
# [2, array(['weekend False', 'global_active_power 25-50%'], dtype='<U26'), 0.1882, 0.703, 0.9878]
# [2, array(['global_active_power 25-50%', 'weekend True'], dtype='<U26'), 0.0795, 0.297, 1.0301]
# [2, array(['global_active_power 50-75%', 'global_intensity 50-75%'],
#       dtype='<U26'), 0.1995, 0.968, 4.7019]
# [2, array(['global_active_power 50-75%', 'global_reactive_power 0-25%'],
#       dtype='<U27'), 0.0536, 0.2601, 0.9746]
# [2, array(['global_active_power 50-75%', 'global_reactive_power 25-50%'],
#       dtype='<U28'), 0.0572, 0.2776, 1.1012]
# [2, array(['global_active_power 50-75%', 'kitchen 0-25%'], dtype='<U26'), 0.0514, 0.2494, 0.8872]
# [2, array(['global_active_power 50-75%', 'kitchen 50-75%'], dtype='<U26'), 0.0533, 0.2585, 1.0506]
# [2, array(['global_active_power 50-75%', 'kitchen 75-100%'], dtype='<U26'), 0.0528, 0.2561, 1.1498]
# [2, array(['laundry 25-50%', 'global_active_power 50-75%'], dtype='<U26'), 0.0556, 0.2698, 1.075]
# [2, array(['global_active_power 50-75%', 'laundry 50-75%'], dtype='<U26'), 0.0534, 0.2591, 1.0602]
# [2, array(['global_active_power 50-75%', 'other 25-50%'], dtype='<U26'), 0.0526, 0.2553, 0.8801]
# [2, array(['global_active_power 50-75%', 'other 50-75%'], dtype='<U26'), 0.0544, 0.2642, 1.1308]
# [2, array(['global_active_power 50-75%', 'other 75-100%'], dtype='<U26'), 0.0646, 0.3133, 1.4592]
# [2, array(['global_active_power 50-75%', 'season_name autumn'], dtype='<U26'), 0.0538, 0.2611, 1.0597]
# [2, array(['global_active_power 50-75%', 'season_name spring'], dtype='<U26'), 0.0552, 0.268, 1.1091]
# [2, array(['global_active_power 50-75%', 'season_name summer'], dtype='<U26'), 0.0519, 0.2519, 1.0369]
# [2, array(['global_active_power 50-75%', 'voltage 0-25%'], dtype='<U26'), 0.0582, 0.2823, 1.1885]
# [2, array(['global_active_power 50-75%', 'voltage 25-50%'], dtype='<U26'), 0.0584, 0.2832, 1.2463]
# [2, array(['global_active_power 50-75%', 'voltage 50-75%'], dtype='<U26'), 0.0502, 0.2438, 1.044]
# [2, array(['weekend False', 'global_active_power 50-75%'], dtype='<U26'), 0.1538, 0.7462, 1.0485]
# [2, array(['global_active_power 50-75%', 'weekend True'], dtype='<U26'), 0.0523, 0.2538, 0.8802]
# [2, array(['global_intensity 75-100%', 'global_active_power 75-100%'],
#       dtype='<U27'), 0.2158, 0.2158, 1.0]
# [2, array(['global_reactive_power 50-75%', 'global_active_power 75-100%'],
#       dtype='<U28'), 0.0501, 0.2291, 0.9416]
# [2, array(['global_reactive_power 75-100%', 'global_active_power 75-100%'],
#       dtype='<U29'), 0.0863, 0.3944, 1.6593]
# [2, array(['kitchen 75-100%', 'global_active_power 75-100%'], dtype='<U27'), 0.0891, 0.4074, 1.8292]
# [2, array(['laundry 25-50%', 'global_active_power 75-100%'], dtype='<U27'), 0.0513, 0.2343, 0.9335]
# [2, array(['laundry 75-100%', 'global_active_power 75-100%'], dtype='<U27'), 0.076, 0.3475, 1.4623]
# [2, array(['other 50-75%', 'global_active_power 75-100%'], dtype='<U27'), 0.0544, 0.2488, 1.065]
# [2, array(['other 75-100%', 'global_active_power 75-100%'], dtype='<U27'), 0.1501, 0.6862, 3.1954]
# [2, array(['season_name autumn', 'global_active_power 75-100%'], dtype='<U27'), 0.062, 0.2835, 1.1508]
# [2, array(['season_name spring', 'global_active_power 75-100%'], dtype='<U27'), 0.0557, 0.2544, 1.0528]
# [2, array(['season_name winter', 'global_active_power 75-100%'], dtype='<U27'), 0.0711, 0.3251, 1.2083]
# [2, array(['voltage 0-25%', 'global_active_power 75-100%'], dtype='<U27'), 0.1082, 0.4947, 2.0828]
# [2, array(['voltage 25-50%', 'global_active_power 75-100%'], dtype='<U27'), 0.06, 0.2744, 1.2073]
# [2, array(['weekend False', 'global_active_power 75-100%'], dtype='<U27'), 0.1427, 0.6523, 0.9166]
# [2, array(['weekend True', 'global_active_power 75-100%'], dtype='<U27'), 0.0761, 0.3477, 1.2057]
# [2, array(['global_intensity 0-25%', 'global_reactive_power 0-25%'],
#       dtype='<U27'), 0.1437, 0.4572, 1.7131]
# [2, array(['global_reactive_power 25-50%', 'global_intensity 0-25%'],
#       dtype='<U28'), 0.0997, 0.317, 1.2578]
# [2, array(['global_intensity 0-25%', 'global_reactive_power 50-75%'],
#       dtype='<U28'), 0.0583, 0.2397, 0.7626]
# [2, array(['kitchen 0-25%', 'global_intensity 0-25%'], dtype='<U22'), 0.1204, 0.383, 1.3623]
# [2, array(['kitchen 25-50%', 'global_intensity 0-25%'], dtype='<U22'), 0.0917, 0.2917, 1.1662]
# [2, array(['kitchen 50-75%', 'global_intensity 0-25%'], dtype='<U22'), 0.0691, 0.2199, 0.8938]
# [2, array(['laundry 0-25%', 'global_intensity 0-25%'], dtype='<U22'), 0.1257, 0.4, 1.4983]
# [2, array(['laundry 25-50%', 'global_intensity 0-25%'], dtype='<U22'), 0.0847, 0.2695, 1.0739]
# [2, array(['laundry 50-75%', 'global_intensity 0-25%'], dtype='<U22'), 0.0772, 0.2457, 1.0051]
# [2, array(['global_intensity 0-25%', 'other 0-25%'], dtype='<U22'), 0.179, 0.5694, 2.1763]
# [2, array(['other 25-50%', 'global_intensity 0-25%'], dtype='<U22'), 0.1327, 0.4221, 1.4554]
# [2, array(['season_name autumn', 'global_intensity 0-25%'], dtype='<U22'), 0.0698, 0.2219, 0.9008]
# [2, array(['season_name spring', 'global_intensity 0-25%'], dtype='<U22'), 0.0629, 0.2001, 0.8279]
# [2, array(['season_name summer', 'global_intensity 0-25%'], dtype='<U22'), 0.0977, 0.3109, 1.2799]
# [2, array(['season_name winter', 'global_intensity 0-25%'], dtype='<U22'), 0.084, 0.2671, 0.9927]
# [2, array(['global_intensity 0-25%', 'voltage 25-50%'], dtype='<U22'), 0.0566, 0.2492, 0.7927]
# [2, array(['global_intensity 0-25%', 'voltage 50-75%'], dtype='<U22'), 0.0779, 0.2477, 1.0608]
# [2, array(['voltage 75-100%', 'global_intensity 0-25%'], dtype='<U22'), 0.1342, 0.4269, 1.4148]
# [2, array(['weekend False', 'global_intensity 0-25%'], dtype='<U22'), 0.2309, 0.2309, 1.0]
# [2, array(['weekend True', 'global_intensity 0-25%'], dtype='<U22'), 0.0835, 0.2655, 0.9208]
# [2, array(['global_reactive_power 25-50%', 'global_intensity 25-50%'],
#       dtype='<U28'), 0.0515, 0.2044, 0.7855]
# [2, array(['global_intensity 25-50%', 'global_reactive_power 50-75%'],
#       dtype='<U28'), 0.0879, 0.3377, 1.3879]
# [2, array(['global_intensity 25-50%', 'global_reactive_power 75-100%'],
#       dtype='<U29'), 0.0884, 0.3398, 1.4294]
# [2, array(['global_intensity 25-50%', 'kitchen 0-25%'], dtype='<U23'), 0.064, 0.246, 0.8751]
# [2, array(['global_intensity 25-50%', 'kitchen 25-50%'], dtype='<U23'), 0.0678, 0.2605, 1.0415]
# [2, array(['global_intensity 25-50%', 'kitchen 50-75%'], dtype='<U23'), 0.0811, 0.3115, 1.266]
# [2, array(['laundry 25-50%', 'global_intensity 25-50%'], dtype='<U23'), 0.0602, 0.2314, 0.922]
# ...
#        'climate_control 0-25%', 'global_active_power 0-25%'], dtype='<U25'), 0.0578, 0.2209, 1.9784]
# [6, array(['weekend False', 'global_intensity 0-25%', 'False', 'other 25-50%',
#        'climate_control 0-25%', 'global_active_power 0-25%'], dtype='<U25'), 0.0539, 0.2044, 3.3504]
# [6, array(['laundry 0-25%', 'weekend False', 'kitchen 0-25%', 'False',
#        'climate_control 0-25%', 'global_active_power 0-25%'], dtype='<U25'), 0.0576, 0.2048, 3.0486]
# [6, array(['weekend False', 'kitchen 0-25%', 'False', 'other 0-25%',
#        'climate_control 0-25%', 'global_active_power 0-25%'], dtype='<U25'), 0.0511, 0.2433, 3.7069]
# [6, array(['laundry 0-25%', 'weekend False', 'kitchen 0-25%',
#        'global_intensity 0-25%', 'False', 'climate_control 0-25%'],
#       dtype='<U22'), 0.058, 0.2063, 3.0177]
# [6, array(['global_reactive_power 0-25%', 'weekend False',
#        'global_intensity 0-25%', 'False', 'other 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0539, 0.2019, 1.8687]
# [6, array(['laundry 0-25%', 'weekend False', 'kitchen 0-25%',
#        'global_intensity 0-25%', 'False', 'global_active_power 0-25%'],
#       dtype='<U25'), 0.0568, 0.2019, 2.6604]
# [6, array(['other 75-100%', 'climate_control 75-100%', 'True',
#        'global_intensity 75-100%', 'activation_type_label cam_1',
#        'global_active_power 75-100%'], dtype='<U27'), 0.0601, 0.2836, 2.4881]
# [6, array(['weekend False', 'climate_control 75-100%', 'True',
#        'global_intensity 75-100%', 'activation_type_label cam_1',
#        'global_active_power 75-100%'], dtype='<U27'), 0.062, 0.2925, 2.7948]
# [6, array(['voltage 0-25%', 'other 75-100%', 'True',
#        'global_intensity 75-100%', 'activation_type_label cam_1',
#        'global_active_power 75-100%'], dtype='<U27'), 0.0669, 0.2012, 2.5176]
# [6, array(['other 75-100%', 'weekend False', 'True',
#        'global_intensity 75-100%', 'activation_type_label cam_1',
#        'global_active_power 75-100%'], dtype='<U27'), 0.0758, 0.2281, 2.3813]
# [6, array(['voltage 0-25%', 'weekend False', 'True',
#        'global_intensity 75-100%', 'activation_type_label cam_1',
#        'global_active_power 75-100%'], dtype='<U27'), 0.0555, 0.2535, 4.4894]
# [6, array(['other 75-100%', 'weekend False', 'climate_control 75-100%',
#        'global_intensity 75-100%', 'activation_type_label cam_1',
#        'global_active_power 75-100%'], dtype='<U27'), 0.0504, 0.2379, 2.4835]
# [6, array(['voltage 0-25%', 'other 75-100%', 'weekend False',
#        'global_intensity 75-100%', 'activation_type_label cam_1',
#        'global_active_power 75-100%'], dtype='<U27'), 0.05, 0.2285, 4.5431]
# [6, array(['activation_type_label cam_2', 'attention_type_label other',
#        'kitchen 0-25%', 'global_intensity 0-25%', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0691, 0.2196, 3.1723]
# [6, array(['activation_type_label cam_2', 'attention_type_label other',
#        'laundry 0-25%', 'global_intensity 0-25%', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0589, 0.2208, 2.2792]
# [6, array(['activation_type_label cam_2', 'attention_type_label other',
#        'weekend False', 'global_intensity 0-25%', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0748, 0.2379, 1.8853]
# [6, array(['activation_type_label cam_2', 'attention_type_label other',
#        'weekend False', 'kitchen 0-25%', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0577, 0.2052, 2.6426]
# [6, array(['activation_type_label cam_2', 'attention_type_label other',
#        'laundry 0-25%', 'kitchen 0-25%', 'global_intensity 0-25%',
#        'climate_control 0-25%'], dtype='<U27'), 0.0505, 0.2605, 4.2197]
# [6, array(['activation_type_label cam_2', 'attention_type_label other',
#        'weekend False', 'kitchen 0-25%', 'global_intensity 0-25%',
#        'climate_control 0-25%'], dtype='<U27'), 0.0563, 0.2003, 2.5609]
# [6, array(['activation_type_label cam_2', 'attention_type_label other',
#        'laundry 0-25%', 'weekend False', 'kitchen 0-25%',
#        'climate_control 0-25%'], dtype='<U27'), 0.0521, 0.2688, 3.8157]
# [6, array(['activation_type_label cam_2', 'attention_type_label other',
#        'weekend False', 'global_intensity 0-25%',
#        'global_reactive_power 0-25%', 'global_active_power 0-25%'],
#       dtype='<U27'), 0.0607, 0.2273, 1.8016]
# [6, array(['activation_type_label cam_2', 'attention_type_label other',
#        'weekend False', 'kitchen 0-25%', 'global_intensity 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0551, 0.2846, 2.2338]
# [6, array(['activation_type_label cam_2', 'attention_type_label other',
#        'laundry 0-25%', 'weekend False', 'global_intensity 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0541, 0.2028, 1.6074]
# [6, array(['activation_type_label cam_2', 'attention_type_label other',
#        'weekend False', 'global_intensity 0-25%', 'other 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0769, 0.2503, 3.2062]
# [6, array(['activation_type_label cam_2', 'attention_type_label other',
#        'weekend False', 'global_intensity 0-25%', 'voltage 75-100%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0529, 0.2089, 1.6395]
# [6, array(['activation_type_label cam_2', 'kitchen 0-25%',
#        'global_intensity 0-25%', 'global_reactive_power 0-25%',
#        'climate_control 0-25%', 'global_active_power 0-25%'], dtype='<U27'), 0.0517, 0.286, 2.4632]
# [6, array(['activation_type_label cam_2', 'laundry 0-25%',
#        'global_intensity 0-25%', 'global_reactive_power 0-25%',
#        'climate_control 0-25%', 'global_active_power 0-25%'], dtype='<U27'), 0.0524, 0.2895, 3.0102]
# [6, array(['activation_type_label cam_2', 'weekend False',
#        'global_intensity 0-25%', 'global_reactive_power 0-25%',
#        'climate_control 0-25%', 'global_active_power 0-25%'], dtype='<U27'), 0.0588, 0.2202, 1.8498]
# [6, array(['activation_type_label cam_2', 'laundry 0-25%', 'kitchen 0-25%',
#        'global_intensity 0-25%', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.081, 0.2576, 3.1722]
# [6, array(['activation_type_label cam_2', 'other 0-25%', 'kitchen 0-25%',
#        'global_intensity 0-25%', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0672, 0.2137, 3.1674]
# [6, array(['activation_type_label cam_2', 'weekend False', 'kitchen 0-25%',
#        'global_intensity 0-25%', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0885, 0.2814, 3.1704]
# [6, array(['activation_type_label cam_2', 'laundry 0-25%', 'weekend False',
#        'global_intensity 0-25%', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0711, 0.2262, 2.5647]
# [6, array(['activation_type_label cam_2', 'weekend False',
#        'global_intensity 0-25%', 'other 0-25%', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0627, 0.2039, 3.2483]
# [6, array(['activation_type_label cam_2', 'weekend False',
#        'global_intensity 0-25%', 'other 25-50%', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0564, 0.2097, 2.5278]
# [6, array(['activation_type_label cam_2', 'laundry 0-25%', 'weekend False',
#        'kitchen 0-25%', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0622, 0.2023, 2.4427]
# [6, array(['activation_type_label cam_2', 'weekend False', 'kitchen 0-25%',
#        'other 0-25%', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0556, 0.2125, 2.2802]
# [6, array(['activation_type_label cam_2', 'laundry 0-25%', 'weekend False',
#        'kitchen 0-25%', 'global_intensity 0-25%', 'climate_control 0-25%'],
#       dtype='<U27'), 0.0626, 0.2228, 3.038]
# [6, array(['activation_type_label cam_2', 'weekend False', 'kitchen 0-25%',
#        'global_intensity 0-25%', 'other 0-25%', 'climate_control 0-25%'],
#       dtype='<U27'), 0.0535, 0.2044, 2.2473]
# [6, array(['activation_type_label cam_2', 'weekend False',
#        'global_intensity 0-25%', 'climate_control 25-50%', 'other 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0519, 0.2095, 1.6066]
# [6, array(['activation_type_label cam_2', 'global_reactive_power 0-25%',
#        'weekend False', 'global_intensity 0-25%', 'other 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.061, 0.2284, 1.7517]
# [6, array(['activation_type_label cam_2', 'laundry 0-25%', 'weekend False',
#        'kitchen 0-25%', 'global_intensity 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0614, 0.2183, 2.4749]
# [6, array(['activation_type_label cam_2', 'weekend False', 'kitchen 0-25%',
#        'global_intensity 0-25%', 'other 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0536, 0.2047, 2.3065]
# [6, array(['activation_type_label cam_2', 'laundry 0-25%', 'weekend False',
#        'global_intensity 0-25%', 'other 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0531, 0.2031, 2.3025]
# [6, array(['activation_type_label cam_2', 'weekend False',
#        'global_intensity 0-25%', 'other 0-25%',
#        'global_active_power 0-25%', 'season_name summer'], dtype='<U27'), 0.066, 0.2148, 3.2453]
# [6, array(['attention_type_label other', 'weekend False', 'kitchen 0-25%',
#        'global_intensity 0-25%', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U26'), 0.0555, 0.2988, 3.3204]
# [6, array(['laundry 0-25%', 'weekend False', 'kitchen 0-25%',
#        'global_intensity 0-25%', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U25'), 0.0619, 0.2015, 3.1799]
# [6, array(['weekend False', 'kitchen 0-25%', 'global_intensity 0-25%',
#        'other 0-25%', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U25'), 0.0541, 0.2067, 2.3072]
# [7, array(['activation_type_label cam_2', 'attention_type_label other',
#        'kitchen 0-25%', 'global_intensity 0-25%', 'False',
#        'climate_control 0-25%', 'global_active_power 0-25%'], dtype='<U27'), 0.0636, 0.2022, 3.1717]
# [7, array(['activation_type_label cam_2', 'attention_type_label other',
#        'laundry 0-25%', 'global_intensity 0-25%', 'False',
#        'climate_control 0-25%', 'global_active_power 0-25%'], dtype='<U27'), 0.0547, 0.2049, 2.2668]
# [7, array(['activation_type_label cam_2', 'attention_type_label other',
#        'weekend False', 'global_intensity 0-25%', 'False',
#        'climate_control 0-25%', 'global_active_power 0-25%'], dtype='<U27'), 0.0701, 0.2228, 1.9619]
# [7, array(['activation_type_label cam_2', 'attention_type_label other',
#        'weekend False', 'kitchen 0-25%', 'False', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0538, 0.2042, 2.3852]
# [7, array(['activation_type_label cam_2', 'attention_type_label other',
#        'weekend False', 'kitchen 0-25%', 'global_intensity 0-25%',
#        'False', 'climate_control 0-25%'], dtype='<U27'), 0.0525, 0.2501, 3.1985]
# [7, array(['activation_type_label cam_2', 'attention_type_label other',
#        'weekend False', 'global_intensity 0-25%', 'False',
#        'global_reactive_power 0-25%', 'global_active_power 0-25%'],
#       dtype='<U27'), 0.0564, 0.2113, 1.8607]
# [7, array(['activation_type_label cam_2', 'attention_type_label other',
#        'weekend False', 'kitchen 0-25%', 'global_intensity 0-25%',
#        'False', 'global_active_power 0-25%'], dtype='<U27'), 0.0514, 0.2447, 1.9397]
# [7, array(['activation_type_label cam_2', 'attention_type_label other',
#        'weekend False', 'global_intensity 0-25%', 'False', 'other 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0665, 0.2164, 3.1989]
# [7, array(['activation_type_label cam_2', 'attention_type_label other',
#        'weekend False', 'global_intensity 0-25%', 'False',
#        'voltage 75-100%', 'global_active_power 0-25%'], dtype='<U27'), 0.0508, 0.2006, 1.7631]
# [7, array(['activation_type_label cam_2', 'global_reactive_power 0-25%',
#        'weekend False', 'global_intensity 0-25%', 'False',
#        'climate_control 0-25%', 'global_active_power 0-25%'], dtype='<U27'), 0.0556, 0.2084, 1.8706]
# [7, array(['activation_type_label cam_2', 'laundry 0-25%', 'kitchen 0-25%',
#        'global_intensity 0-25%', 'False', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0735, 0.2336, 3.1728]
# [7, array(['activation_type_label cam_2', 'other 0-25%', 'kitchen 0-25%',
#        'global_intensity 0-25%', 'False', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0605, 0.2153, 2.9348]
# [7, array(['activation_type_label cam_2', 'weekend False', 'kitchen 0-25%',
#        'global_intensity 0-25%', 'False', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0823, 0.2617, 3.171]
# [7, array(['activation_type_label cam_2', 'laundry 0-25%', 'weekend False',
#        'global_intensity 0-25%', 'False', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0661, 0.2101, 2.7753]
# [7, array(['activation_type_label cam_2', 'other 0-25%', 'weekend False',
#        'global_intensity 0-25%', 'False', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0577, 0.2207, 1.9802]
# [7, array(['activation_type_label cam_2', 'weekend False',
#        'global_intensity 0-25%', 'False', 'other 25-50%',
#        'climate_control 0-25%', 'global_active_power 0-25%'], dtype='<U27'), 0.0537, 0.2037, 3.3714]
# [7, array(['activation_type_label cam_2', 'laundry 0-25%', 'weekend False',
#        'kitchen 0-25%', 'False', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0574, 0.2042, 3.0474]
# [7, array(['activation_type_label cam_2', 'other 0-25%', 'weekend False',
#        'kitchen 0-25%', 'False', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.051, 0.243, 3.742]
# [7, array(['activation_type_label cam_2', 'laundry 0-25%', 'weekend False',
#        'kitchen 0-25%', 'global_intensity 0-25%', 'False',
#        'climate_control 0-25%'], dtype='<U27'), 0.0579, 0.2058, 3.0166]
# [7, array(['activation_type_label cam_2', 'other 0-25%', 'weekend False',
#        'global_intensity 0-25%', 'False', 'global_reactive_power 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0539, 0.2018, 1.8722]
# [7, array(['activation_type_label cam_2', 'laundry 0-25%', 'weekend False',
#        'kitchen 0-25%', 'global_intensity 0-25%', 'False',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0566, 0.2013, 2.6596]
# [7, array(['attention_type_label other', 'weekend False', 'kitchen 0-25%',
#        'global_intensity 0-25%', 'False', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U26'), 0.0514, 0.2446, 3.245]
# [7, array(['laundry 0-25%', 'weekend False', 'kitchen 0-25%',
#        'global_intensity 0-25%', 'False', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U25'), 0.0566, 0.2013, 3.0412]
# [7, array(['activation_type_label cam_2', 'attention_type_label other',
#        'weekend False', 'kitchen 0-25%', 'global_intensity 0-25%',
#        'climate_control 0-25%', 'global_active_power 0-25%'], dtype='<U27'), 0.055, 0.2045, 3.6695]
# [7, array(['activation_type_label cam_2', 'laundry 0-25%', 'weekend False',
#        'kitchen 0-25%', 'global_intensity 0-25%', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0612, 0.2177, 3.0603]
# [7, array(['activation_type_label cam_2', 'other 0-25%', 'weekend False',
#        'kitchen 0-25%', 'global_intensity 0-25%', 'climate_control 0-25%',
#        'global_active_power 0-25%'], dtype='<U27'), 0.0534, 0.204, 2.3048]
# [8, array(['activation_type_label cam_2', 'attention_type_label other',
#        'weekend False', 'kitchen 0-25%', 'global_intensity 0-25%',
#        'False', 'climate_control 0-25%', 'global_active_power 0-25%'],
#       dtype='<U27'), 0.0512, 0.2439, 3.2611]
# [8, array(['activation_type_label cam_2', 'laundry 0-25%', 'weekend False',
#        'kitchen 0-25%', 'global_intensity 0-25%', 'False',
#        'climate_control 0-25%', 'global_active_power 0-25%'], dtype='<U27'), 0.0565, 0.2009, 3.0402]

# %%
# Filter by rhs=='Power Pattern *'
filter_RHS_ECP = True
if(filter_RHS_ECP):
    association_rules_np_rhs = []
    for r in range(len(association_rules_np)):
        # rhs = association_rules_np[r, 1][-1] # old
        rhs = association_rules_np[r][1][-1]
        if(rhs=='True' or rhs=='False'):
            association_rules_np_rhs.append(association_rules_np[r])
    association_rules_np_rhs = np.array(association_rules_np_rhs, dtype=object)
else:
    association_rules_np_rhs = association_rules_np
print('Rule Filtered: %d' %(len(association_rules_np_rhs)))
# Out:
# Rule Filtered: 71

# %%
# Sort rules by confidence
association_rules_np_rhs_sorted = association_rules_np_rhs[association_rules_np_rhs[:, 3].argsort()][::-1]
print(len(association_rules_np_rhs_sorted))
print(association_rules_np_rhs_sorted[:10])

# Length, Rule, Support, Confidence, Lift
# Out:
# 71
# [[3
#   array(['weekend False', 'attention_type_label late_attention', 'True'],
#         dtype='<U35')
#   0.0523 0.6947 0.9762]
#  [1 array(['False'], dtype='<U5') 0.6677 0.6677 1.0]
#  [2 array(['activation_type_label cam_2', 'False'], dtype='<U27') 0.5435
#   0.5435 1.0]
#  [2 array(['global_active_power 50-75%', 'False'], dtype='<U26') 0.1076
#   0.5223 0.7822]
#  [3 array(['weekend False', 'laundry 25-50%', 'False'], dtype='<U14')
#   0.1287 0.5126 1.0657]
#  [3 array(['weekend False', 'laundry 50-75%', 'False'], dtype='<U14')
#   0.1223 0.5005 1.0404]
#  [2 array(['weekend False', 'False'], dtype='<U13') 0.481 0.481 1.0]
#  [2 array(['climate_control 75-100%', 'True'], dtype='<U23') 0.1426
#   0.4293 2.0265]
#  [2 array(['voltage 0-25%', 'False'], dtype='<U13') 0.1014 0.4271 0.6396]
#  [2 array(['attention_type_label other', 'True'], dtype='<U26') 0.1415
#   0.4258 0.8388]]

# %%
# Duplicate Filter

# Filter by rhs=='No change - True'
top_k = 10

filtered_rules_individual = set([])
filtered_rules = []

# rule_states = set({'attention_type_label other'})
# rule_states = set({})
rule_counter = {}
association_rules_np_rhs_buffer = []
for r in range(len(association_rules_np_rhs_sorted)):
    rhs = association_rules_np_rhs_sorted[r, 1][-1]
    if(rhs=='True' and association_rules_np_rhs_sorted[r, 0]>1):
        association_rules_np_rhs_buffer.append(association_rules_np_rhs_sorted[r])
association_rules_np_rhs_buffer = np.array(association_rules_np_rhs_buffer)

# print(association_rules_np_rhs_buffer[:top_k])
for rule in association_rules_np_rhs_buffer:
    
    cari_lagi = False
    # rule_checker_vars_only = set({})
    rule = rule[1][:-1].tolist()
    # print(rule)
    if top_k < 1:
        break
    
    print('mined rule: ', rule)
    
    # top_k = top_k - 1
    filtered_rules_individual_temp = filtered_rules_individual | set(rule)
    # filtered_rules_individual = filtered_rules_individual | set(rule)
    if (len(filtered_rules_individual_temp) > len(filtered_rules_individual)):
        rule_checker_vars_only = set([r.split(' ')[0] for r in filtered_rules_individual_temp])
        print('ada tambahan! cek length')
        print('set dgn tambahan', filtered_rules_individual_temp)
        print('set vars only', rule_checker_vars_only)
        if (len(rule_checker_vars_only) == len(filtered_rules_individual_temp)):
            print('element berbeda dan belum pernah dimasukan!')
        else:
            print('elemen ada yang kembar~ cek lagi yang lain')
            cari_lagi = True
        # break
    if (cari_lagi):
        continue
    
    # jika udah klop, copy aja
    filtered_rules_individual = filtered_rules_individual | set(rule)
    filtered_rules.append(rule)
    top_k = top_k - 1
    print('filtered rules', filtered_rules)
    print('filtered individual', filtered_rules_individual)
    print('next search')
    print()
# filtered_rules_individual
# filtered_rules
'Filtered rules for peak warning',(filtered_rules_individual), filtered_rules, len(filtered_rules)
# Out:
# mined rule:  ['weekend False', 'attention_type_label late_attention']
# ada tambahan! cek length
# set dgn tambahan {'weekend False', 'attention_type_label late_attention'}
# set vars only {'attention_type_label', 'weekend'}
# element berbeda dan belum pernah dimasukan!
# filtered rules [['weekend False', 'attention_type_label late_attention']]
# filtered individual {'weekend False', 'attention_type_label late_attention'}
# next search
#
# mined rule:  ['climate_control 75-100%']
# ada tambahan! cek length
# set dgn tambahan {'weekend False', 'climate_control 75-100%', 'attention_type_label late_attention'}
# set vars only {'attention_type_label', 'weekend', 'climate_control'}
# element berbeda dan belum pernah dimasukan!
# filtered rules [['weekend False', 'attention_type_label late_attention'], ['climate_control 75-100%']]
# filtered individual {'weekend False', 'climate_control 75-100%', 'attention_type_label late_attention'}
# next search
#
# mined rule:  ['attention_type_label other']
# ada tambahan! cek length
# set dgn tambahan {'weekend False', 'climate_control 75-100%', 'attention_type_label late_attention', 'attention_type_label other'}
# set vars only {'attention_type_label', 'weekend', 'climate_control'}
# elemen ada yang kembar~ cek lagi yang lain
# mined rule:  ['voltage 0-25%']
# ada tambahan! cek length
# set dgn tambahan {'weekend False', 'climate_control 75-100%', 'attention_type_label late_attention', 'voltage 0-25%'}
# set vars only {'attention_type_label', 'weekend', 'voltage', 'climate_control'}
# element berbeda dan belum pernah dimasukan!
# filtered rules [['weekend False', 'attention_type_label late_attention'], ['climate_control 75-100%'], ['voltage 0-25%']]
# filtered individual {'weekend False', 'climate_control 75-100%', 'attention_type_label late_attention', 'voltage 0-25%'}
# next search
#
# mined rule:  ['attention_type_label early_attention']
# ada tambahan! cek length
# set dgn tambahan {'climate_control 75-100%', 'voltage 0-25%', 'attention_type_label early_attention', 'weekend False', 'attention_type_label late_attention'}
# set vars only {'attention_type_label', 'weekend', 'voltage', 'climate_control'}
# elemen ada yang kembar~ cek lagi yang lain
# mined rule:  ['weekend False', 'climate_control 75-100%']
# filtered rules [['weekend False', 'attention_type_label late_attention'], ['climate_control 75-100%'], ['voltage 0-25%'], ['weekend False', 'climate_control 75-100%']]
# filtered individual {'climate_control 75-100%', 'voltage 0-25%', 'weekend False', 'attention_type_label late_attention'}
# next search
#
# mined rule:  ['global_active_power 50-75%']
# ada tambahan! cek length
# set dgn tambahan {'climate_control 75-100%', 'voltage 0-25%', 'weekend False', 'global_active_power 50-75%', 'attention_type_label late_attention'}
# set vars only {'climate_control', 'attention_type_label', 'voltage', 'weekend', 'global_active_power'}
# element berbeda dan belum pernah dimasukan!
# filtered rules [['weekend False', 'attention_type_label late_attention'], ['climate_control 75-100%'], ['voltage 0-25%'], ['weekend False', 'climate_control 75-100%'], ['global_active_power 50-75%']]
# filtered individual {'climate_control 75-100%', 'voltage 0-25%', 'weekend False', 'global_active_power 50-75%', 'attention_type_label late_attention'}
# next search
#
# mined rule:  ['climate_control 75-100%', 'attention_type_label early_attention']
# ada tambahan! cek length
# set dgn tambahan {'climate_control 75-100%', 'voltage 0-25%', 'attention_type_label early_attention', 'weekend False', 'global_active_power 50-75%', 'attention_type_label late_attention'}
# set vars only {'climate_control', 'attention_type_label', 'voltage', 'weekend', 'global_active_power'}
# elemen ada yang kembar~ cek lagi yang lain
# mined rule:  ['weekend False', 'voltage 0-25%']
# filtered rules [['weekend False', 'attention_type_label late_attention'], ['climate_control 75-100%'], ['voltage 0-25%'], ['weekend False', 'climate_control 75-100%'], ['global_active_power 50-75%'], ['weekend False', 'voltage 0-25%']]
# filtered individual {'climate_control 75-100%', 'voltage 0-25%', 'weekend False', 'global_active_power 50-75%', 'attention_type_label late_attention'}
# next search
#
# mined rule:  ['climate_control 50-75%']
# ada tambahan! cek length
# set dgn tambahan {'climate_control 75-100%', 'voltage 0-25%', 'climate_control 50-75%', 'weekend False', 'global_active_power 50-75%', 'attention_type_label late_attention'}
# set vars only {'climate_control', 'attention_type_label', 'voltage', 'weekend', 'global_active_power'}
# elemen ada yang kembar~ cek lagi yang lain
# mined rule:  ['weekend False', 'climate_control 50-75%']
# ada tambahan! cek length
# set dgn tambahan {'climate_control 75-100%', 'voltage 0-25%', 'climate_control 50-75%', 'weekend False', 'global_active_power 50-75%', 'attention_type_label late_attention'}
# set vars only {'climate_control', 'attention_type_label', 'voltage', 'weekend', 'global_active_power'}
# elemen ada yang kembar~ cek lagi yang lain
# mined rule:  ['voltage 0-25%', 'attention_type_label early_attention']
# ada tambahan! cek length
# set dgn tambahan {'climate_control 75-100%', 'voltage 0-25%', 'attention_type_label early_attention', 'weekend False', 'global_active_power 50-75%', 'attention_type_label late_attention'}
# set vars only {'climate_control', 'attention_type_label', 'voltage', 'weekend', 'global_active_power'}
# elemen ada yang kembar~ cek lagi yang lain
# mined rule:  ['season_name autumn']
# ada tambahan! cek length
# set dgn tambahan {'climate_control 75-100%', 'voltage 0-25%', 'season_name autumn', 'weekend False', 'global_active_power 50-75%', 'attention_type_label late_attention'}
# set vars only {'season_name', 'climate_control', 'attention_type_label', 'voltage', 'weekend', 'global_active_power'}
# element berbeda dan belum pernah dimasukan!
# filtered rules [['weekend False', 'attention_type_label late_attention'], ['climate_control 75-100%'], ['voltage 0-25%'], ['weekend False', 'climate_control 75-100%'], ['global_active_power 50-75%'], ['weekend False', 'voltage 0-25%'], ['season_name autumn']]
# filtered individual {'climate_control 75-100%', 'voltage 0-25%', 'season_name autumn', 'weekend False', 'global_active_power 50-75%', 'attention_type_label late_attention'}
# next search
#
# mined rule:  ['laundry 50-75%']
# ada tambahan! cek length
# set dgn tambahan {'climate_control 75-100%', 'voltage 0-25%', 'season_name autumn', 'weekend False', 'global_active_power 50-75%', 'laundry 50-75%', 'attention_type_label late_attention'}
# set vars only {'laundry', 'season_name', 'climate_control', 'attention_type_label', 'voltage', 'weekend', 'global_active_power'}
# element berbeda dan belum pernah dimasukan!
# filtered rules [['weekend False', 'attention_type_label late_attention'], ['climate_control 75-100%'], ['voltage 0-25%'], ['weekend False', 'climate_control 75-100%'], ['global_active_power 50-75%'], ['weekend False', 'voltage 0-25%'], ['season_name autumn'], ['laundry 50-75%']]
# filtered individual {'climate_control 75-100%', 'voltage 0-25%', 'season_name autumn', 'weekend False', 'global_active_power 50-75%', 'laundry 50-75%', 'attention_type_label late_attention'}
# next search
#
# mined rule:  ['weekend False', 'season_name autumn']
# filtered rules [['weekend False', 'attention_type_label late_attention'], ['climate_control 75-100%'], ['voltage 0-25%'], ['weekend False', 'climate_control 75-100%'], ['global_active_power 50-75%'], ['weekend False', 'voltage 0-25%'], ['season_name autumn'], ['laundry 50-75%'], ['weekend False', 'season_name autumn']]
# filtered individual {'voltage 0-25%', 'season_name autumn', 'weekend False', 'climate_control 75-100%', 'global_active_power 50-75%', 'laundry 50-75%', 'attention_type_label late_attention'}
# next search
#
# mined rule:  ['weekend False']
# filtered rules [['weekend False', 'attention_type_label late_attention'], ['climate_control 75-100%'], ['voltage 0-25%'], ['weekend False', 'climate_control 75-100%'], ['global_active_power 50-75%'], ['weekend False', 'voltage 0-25%'], ['season_name autumn'], ['laundry 50-75%'], ['weekend False', 'season_name autumn'], ['weekend False']]
# filtered individual {'voltage 0-25%', 'season_name autumn', 'climate_control 75-100%', 'weekend False', 'global_active_power 50-75%', 'laundry 50-75%', 'attention_type_label late_attention'}
# next search
# ('Filtered rules for peak warning',
#  {'attention_type_label late_attention',
#   'climate_control 75-100%',
#   'global_active_power 50-75%',
#   'laundry 50-75%',
#   'season_name autumn',
#   'voltage 0-25%',
#   'weekend False'},
#  [['weekend False', 'attention_type_label late_attention'],
#   ['climate_control 75-100%'],
#   ['voltage 0-25%'],
#   ['weekend False', 'climate_control 75-100%'],
#   ['global_active_power 50-75%'],
#   ['weekend False', 'voltage 0-25%'],
#   ['season_name autumn'],
#   ['laundry 50-75%'],
#   ['weekend False', 'season_name autumn'],
#   ['weekend False']],
#  10)

# %% [markdown]
# OLD V2

# %%
# Filter by rhs=='No change - True'
top_k = 10

filtered_rules_individual = []
filtered_rules = []

# rule_states = set({'attention_type_label other'})
# rule_states = set({})
rule_counter = {}
association_rules_np_rhs_buffer = []
for r in range(len(association_rules_np_rhs_sorted)):
    rhs = association_rules_np_rhs_sorted[r, 1][-1]
    if(rhs=='True' and association_rules_np_rhs_sorted[r, 0]>1):
        association_rules_np_rhs_buffer.append(association_rules_np_rhs_sorted[r])
association_rules_np_rhs_buffer = np.array(association_rules_np_rhs_buffer)

# print(association_rules_np_rhs_buffer[:top_k])
for rule in association_rules_np_rhs_buffer:
    
    # print(rule)
    if top_k < 1:
        break
    if rule[-1] < 1:
        continue
    print('mined rule: ', rule[1][:-1].tolist())
    
    # # cek masing2 rule di rule[1], apakah ada duplikatnya atau enggak
    # save = True
    # for r in rule[1].tolist():
    #     # rule_states_vars = [i.split(' ')[0] for i in rule_states]
    #     rule_states_temp = rule_states | {r}
    #     # rule_states = rule_states | {r}
    #     # print(rule_states_temp)
    #     len_tmp = [i.split(' ')[0] for i in rule_states_temp]
    #     len_ori = [i.split(' ')[0] for i in rule_states]
    #     print(len_tmp, len_ori)
    #     print(len(len_tmp), len(len_ori))
    #     if (len(len_tmp) == len(len_ori)):
    #     # if (len(rule_states_temp) == len(rule_states)):
    #         print('Duplicate found', r)
    #         save = False
    #         continue
        
    # if save == False:
    #     continue
    # rule_states = rule_states | 
    top_k = top_k - 1
    filtered_rules_individual.extend(rule[1][:-1].tolist())
    filtered_rules.append(rule[1][:-1].tolist())
    print('filtered rules', filtered_rules)
    print('next search')
    print()
# filtered_rules_individual
filtered_rules
set(filtered_rules_individual) - {'True'}
# Out:
# mined rule:  ['attention_type_label other']
# filtered rules [['attention_type_label other']]
# next search
#
# mined rule:  ['activation_type_label cam_2', 'weekend False']
# filtered rules [['attention_type_label other'], ['activation_type_label cam_2', 'weekend False']]
# next search
#
# mined rule:  ['weekend False', 'attention_type_label other']
# filtered rules [['attention_type_label other'], ['activation_type_label cam_2', 'weekend False'], ['weekend False', 'attention_type_label other']]
# next search
#
# mined rule:  ['activation_type_label cam_2', 'attention_type_label other']
# filtered rules [['attention_type_label other'], ['activation_type_label cam_2', 'weekend False'], ['weekend False', 'attention_type_label other'], ['activation_type_label cam_2', 'attention_type_label other']]
# next search
#
# mined rule:  ['global_active_power 25-50%']
# filtered rules [['attention_type_label other'], ['activation_type_label cam_2', 'weekend False'], ['weekend False', 'attention_type_label other'], ['activation_type_label cam_2', 'attention_type_label other'], ['global_active_power 25-50%']]
# next search
#
# mined rule:  ['global_intensity 25-50%']
# filtered rules [['attention_type_label other'], ['activation_type_label cam_2', 'weekend False'], ['weekend False', 'attention_type_label other'], ['activation_type_label cam_2', 'attention_type_label other'], ['global_active_power 25-50%'], ['global_intensity 25-50%']]
# next search
#
# mined rule:  ['global_intensity 0-25%', 'attention_type_label other']
# filtered rules [['attention_type_label other'], ['activation_type_label cam_2', 'weekend False'], ['weekend False', 'attention_type_label other'], ['activation_type_label cam_2', 'attention_type_label other'], ['global_active_power 25-50%'], ['global_intensity 25-50%'], ['global_intensity 0-25%', 'attention_type_label other']]
# next search
#
# mined rule:  ['weekend False', 'global_intensity 50-75%']
# filtered rules [['attention_type_label other'], ['activation_type_label cam_2', 'weekend False'], ['weekend False', 'attention_type_label other'], ['activation_type_label cam_2', 'attention_type_label other'], ['global_active_power 25-50%'], ['global_intensity 25-50%'], ['global_intensity 0-25%', 'attention_type_label other'], ['weekend False', 'global_intensity 50-75%']]
# next search
#
# mined rule:  ['global_active_power 0-25%', 'attention_type_label other']
# filtered rules [['attention_type_label other'], ['activation_type_label cam_2', 'weekend False'], ['weekend False', 'attention_type_label other'], ['activation_type_label cam_2', 'attention_type_label other'], ['global_active_power 25-50%'], ['global_intensity 25-50%'], ['global_intensity 0-25%', 'attention_type_label other'], ['weekend False', 'global_intensity 50-75%'], ['global_active_power 0-25%', 'attention_type_label other']]
# next search
#
# mined rule:  ['weekend False', 'global_active_power 50-75%']
# filtered rules [['attention_type_label other'], ['activation_type_label cam_2', 'weekend False'], ['weekend False', 'attention_type_label other'], ['activation_type_label cam_2', 'attention_type_label other'], ['global_active_power 25-50%'], ['global_intensity 25-50%'], ['global_intensity 0-25%', 'attention_type_label other'], ['weekend False', 'global_intensity 50-75%'], ['global_active_power 0-25%', 'attention_type_label other'], ['weekend False', 'global_active_power 50-75%']]
# next search
# {'activation_type_label cam_2',
#  'attention_type_label other',
#  'global_active_power 0-25%',
#  'global_active_power 25-50%',
#  'global_active_power 50-75%',
#  'global_intensity 0-25%',
#  'global_intensity 25-50%',
#  'global_intensity 50-75%',
#  'weekend False'}

# %% [markdown]
# OLD

# %%
# Filter by rhs=='No change - True'
top_k = 10

filtered_rules = []
rule_states = set({})
rule_counter = {}
association_rules_np_rhs_buffer = []
for r in range(len(association_rules_np_rhs_sorted)):
    rhs = association_rules_np_rhs_sorted[r, 1][-1]
    if(rhs=='True' and association_rules_np_rhs_sorted[r, 0]>1):
        association_rules_np_rhs_buffer.append(association_rules_np_rhs_sorted[r])
association_rules_np_rhs_buffer = np.array(association_rules_np_rhs_buffer)
# print(association_rules_np_rhs_buffer[:top_k])
for rule in association_rules_np_rhs_buffer:
    # print(rule)
    if top_k < 1:
        break
    if rule[0] == 0 or rule[-1] < 1:
        continue
    
    print('Mined rule: ',rule)
    # rule_states = rule_states | (set(rule[1].tolist()) - {'True'})
    break_inside = False
    for r in set(rule[1].tolist()) - {'True'}:
        if r not in rule_counter:
            if (len(rule_counter) == False):
                rule_counter[r] = 1
            else:
                rules = rule_counter.keys()
                # cek data duplikat ngga
                rule_counter_temp = rule_counter.copy()
                rule_counter_temp[r] = 1
                fr = set(rule_counter_temp.keys()) - {'True'}
                # fr
                frs = [r.split(" ")[0] for r in fr]
                print('copy rule', rule_counter_temp)
                # if (len(frs) == )
                print('frs ', frs, list(set(frs)))
                # if set is same, then no duplicate
                if len(frs) != len(list(set(frs))):
                    print('found duplicate')
                    break_inside = True
                    break
                # print()
                rule_counter[r] = 1
        else:
            rule_counter[r] += 1
    if break_inside:
        continue
    filtered_rules.extend(rule[1].tolist())
    
    top_k = top_k - 1
    print('Found! k=', top_k)
    print('Filtered rules: ', filtered_rules)
    print('Rules counter: ', rule_counter)
    print('rule:', rule[1].tolist())
    print('')

print('unique vars')
print(set(filtered_rules) - {'True'})
print(rule_states)
print('Rule counter:')
print(rule_counter)
# Out:
# Mined rule:  [2 array(['attention_type_label other', 'True'], dtype='<U26') 0.1714
#  0.513 1.0107]
# Found! k= 9
# Filtered rules:  ['attention_type_label other', 'True']
# Rules counter:  {'attention_type_label other': 1}
# rule: ['attention_type_label other', 'True']
#
# Mined rule:  [3 array(['activation_type_label cam_2', 'weekday', 'True'], dtype='<U27')
#  0.1644 0.4921 1.1226]
# copy rule {'attention_type_label other': 1, 'activation_type_label cam_2': 1}
# frs  ['activation_type_label', 'attention_type_label'] ['attention_type_label', 'activation_type_label']
# copy rule {'attention_type_label other': 1, 'activation_type_label cam_2': 1, 'weekday': 1}
# frs  ['activation_type_label', 'attention_type_label', 'weekday'] ['attention_type_label', 'activation_type_label', 'weekday']
# Found! k= 8
# Filtered rules:  ['attention_type_label other', 'True', 'activation_type_label cam_2', 'weekday', 'True']
# Rules counter:  {'attention_type_label other': 1, 'activation_type_label cam_2': 1, 'weekday': 1}
# rule: ['activation_type_label cam_2', 'weekday', 'True']
#
# Mined rule:  [3 array(['weekday', 'attention_type_label other', 'True'], dtype='<U26')
#  0.1296 0.3881 1.039]
# Found! k= 7
# Filtered rules:  ['attention_type_label other', 'True', 'activation_type_label cam_2', 'weekday', 'True', 'weekday', 'attention_type_label other', 'True']
# Rules counter:  {'attention_type_label other': 2, 'activation_type_label cam_2': 1, 'weekday': 2}
# rule: ['weekday', 'attention_type_label other', 'True']
#
# Mined rule:  [3 array(['activation_type_label cam_2', 'attention_type_label other',
#           'True'], dtype='<U27')
#  0.1268 0.3795 1.0824]
# Found! k= 6
# Filtered rules:  ['attention_type_label other', 'True', 'activation_type_label cam_2', 'weekday', 'True', 'weekday', 'attention_type_label other', 'True', 'activation_type_label cam_2', 'attention_type_label other', 'True']
# Rules counter:  {'attention_type_label other': 3, 'activation_type_label cam_2': 2, 'weekday': 2}
# rule: ['activation_type_label cam_2', 'attention_type_label other', 'True']
#
# Mined rule:  [3 array(['weekday', 'monday', 'True'], dtype='<U7') 0.0524 0.3664 1.4972]
# copy rule {'attention_type_label other': 3, 'activation_type_label cam_2': 2, 'weekday': 2, 'monday': 1}
# frs  ['activation_type_label', 'monday', 'attention_type_label', 'weekday'] ['attention_type_label', 'activation_type_label', 'monday', 'weekday']
# Found! k= 5
# Filtered rules:  ['attention_type_label other', 'True', 'activation_type_label cam_2', 'weekday', 'True', 'weekday', 'attention_type_label other', 'True', 'activation_type_label cam_2', 'attention_type_label other', 'True', 'weekday', 'monday', 'True']
# Rules counter:  {'attention_type_label other': 3, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 1}
# rule: ['weekday', 'monday', 'True']
#
# Mined rule:  [2 array(['monday', 'True'], dtype='<U6') 0.0524 0.3664 1.0968]
# Found! k= 4
# Filtered rules:  ['attention_type_label other', 'True', 'activation_type_label cam_2', 'weekday', 'True', 'weekday', 'attention_type_label other', 'True', 'activation_type_label cam_2', 'attention_type_label other', 'True', 'weekday', 'monday', 'True', 'monday', 'True']
# Rules counter:  {'attention_type_label other': 3, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2}
# rule: ['monday', 'True']
#
# Mined rule:  [2 array(['global_intensity 25-50%', 'True'], dtype='<U23') 0.1059 0.317
#  1.2181]
# copy rule {'attention_type_label other': 3, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1}
# frs  ['activation_type_label', 'global_intensity', 'monday', 'attention_type_label', 'weekday'] ['monday', 'weekday', 'attention_type_label', 'activation_type_label', 'global_intensity']
# Found! k= 3
# Filtered rules:  ['attention_type_label other', 'True', 'activation_type_label cam_2', 'weekday', 'True', 'weekday', 'attention_type_label other', 'True', 'activation_type_label cam_2', 'attention_type_label other', 'True', 'weekday', 'monday', 'True', 'monday', 'True', 'global_intensity 25-50%', 'True']
# Rules counter:  {'attention_type_label other': 3, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1}
# rule: ['global_intensity 25-50%', 'True']
#
# Mined rule:  [2 array(['global_active_power 25-50%', 'True'], dtype='<U26') 0.1059
#  0.317 1.184]
# copy rule {'attention_type_label other': 3, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1, 'global_active_power 25-50%': 1}
# frs  ['activation_type_label', 'global_intensity', 'monday', 'global_active_power', 'attention_type_label', 'weekday'] ['global_active_power', 'monday', 'weekday', 'attention_type_label', 'activation_type_label', 'global_intensity']
# Found! k= 2
# Filtered rules:  ['attention_type_label other', 'True', 'activation_type_label cam_2', 'weekday', 'True', 'weekday', 'attention_type_label other', 'True', 'activation_type_label cam_2', 'attention_type_label other', 'True', 'weekday', 'monday', 'True', 'monday', 'True', 'global_intensity 25-50%', 'True', 'global_active_power 25-50%', 'True']
# Rules counter:  {'attention_type_label other': 3, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1, 'global_active_power 25-50%': 1}
# rule: ['global_active_power 25-50%', 'True']
#
# Mined rule:  [3 array(['global_intensity 0-25%', 'attention_type_label other', 'True'],
#          dtype='<U26')
#  0.0541 0.3159 1.0049]
# copy rule {'attention_type_label other': 3, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1, 'global_active_power 25-50%': 1, 'global_intensity 0-25%': 1}
# frs  ['activation_type_label', 'global_intensity', 'monday', 'global_active_power', 'attention_type_label', 'weekday', 'global_intensity'] ['global_active_power', 'monday', 'weekday', 'attention_type_label', 'activation_type_label', 'global_intensity']
# found duplicate
# Mined rule:  [3 array(['weekday', 'global_intensity 50-75%', 'True'], dtype='<U23')
#  0.0648 0.3148 1.2863]
# copy rule {'attention_type_label other': 3, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1, 'global_active_power 25-50%': 1, 'global_intensity 50-75%': 1}
# frs  ['activation_type_label', 'global_intensity', 'global_intensity', 'monday', 'global_active_power', 'attention_type_label', 'weekday'] ['global_active_power', 'monday', 'weekday', 'attention_type_label', 'activation_type_label', 'global_intensity']
# found duplicate
# Mined rule:  [3
#  array(['global_active_power 0-25%', 'attention_type_label other', 'True'],
#        dtype='<U26')
#  0.0538 0.3141 1.022]
# copy rule {'attention_type_label other': 4, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1, 'global_active_power 25-50%': 1, 'global_active_power 0-25%': 1}
# frs  ['activation_type_label', 'global_intensity', 'monday', 'global_active_power', 'attention_type_label', 'weekday', 'global_active_power'] ['global_active_power', 'monday', 'weekday', 'attention_type_label', 'activation_type_label', 'global_intensity']
# found duplicate
# Mined rule:  [3 array(['weekday', 'global_active_power 50-75%', 'True'], dtype='<U26')
#  0.0647 0.3138 1.2824]
# copy rule {'attention_type_label other': 4, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1, 'global_active_power 25-50%': 1, 'global_active_power 50-75%': 1}
# frs  ['activation_type_label', 'global_intensity', 'monday', 'global_active_power', 'global_active_power', 'attention_type_label', 'weekday'] ['global_active_power', 'monday', 'weekday', 'attention_type_label', 'activation_type_label', 'global_intensity']
# found duplicate
# Mined rule:  [3 array(['voltage 75-100%', 'attention_type_label other', 'True'],
#          dtype='<U26')                                              0.0533
#  0.311 1.0308]
# copy rule {'attention_type_label other': 4, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1, 'global_active_power 25-50%': 1, 'voltage 75-100%': 1}
# frs  ['activation_type_label', 'global_intensity', 'voltage', 'monday', 'global_active_power', 'attention_type_label', 'weekday'] ['global_active_power', 'monday', 'weekday', 'attention_type_label', 'voltage', 'activation_type_label', 'global_intensity']
# Found! k= 1
# Filtered rules:  ['attention_type_label other', 'True', 'activation_type_label cam_2', 'weekday', 'True', 'weekday', 'attention_type_label other', 'True', 'activation_type_label cam_2', 'attention_type_label other', 'True', 'weekday', 'monday', 'True', 'monday', 'True', 'global_intensity 25-50%', 'True', 'global_active_power 25-50%', 'True', 'voltage 75-100%', 'attention_type_label other', 'True']
# Rules counter:  {'attention_type_label other': 5, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1, 'global_active_power 25-50%': 1, 'voltage 75-100%': 1}
# rule: ['voltage 75-100%', 'attention_type_label other', 'True']
#
# Mined rule:  [2 array(['attention_type_label late_attention', 'True'], dtype='<U35')
#  0.1022 0.3061 1.1219]
# copy rule {'attention_type_label other': 5, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1, 'global_active_power 25-50%': 1, 'voltage 75-100%': 1, 'attention_type_label late_attention': 1}
# frs  ['activation_type_label', 'attention_type_label', 'global_intensity', 'voltage', 'monday', 'global_active_power', 'attention_type_label', 'weekday'] ['global_active_power', 'monday', 'weekday', 'attention_type_label', 'voltage', 'activation_type_label', 'global_intensity']
# found duplicate
# Mined rule:  [4
#  array(['global_intensity 50-75%', 'weekday', 'global_active_power 50-75%',
#         'True'], dtype='<U26')
#  0.0625 0.3031 4.6781]
# copy rule {'attention_type_label other': 5, 'activation_type_label cam_2': 2, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1, 'global_active_power 25-50%': 1, 'voltage 75-100%': 1, 'global_intensity 50-75%': 1}
# frs  ['activation_type_label', 'global_intensity', 'global_intensity', 'voltage', 'monday', 'global_active_power', 'attention_type_label', 'weekday'] ['global_active_power', 'monday', 'weekday', 'attention_type_label', 'voltage', 'activation_type_label', 'global_intensity']
# found duplicate
# Mined rule:  [3 array(['activation_type_label cam_2', 'global_active_power 25-50%',
#           'True'], dtype='<U27')
#  0.0996 0.2981 1.2019]
# Found! k= 0
# Filtered rules:  ['attention_type_label other', 'True', 'activation_type_label cam_2', 'weekday', 'True', 'weekday', 'attention_type_label other', 'True', 'activation_type_label cam_2', 'attention_type_label other', 'True', 'weekday', 'monday', 'True', 'monday', 'True', 'global_intensity 25-50%', 'True', 'global_active_power 25-50%', 'True', 'voltage 75-100%', 'attention_type_label other', 'True', 'activation_type_label cam_2', 'global_active_power 25-50%', 'True']
# Rules counter:  {'attention_type_label other': 5, 'activation_type_label cam_2': 3, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1, 'global_active_power 25-50%': 2, 'voltage 75-100%': 1}
# rule: ['activation_type_label cam_2', 'global_active_power 25-50%', 'True']
#
# unique vars
# {'activation_type_label cam_2', 'global_intensity 25-50%', 'voltage 75-100%', 'monday', 'global_active_power 25-50%', 'attention_type_label other', 'weekday'}
# set()
# Rule counter:
# {'attention_type_label other': 5, 'activation_type_label cam_2': 3, 'weekday': 3, 'monday': 2, 'global_intensity 25-50%': 1, 'global_active_power 25-50%': 2, 'voltage 75-100%': 1}

# %%
# Out:
# ['other',
#  'global_intensity 0-25%',
#  'True',
#  'other',
#  'global_active_power 0-25%',
#  'True',
#  'other',
#  'climate_control 0-25%',
#  'True',
#  'other',
#  'True',
#  'cam_2',
#  'weekday',
#  'True',
#  'other',
#  'weekday',
#  'True',
#  'cam_2',
#  'other',
#  'True',
#  'monday',
#  'True',
#  'weekday',
#  'monday',
#  'True',
#  'other',
#  'voltage 75-100%',
#  'True']

# %%
dup = ['other', 'climate_control', 'monday', 'global_active_power', 'cam_2', 'global_intensity', 'weekday'] 
# ['other', 'global_active_power', 'monday', 'climate_control', 'cam_2', 'weekday', 'global_intensity']
len(set(dup)), len(dup) # (7, 8) duplicate
len(set(dup)), len(dup) # (7, 7) aman banget
# Out:
# (7, 7)

# %%
rule_counter = {'other': 1, 'climate_control 0-25%':1, 'monday':1, 'global_active_power 25-50%':1, 'cam_2':1, 'global_intensity 0-25%':1, 'weekday':1, 'global_active_power 0-25%':1}
list(rule_counter.keys())
# Out:
# ['other',
#  'climate_control 0-25%',
#  'monday',
#  'global_active_power 25-50%',
#  'cam_2',
#  'global_intensity 0-25%',
#  'weekday',
#  'global_active_power 0-25%']

# %%
fr = set(rule_counter.keys()) - {'True'}
# fr
frs = [r.split(" ")[0] for r in fr]

frs, list(set(frs))
# Out:
# (['other',
#   'climate_control',
#   'monday',
#   'global_active_power',
#   'cam_2',
#   'global_intensity',
#   'weekday',
#   'global_active_power'],
#  ['other',
#   'global_active_power',
#   'monday',
#   'climate_control',
#   'cam_2',
#   'weekday',
#   'global_intensity'])
