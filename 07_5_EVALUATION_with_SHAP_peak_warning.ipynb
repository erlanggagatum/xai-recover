# %% [markdown]
# #### This is final evaluation

# %%
import sys
sys.path.append('../src')
# from causal_shapley import causal_shapley, predict_proba
from egtoolkit import *
# %load_ext autoreload
# %autoreload 2

from egtoolkit import *

import random
import warnings
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
import itertools
from itertools import combinations, permutations, chain

import shap

warnings.filterwarnings("ignore")
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns

from imblearn.under_sampling import RandomUnderSampler

from pgmpy.models import BayesianNetwork
from pgmpy.inference import VariableElimination
from pgmpy.factors.discrete.CPD import TabularCPD
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Import dataset

# %%
categorical_cols = ['global_active_power', 'global_reactive_power', 'voltage',
                    'global_intensity', 'kitchen', 'laundry', 'climate_control', 'other',
                    'weekend', 'month_name', 'season_name', 'day_name']  # list all columns that are categorical

# %%
dataset = pd.read_csv('./datasets/2.0-discretized-v2-3-peak-label-encoded.csv')

# %%
dataset[['peak_warning']].values
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
targets = ['peak_label_pred', 'peak_warning', 'no_significant_change', 'lower_than_usual']
targets_only = ['peak_label_pred', 'no_significant_change', 'lower_than_usual']

# %%
dataset.columns
# Out:
# Index(['global_active_power', 'global_reactive_power', 'voltage',
#        'global_intensity', 'kitchen', 'laundry', 'climate_control', 'other',
#        'weekend', 'month_name', 'season_name', 'day_name', 'peak_label_pred',
#        'peak_warning', 'no_significant_change', 'lower_than_usual'],
#       dtype='object')

# %%
dataset['peak_warning'].values
# Out:
# array([False, False, False, ..., False, False, False])

# %%
dataset.shape
# Out:
# (41673, 16)

# %%
sample = 50
background = dataset.drop(columns=targets).sample(sample, random_state=4)
indexes = background.index.tolist()
dataset.iloc[indexes]
# Out:
#       global_active_power global_reactive_power    voltage global_intensity  \
# 38128                 Low                Medium       High              Low
# 34353              Medium                   Low     Medium           Medium
# 24951           Very High                  High        Low        Very High
# 32779                 Low                   Low       High              Low
# 37580                 Low                Medium        Low              Low
# 14887           Very High             Very High        Low        Very High
# 4375               Medium                Medium       High           Medium
# 12741                 Low                   Low     Medium              Low
# 27682                High                  High        Low             High
# 8848            Very High                   Low       High        Very High
# 21412           Very High             Very High     Medium        Very High
# 26850                 Low                Medium       High              Low
# 15237           Very High                   Low        Low        Very High
# 5977                 High                Medium        Low             High
# 3116            Very High                Medium        Low        Very High
# 13789           Very High                  High       High             High
# 28056                 Low                   Low       High              Low
# 21211                High                  High        Low             High
# 16250                High                   Low       High             High
# 32623                 Low                   Low  Very High              Low
# 25986                High                Medium        Low             High
# 5349            Very High             Very High        Low        Very High
# 36995              Medium             Very High       High           Medium
# 25617           Very High             Very High     Medium        Very High
# 27722              Medium             Very High       High           Medium
# 31678                High                  High        Low             High
# 31998                 Low                Medium        Low              Low
# 14512                 Low             Very High       High              Low
# 9965               Medium                Medium       High           Medium
# 32760              Medium             Very High     Medium           Medium
# 11917              Medium             Very High     Medium           Medium
# 15052           Very High             Very High        Low        Very High
# 18148           Very High             Very High     Medium        Very High
# 25747           Very High                   Low        Low        Very High
# 3426                 High                   Low       High             High
# 11425                 Low                   Low       High              Low
# 11971                High                  High  Very High             High
# 1328               Medium             Very High       High           Medium
# 36787                 Low                   Low  Very High              Low
# 29987              Medium                   Low  Very High           Medium
# 3792               Medium                   Low     Medium           Medium
# 12310              Medium                  High       High           Medium
# 1028                  Low             Very High       High           Medium
# 40097                 Low                  High       High              Low
# 40011              Medium                  High  Very High           Medium
# 12001           Very High                  High        Low        Very High
# 38061                High             Very High     Medium             High
# 38605              Medium             Very High     Medium           Medium
# 21046           Very High                   Low        Low        Very High
# 31771                High             Very High  Very High             High
#
#          kitchen    laundry climate_control      other  weekend month_name  \
# 38128     Medium     Medium          Medium        Low     True  september
# 34353     Medium        Low            High        Low    False  september
# 24951        Low  Very High            High  Very High     True      april
# 32779        Low        Low             Low     Medium    False    january
# 37580        Low        Low             Low        Low    False       july
# 14887  Very High  Very High       Very High  Very High     True    october
# 4375      Medium        Low             Low       High    False      march
# 12741  Very High       High            High        Low    False  september
# 27682  Very High       High       Very High     Medium    False        may
# 8848      Medium       High       Very High  Very High    False    january
# 21412       High     Medium       Very High  Very High    False   february
# 26850       High     Medium          Medium        Low    False       july
# 15237  Very High  Very High            High  Very High     True    january
# 5977      Medium  Very High            High       High     True        may
# 3116      Medium  Very High       Very High       High    False      march
# 13789       High  Very High       Very High     Medium    False        may
# 28056       High     Medium          Medium        Low    False   november
# 21211  Very High  Very High          Medium  Very High     True       july
# 16250       High       High       Very High     Medium    False   february
# 32623       High     Medium            High        Low    False    january
# 25986        Low        Low            High        Low    False      april
# 5349        High     Medium       Very High  Very High    False      march
# 36995       High     Medium            High        Low     True     august
# 25617     Medium       High            High  Very High    False   february
# 27722       High     Medium            High        Low    False     august
# 31678     Medium  Very High             Low  Very High    False    january
# 31998        Low       High             Low     Medium     True   november
# 14512        Low  Very High             Low        Low    False     august
# 9965      Medium     Medium             Low       High    False    january
# 32760        Low  Very High             Low     Medium     True       june
# 11917     Medium        Low          Medium       High    False  september
# 15052     Medium       High       Very High  Very High    False  september
# 18148  Very High       High       Very High       High    False      april
# 25747        Low        Low       Very High  Very High    False    january
# 3426      Medium     Medium       Very High       High    False   december
# 11425     Medium       High          Medium        Low    False       july
# 11971  Very High       High       Very High     Medium    False   november
# 1328         Low       High             Low       High     True    october
# 36787     Medium       High             Low     Medium    False   december
# 29987       High     Medium          Medium       High    False   december
# 3792        High     Medium          Medium       High    False        may
# 12310       High     Medium            High        Low    False     august
# 1028      Medium       High          Medium        Low    False       june
# 40097        Low        Low             Low        Low    False     august
# 40011       High     Medium            High     Medium    False      march
# 12001     Medium     Medium            High       High     True   november
# 38061  Very High       High          Medium       High     True  september
# 38605       High  Very High            High     Medium    False      march
# 21046  Very High        Low            High     Medium    False        may
# 31771       High  Very High       Very High     Medium     True   february
#
#       season_name   day_name        peak_label_pred  peak_warning  \
# 38128      autumn     sunday       lower_than_usual         False
# 34353      autumn    tuesday       lower_than_usual         False
# 24951      spring   saturday           peak_warning          True
# 32779      winter     monday       lower_than_usual         False
# 37580      summer     friday       lower_than_usual         False
# 14887      autumn     sunday           peak_warning          True
# 4375       spring    tuesday  no_significant_change         False
# 12741      autumn   thursday  no_significant_change         False
# 27682      spring     friday           peak_warning          True
# 8848       winter  wednesday  no_significant_change         False
# 21412      winter    tuesday           peak_warning          True
# 26850      summer     friday           peak_warning          True
# 15237      winter     sunday           peak_warning          True
# 5977       spring     sunday  no_significant_change         False
# 3116       spring     monday  no_significant_change         False
# 13789      spring   thursday  no_significant_change         False
# 28056      autumn  wednesday       lower_than_usual         False
# 21211      summer     sunday           peak_warning          True
# 16250      winter     friday           peak_warning          True
# 32623      winter  wednesday       lower_than_usual         False
# 25986      spring   thursday           peak_warning          True
# 5349       spring     friday  no_significant_change         False
# 36995      summer     sunday       lower_than_usual         False
# 25617      winter   thursday           peak_warning          True
# 27722      summer     monday           peak_warning          True
# 31678      winter   thursday       lower_than_usual         False
# 31998      autumn   saturday       lower_than_usual         False
# 14512      summer     friday           peak_warning          True
# 9965       winter     friday  no_significant_change         False
# 32760      summer   saturday       lower_than_usual         False
# 11917      autumn  wednesday  no_significant_change         False
# 15052      autumn  wednesday           peak_warning          True
# 18148      spring  wednesday           peak_warning          True
# 25747      winter  wednesday           peak_warning          True
# 3426       winter     monday  no_significant_change         False
# 11425      summer  wednesday  no_significant_change         False
# 11971      autumn     monday  no_significant_change         False
# 1328       autumn   saturday  no_significant_change         False
# 36787      winter  wednesday       lower_than_usual         False
# 29987      winter    tuesday       lower_than_usual         False
# 3792       spring  wednesday  no_significant_change         False
# 12310      summer     monday  no_significant_change         False
# 1028       summer     friday  no_significant_change         False
# 40097      summer     friday       lower_than_usual         False
# 40011      spring     friday       lower_than_usual         False
# 12001      autumn     sunday  no_significant_change         False
# 38061      autumn     sunday       lower_than_usual         False
# 38605      spring   thursday       lower_than_usual         False
# 21046      spring     friday           peak_warning          True
# 31771      winter     sunday       lower_than_usual         False
#
#        no_significant_change  lower_than_usual
# 38128                  False              True
# 34353                  False              True
# 24951                  False             False
# 32779                  False              True
# 37580                  False              True
# 14887                  False             False
# 4375                    True             False
# 12741                   True             False
# 27682                  False             False
# 8848                    True             False
# 21412                  False             False
# 26850                  False             False
# 15237                  False             False
# 5977                    True             False
# 3116                    True             False
# 13789                   True             False
# 28056                  False              True
# 21211                  False             False
# 16250                  False             False
# 32623                  False              True
# 25986                  False             False
# 5349                    True             False
# 36995                  False              True
# 25617                  False             False
# 27722                  False             False
# 31678                  False              True
# 31998                  False              True
# 14512                  False             False
# 9965                    True             False
# 32760                  False              True
# 11917                   True             False
# 15052                  False             False
# 18148                  False             False
# 25747                  False             False
# 3426                    True             False
# 11425                   True             False
# 11971                   True             False
# 1328                    True             False
# 36787                  False              True
# 29987                  False              True
# 3792                    True             False
# 12310                   True             False
# 1028                    True             False
# 40097                  False              True
# 40011                  False              True
# 12001                   True             False
# 38061                  False              True
# 38605                  False              True
# 21046                  False             False
# 31771                  False              True

# %%
_data = dataset.drop(columns=targets_only)

def find_outcome(observation):
    # Iterate through each record in the data
    # print(len(data.values))
    for record in _data.values:
        # print('obs', observation)
        if (record[:-1] == observation).all():
            # print('Found!')
            # print('Record: ', record)
            # print('Observation: ', observation)
            return record[-1]  # Return the last item (True/False) if there's a match
    return None  # Return None if  no match is found

def custom_predict(data):
    # Debugging to check input data shape
    print('=================')
    # print("Input shape to custom_predict:", data.shape)
    # if data.shape[0] == 621600:
    #     print(data)

    # Assuming boolean to integer conversion as before
    predictions = []
    # encode = {True: 1.0, False: 0.0}
    encode = {True: 1.0, False: 0.0, None: random.uniform(0.4, 0.6)}
    if isinstance(data, pd.DataFrame):
        print('dataframe instance')
        predictions = data['peak_warning'].apply(lambda x: encode[x]).values
    else:
        print('non dataframe instance')
        # predictions = np.array([encode[bool(p)] for p in data[:, -1]])
        # print(predictions)
        # print(p)
        print(f'Finding outcome based on prediction result with data Shape {data.shape}...')
        for observation in data[:,:]:
            predictions.append(encode[find_outcome(observation)])
            # print(predictions)
            # break
        # print(predictions)
        predictions = np.array(predictions)
        
    # print('data', data)
    
    # Ensure the output is correctly shaped
    predictions = predictions.reshape(-1, 1)
    print("Output shape from custom_predict:", predictions.shape)
    print('Done...')
    print('')
    return predictions
explainer = shap.KernelExplainer(custom_predict, background)
# Out:
# =================
# non dataframe instance
# Finding outcome based on prediction result with data Shape (50, 12)...
# Output shape from custom_predict: (50, 1)
# Done...

# %% [markdown]
# TEST BASED ON EVIDENCE (FROM ARM)

# %%
observation_peak = dataset[(dataset.global_active_power == 'High') &
        (dataset.climate_control == 'Very High') &
        (dataset.laundry == 'High') &
        (dataset.season_name == 'autumn') &
        (dataset.voltage == 'Low') &
        (dataset.weekend == False) &
        (dataset.peak_warning == True) 
        ].iloc[:1,:]
observation_peak.drop(columns=['peak_label_pred','peak_warning','no_significant_change','lower_than_usual'], inplace=True)
# print(pd.DataFrame(observation_peak))

# %%
print("Observation shape before SHAP:", observation_peak.shape)
print('Observation:', observation_peak)

try:
    shap_values = explainer.shap_values(observation_peak)
    # shap_values = explainer.shap_values(background.iloc[0])
except Exception as e:
    print("Error during SHAP computation:", e)
# # (10360, 1)
# Out:
# Observation shape before SHAP: (1, 12)
# Observation:       global_active_power global_reactive_power voltage global_intensity  \
# 13916                High                   Low     Low             High
#
#       kitchen laundry climate_control other  weekend month_name season_name  \
# 13916  Medium    High       Very High  High    False  september      autumn
#
#       day_name
# 13916   friday
#   0%|          | 0/1 [00:00<?, ?it/s]INFO:shap:num_full_subsets = 3
# INFO:shap:remaining_weight_vector = array([0.35673839, 0.32616082, 0.31710079])
# INFO:shap:num_paired_subset_sizes = 5
# INFO:shap:weight_left = 0.2929005745959313
# =================
# non dataframe instance
# Finding outcome based on prediction result with data Shape (1, 12)...
# Output shape from custom_predict: (1, 1)
# Done...
#
# =================
# non dataframe instance
# Finding outcome based on prediction result with data Shape (103600, 12)...

# %%
observation_peak.iloc[0], shap_values
# Out:
# (global_active_power           High
#  global_reactive_power       Medium
#  voltage                        Low
#  global_intensity         Very High
#  kitchen                  Very High
#  laundry                  Very High
#  climate_control          Very High
#  other                    Very High
#  weekend                       True
#  month_name               september
#  season_name                 autumn
#  day_name                    sunday
#  Name: 0, dtype: object,
#  [array([[0.01695862, 0.01518858, 0.0315374 , 0.02940806, 0.03120862,
#           0.02077708, 0.02532081, 0.03246558, 0.02024132, 0.01981452,
#           0.01466551, 0.01899645]])])

# %%
data = background.values

# %%
data = dataset.drop(columns=targets_only)
data
# Out:
#       global_active_power global_reactive_power    voltage global_intensity  \
# 0               Very High                   Low        Low        Very High
# 1                    High                   Low       High             High
# 2               Very High                  High       High        Very High
# 3                     Low                   Low        Low              Low
# 4               Very High                   Low  Very High        Very High
# ...                   ...                   ...        ...              ...
# 41668                 Low                   Low  Very High              Low
# 41669              Medium                Medium  Very High           Medium
# 41670              Medium             Very High       High           Medium
# 41671                 Low                   Low  Very High              Low
# 41672                 Low                   Low       High              Low
#
#       kitchen laundry climate_control      other  weekend month_name  \
# 0        High  Medium            High  Very High     True      march
# 1         Low     Low            High       High    False    january
# 2      Medium  Medium       Very High  Very High    False    january
# 3      Medium     Low             Low     Medium    False   february
# 4         Low     Low             Low  Very High     True   december
# ...       ...     ...             ...        ...      ...        ...
# 41668     Low     Low             Low     Medium     True    january
# 41669    High  Medium          Medium       High    False   february
# 41670     Low    High             Low       High    False      april
# 41671    High    High          Medium        Low     True    january
# 41672     Low     Low             Low        Low    False  september
#
#       season_name  day_name  peak_warning
# 0          spring  saturday         False
# 1          winter  thursday         False
# 2          winter    friday         False
# 3          winter    friday         False
# 4          winter  saturday         False
# ...           ...       ...           ...
# 41668      winter  saturday         False
# 41669      winter   tuesday         False
# 41670      spring   tuesday         False
# 41671      winter  saturday         False
# 41672      autumn   tuesday         False
#
# [41673 rows x 13 columns]

# %%
rand_state = 10
observation = data.sample(5, random_state=rand_state).iloc[:,:-1].values
real_target = data.sample(5, random_state=rand_state).iloc[:,-1].values
real_target
# Out:
# array([False, False, False,  True, False])

# %% [markdown]
# mimic predict method

# %%
def find_outcome(data, observation):
    # Iterate through each record in the data
    # print(len(data.values))
    for record in data.values:
        # print('obs', observation)
        if (record[:-1] == observation).all():
            print('Found!')
            print('Record: ', record)
            print('Observation: ', observation)
            return record[-1]  # Return the last item (True/False) if there's a match
    return None  # Return None if  no match is found

# for obs in observation:
# print(observation)
for obs in observation:
    outcome = find_outcome(data, obs)
    print('outcome', outcome)
    # print("The outcome for observation", obs, "is:", outcome)
# Out:
# Found!
# Record:  ['Low' 'Medium' 'Very High' 'Low' 'Very High' 'High' 'High' 'Medium' False
#  'june' 'summer' 'monday' False]
# Observation:  ['Low' 'Medium' 'Very High' 'Low' 'Very High' 'High' 'High' 'Medium' False
#  'june' 'summer' 'monday']
# outcome False
# Found!
# Record:  ['Very High' 'Very High' 'High' 'Very High' 'Medium' 'Very High' 'Low'
#  'Medium' False 'march' 'spring' 'monday' False]
# Observation:  ['Very High' 'Very High' 'High' 'Very High' 'Medium' 'Very High' 'Low'
#  'Medium' False 'march' 'spring' 'monday']
# outcome False
# Found!
# Record:  ['Medium' 'High' 'High' 'Medium' 'Low' 'Very High' 'Low' 'Medium' False
#  'august' 'summer' 'friday' False]
# Observation:  ['Medium' 'High' 'High' 'Medium' 'Low' 'Very High' 'Low' 'Medium' False
#  'august' 'summer' 'friday']
# outcome False
# Found!
# Record:  ['Very High' 'High' 'Low' 'Very High' 'Very High' 'High' 'Very High'
#  'Very High' False 'october' 'autumn' 'tuesday' True]
# Observation:  ['Very High' 'High' 'Low' 'Very High' 'Very High' 'High' 'Very High'
#  'Very High' False 'october' 'autumn' 'tuesday']
# outcome True
# Found!
# Record:  ['Very High' 'Medium' 'Low' 'Very High' 'Very High' 'Very High' 'High'
#  'High' False 'december' 'winter' 'thursday' False]
# Observation:  ['Very High' 'Medium' 'Low' 'Very High' 'Very High' 'Very High' 'High'
#  'High' False 'december' 'winter' 'thursday']
# outcome False

# %% [markdown]
# old

# %%
def find_outcome(data, observation):
    # Iterate through each record in the data
    for record in data:
        if (record[:-1] == observation.values[0][:-1]).all():
            return record[-1]  # Return the last item (True/False) if there's a match
    return None  # Return None if  no match is found

outcome = find_outcome(data, observation)
print("The outcome for observation", observation, "is:", outcome)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[204], line 8
#       5             return record[-1]  # Return the last item (True/False) if there's a match
#       6     return None  # Return None if  no match is found
# ----> 8 outcome = find_outcome(data, observation)
#       9 print("The outcome for observation", observation, "is:", outcome)
#
# Cell In[204], line 4, in find_outcome(data, observation)
#       1 def find_outcome(data, observation):
#       2     # Iterate through each record in the data
#       3     for record in data:
# ----> 4         if (record[:-1] == observation.values[0][:-1]).all():
#       5             return record[-1]  # Return the last item (True/False) if there's a match
#       6     return None
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'
