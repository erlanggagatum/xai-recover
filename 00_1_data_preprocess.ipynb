# %%
# from softcomputing_packages_bu import *
from apyori import apriori
import pandas as pd
import numpy as np
import copy
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Load dataset
hc_csv_raw = pd.read_csv('./datasets/2.0-discretized-v2-2-2-with-label-resampled-and-DLP.csv').drop(columns=['Unnamed: 0'])
hc_csv_raw.head()
len(hc_csv_raw)
# Out:
# 41673

# %%
hc_csv_raw['peak_warning'] = hc_csv_raw['peak_label_pred'].apply(lambda x: 'true' if x == 'peak_warning' else 'false')
hc_csv_raw['no_significant_change'] = hc_csv_raw['peak_label_pred'].apply(lambda x: 'true' if x == 'no_significant_change' else 'false')
hc_csv_raw['lower_than_usual'] = hc_csv_raw['peak_label_pred'].apply(lambda x: 'true' if x == 'lower_than_usual' else 'false')
hc_csv_raw
# Out:
#       global_active_power global_reactive_power    voltage global_intensity  \
# 0               Very High                   Low        Low        Very High
# 1                    High                   Low       High             High
# 2               Very High                  High       High        Very High
# 3                     Low                   Low        Low              Low
# 4               Very High                   Low  Very High        Very High
# ...                   ...                   ...        ...              ...
# 41668                 Low                   Low  Very High              Low
# 41669              Medium                Medium  Very High           Medium
# 41670              Medium             Very High       High           Medium
# 41671                 Low                   Low  Very High              Low
# 41672                 Low                   Low       High              Low
#
#       kitchen laundry climate_control      other  weekend month_name  \
# 0        High  Medium            High  Very High     True      march
# 1         Low     Low            High       High    False    january
# 2      Medium  Medium       Very High  Very High    False    january
# 3      Medium     Low             Low     Medium    False   february
# 4         Low     Low             Low  Very High     True   december
# ...       ...     ...             ...        ...      ...        ...
# 41668     Low     Low             Low     Medium     True    january
# 41669    High  Medium          Medium       High    False   february
# 41670     Low    High             Low       High    False      april
# 41671    High    High          Medium        Low     True    january
# 41672     Low     Low             Low        Low    False  september
#
#       season_name  day_name        peak_label_pred attention_type_label  \
# 0          spring  saturday  no_significant_change      early_attention
# 1          winter  thursday  no_significant_change                other
# 2          winter    friday  no_significant_change      early_attention
# 3          winter    friday  no_significant_change       late_attention
# 4          winter  saturday  no_significant_change      early_attention
# ...           ...       ...                    ...                  ...
# 41668      winter  saturday       lower_than_usual       late_attention
# 41669      winter   tuesday       lower_than_usual                other
# 41670      spring   tuesday       lower_than_usual                other
# 41671      winter  saturday       lower_than_usual       late_attention
# 41672      autumn   tuesday       lower_than_usual       late_attention
#
#       activation_type_label peak_warning no_significant_change  \
# 0                     cam_1        false                  true
# 1                     cam_1        false                  true
# 2                     cam_1        false                  true
# 3                     cam_2        false                  true
# 4                     cam_1        false                  true
# ...                     ...          ...                   ...
# 41668                 cam_2        false                 false
# 41669                 cam_2        false                 false
# 41670                 cam_2        false                 false
# 41671                 cam_2        false                 false
# 41672                 cam_2        false                 false
#
#       lower_than_usual
# 0                false
# 1                false
# 2                false
# 3                false
# 4                false
# ...                ...
# 41668             true
# 41669             true
# 41670             true
# 41671             true
# 41672             true
#
# [41673 rows x 18 columns]

# %%
hc_csv_raw.to_csv('./datasets/2.0-discretized-v2-2-2-with-label-resampled-and-DLP-encoded.csv', index=False)
hc_csv_raw
# Out:
#       global_active_power global_reactive_power    voltage global_intensity  \
# 0               Very High                   Low        Low        Very High
# 1                    High                   Low       High             High
# 2               Very High                  High       High        Very High
# 3                     Low                   Low        Low              Low
# 4               Very High                   Low  Very High        Very High
# ...                   ...                   ...        ...              ...
# 41668                 Low                   Low  Very High              Low
# 41669              Medium                Medium  Very High           Medium
# 41670              Medium             Very High       High           Medium
# 41671                 Low                   Low  Very High              Low
# 41672                 Low                   Low       High              Low
#
#       kitchen laundry climate_control      other  weekend month_name  \
# 0        High  Medium            High  Very High     True      march
# 1         Low     Low            High       High    False    january
# 2      Medium  Medium       Very High  Very High    False    january
# 3      Medium     Low             Low     Medium    False   february
# 4         Low     Low             Low  Very High     True   december
# ...       ...     ...             ...        ...      ...        ...
# 41668     Low     Low             Low     Medium     True    january
# 41669    High  Medium          Medium       High    False   february
# 41670     Low    High             Low       High    False      april
# 41671    High    High          Medium        Low     True    january
# 41672     Low     Low             Low        Low    False  september
#
#       season_name  day_name        peak_label_pred attention_type_label  \
# 0          spring  saturday  no_significant_change      early_attention
# 1          winter  thursday  no_significant_change                other
# 2          winter    friday  no_significant_change      early_attention
# 3          winter    friday  no_significant_change       late_attention
# 4          winter  saturday  no_significant_change      early_attention
# ...           ...       ...                    ...                  ...
# 41668      winter  saturday       lower_than_usual       late_attention
# 41669      winter   tuesday       lower_than_usual                other
# 41670      spring   tuesday       lower_than_usual                other
# 41671      winter  saturday       lower_than_usual       late_attention
# 41672      autumn   tuesday       lower_than_usual       late_attention
#
#       activation_type_label peak_warning no_significant_change  \
# 0                     cam_1        false                  true
# 1                     cam_1        false                  true
# 2                     cam_1        false                  true
# 3                     cam_2        false                  true
# 4                     cam_1        false                  true
# ...                     ...          ...                   ...
# 41668                 cam_2        false                 false
# 41669                 cam_2        false                 false
# 41670                 cam_2        false                 false
# 41671                 cam_2        false                 false
# 41672                 cam_2        false                 false
#
#       lower_than_usual
# 0                false
# 1                false
# 2                false
# 3                false
# 4                false
# ...                ...
# 41668             true
# 41669             true
# 41670             true
# 41671             true
# 41672             true
#
# [41673 rows x 18 columns]

# %%
# Sampling (for Development)
n_sample = 30000
hc_csv = hc_csv_raw.sample(frac=1, random_state=42)
hc_csv = hc_csv.iloc[:n_sample]
hc_csv.head()
# Out:
#       global_active_power global_reactive_power    voltage global_intensity  \
# 35103              Medium             Very High  Very High           Medium
# 8049                  Low                  High  Very High              Low
# 22355                 Low                Medium     Medium              Low
# 21779              Medium             Very High     Medium           Medium
# 40302                 Low                Medium       High              Low
#
#          kitchen    laundry climate_control   other  weekend month_name  \
# 35103     Medium        Low            High    High     True      april
# 8049         Low        Low             Low  Medium    False      march
# 22355     Medium       High          Medium     Low    False  september
# 21779  Very High  Very High            High  Medium     True       june
# 40302       High       High          Medium  Medium    False      march
#
#       season_name   day_name        peak_label_pred  peak_warning  \
# 35103      spring     sunday       lower_than_usual         False
# 8049       spring    tuesday  no_significant_change         False
# 22355      autumn     friday           peak_warning          True
# 21779      summer   saturday           peak_warning          True
# 40302      spring  wednesday       lower_than_usual         False
#
#        no_significant_change  lower_than_usual
# 35103                  False              True
# 8049                    True             False
# 22355                  False             False
# 21779                  False             False
# 40302                  False              True

# %%
# Preprocess dataset
for c in range(8):
    print(c)
    print("[%d] Column Preprocessing: %s" %(c, hc_csv.columns[c]))
    for r in range(hc_csv.shape[0]):
        if(hc_csv.iloc[r,c]=='Very High'):
            hc_csv.iloc[r,c] = hc_csv.columns[c]+' 75-100%'
        elif(hc_csv.iloc[r,c]=='High'):
            hc_csv.iloc[r,c] = hc_csv.columns[c]+' 50-75%'
        elif(hc_csv.iloc[r,c]=='Medium'):
            hc_csv.iloc[r,c] = hc_csv.columns[c]+' 25-50%'
        elif(hc_csv.iloc[r,c]=='Low'):
            # hc_csv.iloc[r,c] = '-1'
            hc_csv.iloc[r,c] = hc_csv.columns[c]+' 0-25%'
        else:
            hc_csv.iloc[r,c] = '-1'
print("Done.")
# Out:
# 0
# [0] Column Preprocessing: global_active_power
# 1
# [1] Column Preprocessing: global_reactive_power
# 2
# [2] Column Preprocessing: voltage
# 3
# [3] Column Preprocessing: global_intensity
# 4
# [4] Column Preprocessing: kitchen
# 5
# [5] Column Preprocessing: laundry
# 6
# [6] Column Preprocessing: climate_control
# 7
# [7] Column Preprocessing: other
# Done.

# %%
for c in hc_csv.columns:
  if c == 'weekend':
    for r in range(hc_csv.shape[0]):
      if hc_csv.iloc[r,list(hc_csv.columns).index('weekend')] == True:
        hc_csv.iloc[r,list(hc_csv.columns).index('weekend')] = 'weekend'
      else:
        hc_csv.iloc[r,list(hc_csv.columns).index('weekend')] = 'weekday'
      # break
# Out:
# C:\Users\sclab\AppData\Local\Temp\ipykernel_33248\1856367701.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'weekend' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   hc_csv.iloc[r,list(hc_csv.columns).index('weekend')] = 'weekend'

# %%
hc_csv.sample(5)
# Out:
#                global_active_power          global_reactive_power  \
# 28950    global_active_power 0-25%    global_reactive_power 0-25%
# 17803   global_active_power 25-50%  global_reactive_power 75-100%
# 13194   global_active_power 25-50%    global_reactive_power 0-25%
# 38779  global_active_power 75-100%   global_reactive_power 25-50%
# 8814    global_active_power 25-50%   global_reactive_power 50-75%
#
#                voltage          global_intensity          kitchen  \
# 28950   voltage 50-75%   global_intensity 25-50%   kitchen 50-75%
# 17803   voltage 50-75%   global_intensity 25-50%   kitchen 25-50%
# 13194  voltage 75-100%   global_intensity 25-50%   kitchen 50-75%
# 38779   voltage 50-75%  global_intensity 75-100%    kitchen 0-25%
# 8814    voltage 50-75%   global_intensity 25-50%  kitchen 75-100%
#
#                laundry          climate_control         other  weekend  \
# 28950   laundry 25-50%   climate_control 25-50%  other 25-50%  weekend
# 17803  laundry 75-100%   climate_control 25-50%  other 50-75%  weekend
# 13194   laundry 50-75%   climate_control 25-50%  other 50-75%  weekday
# 38779    laundry 0-25%  climate_control 75-100%  other 50-75%  weekday
# 8814    laundry 50-75%   climate_control 25-50%  other 25-50%  weekend
#
#       month_name season_name  day_name        peak_label_pred  peak_warning  \
# 28950      april      spring    sunday       lower_than_usual         False
# 17803       june      summer    sunday           peak_warning          True
# 13194   december      winter  thursday  no_significant_change         False
# 38779   february      winter    friday       lower_than_usual         False
# 8814     october      autumn    sunday  no_significant_change         False
#
#        no_significant_change  lower_than_usual
# 28950                  False              True
# 17803                  False             False
# 13194                   True             False
# 38779                  False              True
# 8814                    True             False

# %%
# targets_only = ['peak_label_pred', 'no_significant_change', 'lower_than_usual']

# %%
hc_csv_temp = copy.copy(hc_csv)
hc_csv_temp.drop(columns=['month_name', 'day_name', 'peak_label_pred', 'peak_warning', 'lower_than_usual'], inplace=True)

# %%
for i in range(len(hc_csv_temp)):
    if hc_csv_temp.iloc[i,-1] == True:
        hc_csv_temp.iloc[i,-1] = 'True'
    else:
        hc_csv_temp.iloc[i,-1] = 'False'
    # break
# Out:
# C:\Users\sclab\AppData\Local\Temp\ipykernel_33248\3489011138.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'False' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   hc_csv_temp.iloc[i,-1] = 'False'

# %%
hc_csv_temp.head(4)
# Out:
#               global_active_power          global_reactive_power  \
# 35103  global_active_power 25-50%  global_reactive_power 75-100%
# 8049    global_active_power 0-25%   global_reactive_power 50-75%
# 22355   global_active_power 0-25%   global_reactive_power 25-50%
# 21779  global_active_power 25-50%  global_reactive_power 75-100%
#
#                voltage         global_intensity          kitchen  \
# 35103  voltage 75-100%  global_intensity 25-50%   kitchen 25-50%
# 8049   voltage 75-100%   global_intensity 0-25%    kitchen 0-25%
# 22355   voltage 25-50%   global_intensity 0-25%   kitchen 25-50%
# 21779   voltage 25-50%  global_intensity 25-50%  kitchen 75-100%
#
#                laundry         climate_control         other  weekend  \
# 35103    laundry 0-25%  climate_control 50-75%  other 50-75%  weekend
# 8049     laundry 0-25%   climate_control 0-25%  other 25-50%  weekday
# 22355   laundry 50-75%  climate_control 25-50%   other 0-25%  weekday
# 21779  laundry 75-100%  climate_control 50-75%  other 25-50%  weekend
#
#       season_name no_significant_change
# 35103      spring                 False
# 8049       spring                  True
# 22355      autumn                 False
# 21779      summer                 False

# %%
# hc_csv to list
hc_list = []
for r in range(hc_csv_temp.shape[0]):
    rule_buffer = []
    for c in range(len(hc_csv_temp.iloc[r])):
        if(hc_csv_temp.iloc[r,c]!='-1'):
            rule_buffer.append(hc_csv_temp.iloc[r,c])
    hc_list.append(rule_buffer)

# %%
hc_list
# Out:
# [['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 50-75%',
#   'weekend',
#   'spring',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekend',
#   'summer',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekend',
#   'winter',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'summer',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekend',
#   'winter',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend',
#   'winter',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekend',
#   'winter',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 0-25%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend',
#   'spring',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend',
#   'autumn',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'spring',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekend',
#   'autumn',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekend',
#   'spring',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekend',
#   'spring',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 0-25%',
#   'weekend',
#   'winter',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend',
#   'winter',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend',
#   'summer',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekend',
#   'summer',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekday',
#   'summer',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend',
#   'autumn',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 25-50%',
#   'other 50-75%',
#   'weekday',
#   'spring',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 75-100%',
#   'weekend',
#   'autumn',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekday',
#   'spring',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 0-25%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekend',
#   'spring',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekday',
#   'spring',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 0-25%',
#   'weekday',
#   'spring',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend',
#   'winter',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'spring',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 0-25%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend',
#   'autumn',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend',
#   'spring',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 50-75%',
#   'weekend',
#   'spring',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 75-100%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'autumn',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend',
#   'winter',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend',
#   'autumn',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend',
#   'winter',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekday',
#   'summer',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekday',
#   'winter',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 75-100%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'autumn',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 50-75%',
#   'weekend',
#   'winter',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 0-25%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend',
#   'spring',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekend',
#   'spring',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 0-25%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekday',
#   'spring',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend',
#   'autumn',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'autumn',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend',
#   'autumn',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend',
#   'spring',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'spring',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend',
#   'spring',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekday',
#   'winter',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 0-25%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend',
#   'summer',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekday',
#   'autumn',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'spring',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 0-25%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend',
#   'autumn',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 75-100%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 75-100%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 50-75%',
#   'weekday',
#   'winter',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'spring',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekend',
#   'spring',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekend',
#   'spring',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 75-100%',
#   'weekend',
#   'spring',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'spring',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'autumn',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend',
#   'spring',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend',
#   'spring',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 75-100%',
#   'other 0-25%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekend',
#   'summer',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 50-75%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'spring',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'winter',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 50-75%',
#   'weekend',
#   'summer',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekend',
#   'autumn',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend',
#   'autumn',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'spring',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'autumn',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekday',
#   'spring',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekday',
#   'spring',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekend',
#   'spring',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 50-75%',
#   'weekend',
#   'spring',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 75-100%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend',
#   'spring',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekend',
#   'spring',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 75-100%',
#   'weekend',
#   'summer',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend',
#   'summer',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekend',
#   'autumn',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekend',
#   'summer',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'winter',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend',
#   'autumn',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'autumn',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 75-100%',
#   'weekday',
#   'winter',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 50-75%',
# ...
#   'other 75-100%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend',
#   'winter',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 75-100%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend',
#   'spring',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 0-25%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekday',
#   'spring',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend',
#   'autumn',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 50-75%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 75-100%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 50-75%',
#   'weekday',
#   'spring',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 50-75%',
#   'weekend',
#   'spring',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekend',
#   'autumn',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'autumn',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'winter',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 50-75%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 50-75%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend',
#   'winter',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 75-100%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend',
#   'spring',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 75-100%',
#   'other 0-25%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend',
#   'spring',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 0-25%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekday',
#   'spring',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 25-50%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend',
#   'autumn',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekend',
#   'summer',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 50-75%',
#   'weekday',
#   'spring',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 75-100%',
#   'weekend',
#   'summer',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'summer',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend',
#   'winter',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 25-50%',
#   'weekday',
#   'spring',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 75-100%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekday',
#   'summer',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 25-50%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 0-25%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 50-75%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 50-75%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 75-100%',
#   'weekend',
#   'autumn',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 0-25%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'spring',
#   'True'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 25-50%',
#   'voltage 75-100%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 50-75%',
#   'weekend',
#   'winter',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 0-25%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'True'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 25-50%',
#   'voltage 0-25%',
#   'global_intensity 75-100%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekday',
#   'autumn',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 25-50%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 75-100%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 75-100%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 75-100%',
#   'weekend',
#   'spring',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 25-50%',
#   'kitchen 75-100%',
#   'laundry 50-75%',
#   'climate_control 50-75%',
#   'other 25-50%',
#   'weekday',
#   'summer',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 0-25%',
#   'voltage 50-75%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 75-100%',
#   'other 50-75%',
#   'weekend',
#   'spring',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 0-25%',
#   'laundry 75-100%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekend',
#   'summer',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 0-25%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 0-25%',
#   'climate_control 0-25%',
#   'other 0-25%',
#   'weekday',
#   'winter',
#   'False'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 25-50%',
#   'global_intensity 0-25%',
#   'kitchen 25-50%',
#   'laundry 50-75%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'True'],
#  ['global_active_power 50-75%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 50-75%',
#   'kitchen 50-75%',
#   'laundry 25-50%',
#   'climate_control 50-75%',
#   'other 50-75%',
#   'weekend',
#   'summer',
#   'False'],
#  ['global_active_power 25-50%',
#   'global_reactive_power 75-100%',
#   'voltage 25-50%',
#   'global_intensity 25-50%',
#   'kitchen 50-75%',
#   'laundry 75-100%',
#   'climate_control 25-50%',
#   'other 0-25%',
#   'weekday',
#   'summer',
#   'True'],
#  ['global_active_power 0-25%',
#   'global_reactive_power 50-75%',
#   'voltage 75-100%',
#   'global_intensity 0-25%',
#   'kitchen 0-25%',
#   'laundry 50-75%',
#   'climate_control 0-25%',
#   'other 25-50%',
#   'weekday',
#   'winter',
#   'False'],
#  ...]

# %%
# Association Rule Mining (ARM) (Caution: extremly slow)
association_rules = list(apriori(hc_list, min_support=0.05, min_confidence=0.2))
print('Rule Mined: %d' %(len(association_rules)))
# Out:
# Rule Mined: 1479

# %%
# Rules to numpy structure
association_rules_np = []
for r in range(len(association_rules)):
    rule_buffer = []
    association_rule = association_rules[r]
    items = [x for x in association_rule[0]]
    n_items = len(items)
    support = association_rule[1]
    confidence = association_rule[2][0][2]
    lift = association_rule[2][0][3]
    rule_buffer.append(n_items), rule_buffer.append(np.array(items)), rule_buffer.append(round(support, 4)), rule_buffer.append(round(confidence, 4)), rule_buffer.append(round(lift, 4))
    print(rule_buffer)
    association_rules_np.append(rule_buffer)
# Fix later
# association_rules_np = np.array(association_rules_np)
# print(association_rules_np)
# np.save('./association_rules', association_rules_np)
# Length, Rule, Support, Confidence, Lift
# Out:
# [1, array(['False'], dtype='<U5'), 0.666, 0.666, 1.0]
# [1, array(['True'], dtype='<U4'), 0.334, 0.334, 1.0]
# [1, array(['autumn'], dtype='<U6'), 0.2464, 0.2464, 1.0]
# [1, array(['climate_control 0-25%'], dtype='<U21'), 0.3145, 0.3145, 1.0]
# [1, array(['climate_control 25-50%'], dtype='<U22'), 0.2476, 0.2476, 1.0]
# [1, array(['climate_control 50-75%'], dtype='<U22'), 0.2261, 0.2261, 1.0]
# [1, array(['climate_control 75-100%'], dtype='<U23'), 0.2118, 0.2118, 1.0]
# [1, array(['global_active_power 0-25%'], dtype='<U25'), 0.3074, 0.3074, 1.0]
# [1, array(['global_active_power 25-50%'], dtype='<U26'), 0.2678, 0.2678, 1.0]
# [1, array(['global_active_power 50-75%'], dtype='<U26'), 0.2061, 0.2061, 1.0]
# [1, array(['global_active_power 75-100%'], dtype='<U27'), 0.2188, 0.2188, 1.0]
# [1, array(['global_intensity 0-25%'], dtype='<U22'), 0.3144, 0.3144, 1.0]
# [1, array(['global_intensity 25-50%'], dtype='<U23'), 0.2603, 0.2603, 1.0]
# [1, array(['global_intensity 50-75%'], dtype='<U23'), 0.2059, 0.2059, 1.0]
# [1, array(['global_intensity 75-100%'], dtype='<U24'), 0.2195, 0.2195, 1.0]
# [1, array(['global_reactive_power 0-25%'], dtype='<U27'), 0.2669, 0.2669, 1.0]
# [1, array(['global_reactive_power 25-50%'], dtype='<U28'), 0.2521, 0.2521, 1.0]
# [1, array(['global_reactive_power 50-75%'], dtype='<U28'), 0.2433, 0.2433, 1.0]
# [1, array(['global_reactive_power 75-100%'], dtype='<U29'), 0.2377, 0.2377, 1.0]
# [1, array(['kitchen 0-25%'], dtype='<U13'), 0.2811, 0.2811, 1.0]
# [1, array(['kitchen 25-50%'], dtype='<U14'), 0.2501, 0.2501, 1.0]
# [1, array(['kitchen 50-75%'], dtype='<U14'), 0.246, 0.246, 1.0]
# [1, array(['kitchen 75-100%'], dtype='<U15'), 0.2227, 0.2227, 1.0]
# [1, array(['laundry 0-25%'], dtype='<U13'), 0.2669, 0.2669, 1.0]
# [1, array(['laundry 25-50%'], dtype='<U14'), 0.251, 0.251, 1.0]
# [1, array(['laundry 50-75%'], dtype='<U14'), 0.2444, 0.2444, 1.0]
# [1, array(['laundry 75-100%'], dtype='<U15'), 0.2376, 0.2376, 1.0]
# [1, array(['other 0-25%'], dtype='<U11'), 0.2616, 0.2616, 1.0]
# [1, array(['other 25-50%'], dtype='<U12'), 0.29, 0.29, 1.0]
# [1, array(['other 50-75%'], dtype='<U12'), 0.2336, 0.2336, 1.0]
# [1, array(['other 75-100%'], dtype='<U13'), 0.2147, 0.2147, 1.0]
# [1, array(['spring'], dtype='<U6'), 0.2417, 0.2417, 1.0]
# [1, array(['summer'], dtype='<U6'), 0.2429, 0.2429, 1.0]
# [1, array(['voltage 0-25%'], dtype='<U13'), 0.2375, 0.2375, 1.0]
# [1, array(['voltage 25-50%'], dtype='<U14'), 0.2273, 0.2273, 1.0]
# [1, array(['voltage 50-75%'], dtype='<U14'), 0.2335, 0.2335, 1.0]
# [1, array(['voltage 75-100%'], dtype='<U15'), 0.3017, 0.3017, 1.0]
# [1, array(['weekday'], dtype='<U7'), 0.7117, 0.7117, 1.0]
# [1, array(['weekend'], dtype='<U7'), 0.2883, 0.2883, 1.0]
# [1, array(['winter'], dtype='<U6'), 0.2691, 0.2691, 1.0]
# [2, array(['False', 'autumn'], dtype='<U6'), 0.1592, 0.2391, 0.9703]
# [2, array(['False', 'climate_control 0-25%'], dtype='<U21'), 0.2264, 0.2264, 1.0]
# [2, array(['False', 'climate_control 25-50%'], dtype='<U22'), 0.1511, 0.2268, 0.9163]
# [2, array(['climate_control 50-75%', 'False'], dtype='<U22'), 0.1403, 0.2106, 0.9314]
# [2, array(['False', 'climate_control 75-100%'], dtype='<U23'), 0.1483, 0.2226, 1.051]
# [2, array(['False', 'global_active_power 0-25%'], dtype='<U25'), 0.2191, 0.2191, 1.0]
# [2, array(['global_active_power 25-50%', 'False'], dtype='<U26'), 0.1619, 0.2431, 0.9077]
# [2, array(['False', 'global_active_power 50-75%'], dtype='<U26'), 0.1195, 0.5801, 0.871]
# [2, array(['False', 'global_active_power 75-100%'], dtype='<U27'), 0.1655, 0.2485, 1.1358]
# [2, array(['False', 'global_intensity 0-25%'], dtype='<U22'), 0.226, 0.226, 1.0]
# [2, array(['global_intensity 25-50%', 'False'], dtype='<U23'), 0.1544, 0.2318, 0.8906]
# [2, array(['False', 'global_intensity 50-75%'], dtype='<U23'), 0.1189, 0.5774, 0.867]
# [2, array(['global_intensity 75-100%', 'False'], dtype='<U24'), 0.1668, 0.2504, 1.1408]
# [2, array(['False', 'global_reactive_power 0-25%'], dtype='<U27'), 0.1785, 0.268, 1.0042]
# [2, array(['False', 'global_reactive_power 25-50%'], dtype='<U28'), 0.1651, 0.248, 0.9837]
# [2, array(['global_reactive_power 50-75%', 'False'], dtype='<U28'), 0.161, 0.2418, 0.9937]
# [2, array(['global_reactive_power 75-100%', 'False'], dtype='<U29'), 0.1613, 0.2422, 1.0189]
# [2, array(['kitchen 0-25%', 'False'], dtype='<U13'), 0.201, 0.201, 1.0]
# [2, array(['False', 'kitchen 25-50%'], dtype='<U14'), 0.1657, 0.2488, 0.9945]
# [2, array(['False', 'kitchen 50-75%'], dtype='<U14'), 0.1564, 0.2348, 0.9543]
# [2, array(['kitchen 75-100%', 'False'], dtype='<U15'), 0.1429, 0.2146, 0.9637]
# [2, array(['False', 'laundry 0-25%'], dtype='<U13'), 0.1895, 0.2846, 1.0662]
# [2, array(['laundry 25-50%', 'False'], dtype='<U14'), 0.1614, 0.2424, 0.9658]
# [2, array(['laundry 50-75%', 'False'], dtype='<U14'), 0.1555, 0.2335, 0.9553]
# [2, array(['laundry 75-100%', 'False'], dtype='<U15'), 0.1595, 0.2395, 1.0079]
# [2, array(['other 0-25%', 'False'], dtype='<U11'), 0.1777, 0.2668, 1.0199]
# [2, array(['other 25-50%', 'False'], dtype='<U12'), 0.1949, 0.2927, 1.0092]
# [2, array(['other 50-75%', 'False'], dtype='<U12'), 0.1433, 0.2151, 0.9209]
# [2, array(['False', 'other 75-100%'], dtype='<U13'), 0.1501, 0.2253, 1.0494]
# [2, array(['False', 'spring'], dtype='<U6'), 0.1505, 0.226, 0.9351]
# [2, array(['summer', 'False'], dtype='<U6'), 0.1701, 0.2554, 1.0515]
# [2, array(['voltage 0-25%', 'False'], dtype='<U13'), 0.1772, 0.266, 1.1201]
# [2, array(['voltage 25-50%', 'False'], dtype='<U14'), 0.1468, 0.2205, 0.9701]
# [2, array(['voltage 50-75%', 'False'], dtype='<U14'), 0.1392, 0.209, 0.8952]
# [2, array(['False', 'voltage 75-100%'], dtype='<U15'), 0.2028, 0.2028, 1.0]
# [2, array(['weekday', 'False'], dtype='<U7'), 0.467, 0.467, 1.0]
# [2, array(['False', 'weekend'], dtype='<U7'), 0.199, 0.2988, 1.0363]
# [2, array(['False', 'winter'], dtype='<U6'), 0.1862, 0.2795, 1.0389]
# [2, array(['True', 'autumn'], dtype='<U6'), 0.0872, 0.261, 1.0592]
# [2, array(['True', 'climate_control 0-25%'], dtype='<U21'), 0.0881, 0.2637, 0.8387]
# [2, array(['True', 'climate_control 25-50%'], dtype='<U22'), 0.0965, 0.2889, 1.1669]
# [2, array(['climate_control 50-75%', 'True'], dtype='<U22'), 0.0859, 0.2571, 1.1368]
# [2, array(['True', 'climate_control 75-100%'], dtype='<U23'), 0.0636, 0.3001, 0.8983]
# [2, array(['True', 'global_active_power 0-25%'], dtype='<U25'), 0.0883, 0.2643, 0.86]
# [2, array(['global_active_power 25-50%', 'True'], dtype='<U26'), 0.1059, 0.317, 1.184]
# [2, array(['True', 'global_active_power 50-75%'], dtype='<U26'), 0.0865, 0.2591, 1.2571]
# [2, array(['True', 'global_active_power 75-100%'], dtype='<U27'), 0.0533, 0.2436, 0.7293]
# [2, array(['True', 'global_intensity 0-25%'], dtype='<U22'), 0.0884, 0.2646, 0.8418]
# [2, array(['global_intensity 25-50%', 'True'], dtype='<U23'), 0.1059, 0.317, 1.2181]
# [2, array(['True', 'global_intensity 50-75%'], dtype='<U23'), 0.087, 0.2605, 1.2652]
# [2, array(['global_intensity 75-100%', 'True'], dtype='<U24'), 0.0527, 0.2402, 0.7192]
# [2, array(['True', 'global_reactive_power 0-25%'], dtype='<U27'), 0.0884, 0.2646, 0.9915]
# [2, array(['True', 'global_reactive_power 25-50%'], dtype='<U28'), 0.0869, 0.2603, 1.0325]
# [2, array(['global_reactive_power 50-75%', 'True'], dtype='<U28'), 0.0823, 0.2464, 1.0125]
# [2, array(['global_reactive_power 75-100%', 'True'], dtype='<U29'), 0.0764, 0.2287, 0.9622]
# [2, array(['kitchen 0-25%', 'True'], dtype='<U13'), 0.0801, 0.2399, 0.8533]
# [2, array(['True', 'kitchen 25-50%'], dtype='<U14'), 0.0845, 0.2529, 1.0109]
# [2, array(['True', 'kitchen 50-75%'], dtype='<U14'), 0.0897, 0.2684, 1.0911]
# [2, array(['kitchen 75-100%', 'True'], dtype='<U15'), 0.0798, 0.2388, 1.0723]
# [2, array(['True', 'laundry 0-25%'], dtype='<U13'), 0.0774, 0.2317, 0.8681]
# [2, array(['laundry 25-50%', 'True'], dtype='<U14'), 0.0896, 0.2681, 1.0683]
# [2, array(['laundry 50-75%', 'True'], dtype='<U14'), 0.0889, 0.2662, 1.0892]
# [2, array(['laundry 75-100%', 'True'], dtype='<U15'), 0.0781, 0.2339, 0.9843]
# [2, array(['other 0-25%', 'True'], dtype='<U11'), 0.0839, 0.2513, 0.9604]
# [2, array(['other 25-50%', 'True'], dtype='<U12'), 0.0951, 0.2847, 0.9816]
# [2, array(['other 50-75%', 'True'], dtype='<U12'), 0.0903, 0.2704, 1.1577]
# [2, array(['True', 'other 75-100%'], dtype='<U13'), 0.0647, 0.3011, 0.9016]
# [2, array(['True', 'spring'], dtype='<U6'), 0.0912, 0.2729, 1.1294]
# [2, array(['summer', 'True'], dtype='<U6'), 0.0728, 0.2179, 0.8973]
# [2, array(['voltage 0-25%', 'True'], dtype='<U13'), 0.0603, 0.254, 0.7605]
# [2, array(['voltage 25-50%', 'True'], dtype='<U14'), 0.0804, 0.2408, 1.0595]
# [2, array(['voltage 50-75%', 'True'], dtype='<U14'), 0.0943, 0.2823, 1.209]
# [2, array(['True', 'voltage 75-100%'], dtype='<U15'), 0.099, 0.2963, 0.9819]
# [2, array(['weekday', 'True'], dtype='<U7'), 0.2447, 0.2447, 1.0]
# [2, array(['True', 'weekend'], dtype='<U7'), 0.0893, 0.2674, 0.9275]
# [2, array(['True', 'winter'], dtype='<U6'), 0.0829, 0.2482, 0.9224]
# [2, array(['climate_control 0-25%', 'autumn'], dtype='<U21'), 0.0636, 0.2583, 0.8213]
# [2, array(['climate_control 25-50%', 'autumn'], dtype='<U22'), 0.063, 0.2557, 1.0329]
# [2, array(['climate_control 50-75%', 'autumn'], dtype='<U22'), 0.061, 0.2475, 1.0943]
# [2, array(['climate_control 75-100%', 'autumn'], dtype='<U23'), 0.0588, 0.2385, 1.126]
# [2, array(['global_active_power 0-25%', 'autumn'], dtype='<U25'), 0.0669, 0.2714, 0.883]
# [2, array(['global_active_power 25-50%', 'autumn'], dtype='<U26'), 0.0637, 0.2584, 0.9651]
# [2, array(['global_active_power 50-75%', 'autumn'], dtype='<U26'), 0.0538, 0.2184, 1.0597]
# [2, array(['global_active_power 75-100%', 'autumn'], dtype='<U27'), 0.062, 0.2518, 1.1508]
# [2, array(['global_intensity 0-25%', 'autumn'], dtype='<U22'), 0.0698, 0.2832, 0.9008]
# [2, array(['global_intensity 25-50%', 'autumn'], dtype='<U23'), 0.0611, 0.2481, 0.9534]
# [2, array(['global_intensity 50-75%', 'autumn'], dtype='<U23'), 0.0536, 0.2177, 1.0575]
# [2, array(['global_intensity 75-100%', 'autumn'], dtype='<U24'), 0.0618, 0.251, 1.1434]
# [2, array(['global_reactive_power 0-25%', 'autumn'], dtype='<U27'), 0.0639, 0.2594, 0.9718]
# [2, array(['global_reactive_power 25-50%', 'autumn'], dtype='<U28'), 0.0695, 0.282, 1.1186]
# [2, array(['global_reactive_power 50-75%', 'autumn'], dtype='<U28'), 0.0592, 0.2404, 0.9881]
# [2, array(['global_reactive_power 75-100%', 'autumn'], dtype='<U29'), 0.0538, 0.2182, 0.9181]
# [2, array(['kitchen 0-25%', 'autumn'], dtype='<U13'), 0.0635, 0.2577, 0.9168]
# [2, array(['kitchen 25-50%', 'autumn'], dtype='<U14'), 0.0533, 0.2162, 0.8644]
# [2, array(['kitchen 50-75%', 'autumn'], dtype='<U14'), 0.0537, 0.2181, 0.8865]
# [2, array(['kitchen 75-100%', 'autumn'], dtype='<U15'), 0.0759, 0.3079, 1.3828]
# [2, array(['laundry 25-50%', 'autumn'], dtype='<U14'), 0.0603, 0.2449, 0.9757]
# [2, array(['laundry 50-75%', 'autumn'], dtype='<U14'), 0.0803, 0.3259, 1.3334]
# [2, array(['laundry 75-100%', 'autumn'], dtype='<U15'), 0.0615, 0.2495, 1.0499]
# [2, array(['other 0-25%', 'autumn'], dtype='<U11'), 0.0596, 0.2419, 0.9246]
# [2, array(['other 25-50%', 'autumn'], dtype='<U12'), 0.071, 0.2882, 0.9936]
# [2, array(['other 50-75%', 'autumn'], dtype='<U12'), 0.0529, 0.2147, 0.9192]
# [2, array(['other 75-100%', 'autumn'], dtype='<U13'), 0.0629, 0.2552, 1.1883]
# [2, array(['voltage 0-25%', 'autumn'], dtype='<U13'), 0.0604, 0.2453, 1.0328]
# [2, array(['voltage 25-50%', 'autumn'], dtype='<U14'), 0.0634, 0.2573, 1.1323]
# [2, array(['voltage 50-75%', 'autumn'], dtype='<U14'), 0.0627, 0.2545, 1.0899]
# [2, array(['voltage 75-100%', 'autumn'], dtype='<U15'), 0.0598, 0.2429, 0.8049]
# [2, array(['weekday', 'autumn'], dtype='<U7'), 0.1733, 0.7036, 0.9886]
# [2, array(['weekend', 'autumn'], dtype='<U7'), 0.073, 0.2964, 1.0281]
# [2, array(['climate_control 0-25%', 'global_active_power 0-25%'], dtype='<U25'), 0.1662, 0.5286, 1.7198]
# [2, array(['global_active_power 25-50%', 'climate_control 0-25%'],
#       dtype='<U26'), 0.0965, 0.3069, 1.146]
# [2, array(['climate_control 0-25%', 'global_intensity 0-25%'], dtype='<U22'), 0.1683, 0.5353, 1.7028]
# [2, array(['global_intensity 25-50%', 'climate_control 0-25%'], dtype='<U23'), 0.0942, 0.2997, 1.1514]
# [2, array(['climate_control 0-25%', 'global_reactive_power 0-25%'],
#       dtype='<U27'), 0.1075, 0.342, 1.2812]
# [2, array(['climate_control 0-25%', 'global_reactive_power 25-50%'],
#       dtype='<U28'), 0.0836, 0.2657, 1.0542]
# [2, array(['global_reactive_power 50-75%', 'climate_control 0-25%'],
#       dtype='<U28'), 0.0718, 0.2284, 0.9387]
# [2, array(['global_reactive_power 75-100%', 'climate_control 0-25%'],
#       dtype='<U29'), 0.0515, 0.2168, 0.6894]
# [2, array(['kitchen 0-25%', 'climate_control 0-25%'], dtype='<U21'), 0.2085, 0.2085, 1.0]
# [2, array(['climate_control 0-25%', 'kitchen 25-50%'], dtype='<U21'), 0.094, 0.299, 1.1955]
# [2, array(['climate_control 0-25%', 'laundry 0-25%'], dtype='<U21'), 0.1514, 0.4816, 1.804]
# [2, array(['laundry 50-75%', 'climate_control 0-25%'], dtype='<U21'), 0.0663, 0.2108, 0.8625]
# [2, array(['laundry 75-100%', 'climate_control 0-25%'], dtype='<U21'), 0.0574, 0.2417, 0.7686]
# [2, array(['other 0-25%', 'climate_control 0-25%'], dtype='<U21'), 0.0859, 0.2733, 1.0445]
# [2, array(['other 25-50%', 'climate_control 0-25%'], dtype='<U21'), 0.1121, 0.3565, 1.2291]
# [2, array(['other 50-75%', 'climate_control 0-25%'], dtype='<U21'), 0.0714, 0.2272, 0.9724]
# [2, array(['climate_control 0-25%', 'spring'], dtype='<U21'), 0.0634, 0.2016, 0.8343]
# [2, array(['summer', 'climate_control 0-25%'], dtype='<U21'), 0.0594, 0.2444, 0.7772]
# [2, array(['voltage 0-25%', 'climate_control 0-25%'], dtype='<U21'), 0.0738, 0.2347, 0.9881]
# [2, array(['voltage 50-75%', 'climate_control 0-25%'], dtype='<U21'), 0.0657, 0.2088, 0.8943]
# [2, array(['climate_control 0-25%', 'voltage 75-100%'], dtype='<U21'), 0.1254, 0.3988, 1.3216]
# [2, array(['weekday', 'climate_control 0-25%'], dtype='<U21'), 0.2305, 0.2305, 1.0]
# [2, array(['climate_control 0-25%', 'weekend'], dtype='<U21'), 0.084, 0.267, 0.9261]
# [2, array(['climate_control 0-25%', 'winter'], dtype='<U21'), 0.1281, 0.4073, 1.5136]
# [2, array(['global_active_power 0-25%', 'climate_control 25-50%'],
#       dtype='<U25'), 0.1113, 0.4496, 1.4627]
# [2, array(['global_active_power 25-50%', 'climate_control 25-50%'],
#       dtype='<U26'), 0.0933, 0.377, 1.408]
# [2, array(['global_intensity 0-25%', 'climate_control 25-50%'], dtype='<U22'), 0.1137, 0.4591, 1.4605]
# [2, array(['global_intensity 25-50%', 'climate_control 25-50%'], dtype='<U23'), 0.0911, 0.368, 1.4139]
# [2, array(['global_reactive_power 0-25%', 'climate_control 25-50%'],
#       dtype='<U27'), 0.0636, 0.2569, 0.9625]
# [2, array(['global_reactive_power 25-50%', 'climate_control 25-50%'],
#       dtype='<U28'), 0.0616, 0.2488, 0.9871]
# [2, array(['global_reactive_power 50-75%', 'climate_control 25-50%'],
#       dtype='<U28'), 0.0641, 0.2589, 1.0641]
# [2, array(['global_reactive_power 75-100%', 'climate_control 25-50%'],
#       dtype='<U29'), 0.0583, 0.2354, 0.9901]
# [2, array(['kitchen 25-50%', 'climate_control 25-50%'], dtype='<U22'), 0.0724, 0.2924, 1.1692]
# [2, array(['kitchen 50-75%', 'climate_control 25-50%'], dtype='<U22'), 0.1364, 0.5508, 2.2388]
# [2, array(['laundry 25-50%', 'climate_control 25-50%'], dtype='<U22'), 0.0965, 0.3897, 1.5524]
# [2, array(['laundry 50-75%', 'climate_control 25-50%'], dtype='<U22'), 0.0576, 0.2327, 0.9519]
# [2, array(['laundry 75-100%', 'climate_control 25-50%'], dtype='<U22'), 0.0588, 0.2375, 0.9995]
# [2, array(['other 0-25%', 'climate_control 25-50%'], dtype='<U22'), 0.0864, 0.3489, 1.3334]
# [2, array(['other 25-50%', 'climate_control 25-50%'], dtype='<U22'), 0.0777, 0.3139, 1.0821]
# [2, array(['other 50-75%', 'climate_control 25-50%'], dtype='<U22'), 0.0501, 0.2025, 0.8669]
# [2, array(['spring', 'climate_control 25-50%'], dtype='<U22'), 0.0677, 0.2735, 1.1316]
# [2, array(['summer', 'climate_control 25-50%'], dtype='<U22'), 0.0725, 0.2927, 1.2051]
# [2, array(['voltage 25-50%', 'climate_control 25-50%'], dtype='<U22'), 0.057, 0.2304, 1.0137]
# [2, array(['voltage 50-75%', 'climate_control 25-50%'], dtype='<U22'), 0.0707, 0.2854, 1.2225]
# [2, array(['voltage 75-100%', 'climate_control 25-50%'], dtype='<U22'), 0.0938, 0.3788, 1.2553]
# [2, array(['weekday', 'climate_control 25-50%'], dtype='<U22'), 0.1743, 0.7039, 0.9891]
# [2, array(['weekend', 'climate_control 25-50%'], dtype='<U22'), 0.0733, 0.2961, 1.0269]
# [2, array(['global_active_power 25-50%', 'climate_control 50-75%'],
#       dtype='<U26'), 0.0779, 0.3446, 1.2871]
# [2, array(['climate_control 50-75%', 'global_active_power 50-75%'],
#       dtype='<U26'), 0.0628, 0.2777, 1.3477]
# [2, array(['climate_control 50-75%', 'global_active_power 75-100%'],
#       dtype='<U27'), 0.0556, 0.2457, 1.1231]
# [2, array(['global_intensity 25-50%', 'climate_control 50-75%'], dtype='<U23'), 0.0749, 0.3314, 1.2732]
# [2, array(['climate_control 50-75%', 'global_intensity 50-75%'], dtype='<U23'), 0.0621, 0.2746, 1.334]
# [2, array(['global_intensity 75-100%', 'climate_control 50-75%'], dtype='<U24'), 0.0567, 0.2509, 1.143]
# [2, array(['climate_control 50-75%', 'global_reactive_power 25-50%'],
#       dtype='<U28'), 0.0522, 0.2308, 0.9158]
# [2, array(['global_reactive_power 50-75%', 'climate_control 50-75%'],
#       dtype='<U28'), 0.0578, 0.2555, 1.0498]
# [2, array(['global_reactive_power 75-100%', 'climate_control 50-75%'],
#       dtype='<U29'), 0.0701, 0.3098, 1.3035]
# [2, array(['kitchen 75-100%', 'climate_control 50-75%'], dtype='<U22'), 0.1015, 0.4487, 2.0148]
# [2, array(['laundry 50-75%', 'climate_control 50-75%'], dtype='<U22'), 0.0696, 0.3076, 1.2586]
# [2, array(['laundry 75-100%', 'climate_control 50-75%'], dtype='<U22'), 0.0658, 0.2908, 1.2239]
# [2, array(['other 0-25%', 'climate_control 50-75%'], dtype='<U22'), 0.0632, 0.2795, 1.0682]
# [2, array(['other 25-50%', 'climate_control 50-75%'], dtype='<U22'), 0.0559, 0.2471, 0.8518]
# [2, array(['climate_control 50-75%', 'other 75-100%'], dtype='<U22'), 0.0606, 0.2678, 1.2473]
# [2, array(['climate_control 50-75%', 'spring'], dtype='<U22'), 0.0541, 0.2394, 0.9906]
# [2, array(['summer', 'climate_control 50-75%'], dtype='<U22'), 0.0757, 0.3346, 1.3776]
# [2, array(['voltage 0-25%', 'climate_control 50-75%'], dtype='<U22'), 0.0695, 0.3075, 1.2947]
# [2, array(['voltage 50-75%', 'climate_control 50-75%'], dtype='<U22'), 0.0542, 0.2397, 1.0265]
# [2, array(['climate_control 50-75%', 'voltage 75-100%'], dtype='<U22'), 0.0549, 0.2428, 0.8046]
# [2, array(['weekday', 'climate_control 50-75%'], dtype='<U22'), 0.1553, 0.6868, 0.965]
# [2, array(['climate_control 50-75%', 'weekend'], dtype='<U22'), 0.0708, 0.3132, 1.0864]
# [2, array(['climate_control 75-100%', 'global_active_power 50-75%'],
#       dtype='<U26'), 0.0861, 0.4066, 1.9732]
# [2, array(['global_active_power 75-100%', 'climate_control 75-100%'],
#       dtype='<U27'), 0.1257, 0.5934, 2.712]
# [2, array(['climate_control 75-100%', 'global_intensity 50-75%'], dtype='<U23'), 0.0876, 0.4135, 2.0087]
# [2, array(['global_intensity 75-100%', 'climate_control 75-100%'],
#       dtype='<U24'), 0.1242, 0.5865, 2.6718]
# [2, array(['climate_control 75-100%', 'global_reactive_power 25-50%'],
#       dtype='<U28'), 0.0547, 0.2582, 1.0244]
# [2, array(['global_reactive_power 75-100%', 'climate_control 75-100%'],
#       dtype='<U29'), 0.0578, 0.273, 1.1486]
# [2, array(['climate_control 75-100%', 'kitchen 50-75%'], dtype='<U23'), 0.0602, 0.284, 1.1544]
# [2, array(['kitchen 75-100%', 'climate_control 75-100%'], dtype='<U23'), 0.0713, 0.3364, 1.5107]
# [2, array(['laundry 25-50%', 'climate_control 75-100%'], dtype='<U23'), 0.0674, 0.318, 1.267]
# [2, array(['laundry 50-75%', 'climate_control 75-100%'], dtype='<U23'), 0.051, 0.2406, 0.9843]
# [2, array(['laundry 75-100%', 'climate_control 75-100%'], dtype='<U23'), 0.0556, 0.2626, 1.1052]
# [2, array(['other 50-75%', 'climate_control 75-100%'], dtype='<U23'), 0.0655, 0.3094, 1.3243]
# [2, array(['other 75-100%', 'climate_control 75-100%'], dtype='<U23'), 0.0758, 0.3578, 1.6664]
# [2, array(['spring', 'climate_control 75-100%'], dtype='<U23'), 0.0564, 0.2664, 1.1024]
# [2, array(['voltage 0-25%', 'climate_control 75-100%'], dtype='<U23'), 0.0681, 0.3213, 1.3529]
# [2, array(['voltage 25-50%', 'climate_control 75-100%'], dtype='<U23'), 0.0731, 0.3452, 1.5191]
# [2, array(['weekday', 'climate_control 75-100%'], dtype='<U23'), 0.1516, 0.7157, 1.0056]
# [2, array(['climate_control 75-100%', 'weekend'], dtype='<U23'), 0.0602, 0.2843, 0.9862]
# [2, array(['climate_control 75-100%', 'winter'], dtype='<U23'), 0.0612, 0.2891, 1.0743]
# [2, array(['global_intensity 0-25%', 'global_active_power 0-25%'],
#       dtype='<U25'), 0.2915, 0.2915, 1.0]
# [2, array(['global_active_power 0-25%', 'global_reactive_power 0-25%'],
#       dtype='<U27'), 0.1391, 0.4527, 1.696]
# [2, array(['global_active_power 0-25%', 'global_reactive_power 25-50%'],
#       dtype='<U28'), 0.0891, 0.29, 1.1505]
# [2, array(['global_reactive_power 50-75%', 'global_active_power 0-25%'],
#       dtype='<U28'), 0.0553, 0.2271, 0.7389]
# [2, array(['kitchen 0-25%', 'global_active_power 0-25%'], dtype='<U25'), 0.1227, 0.3992, 1.42]
# [2, array(['kitchen 25-50%', 'global_active_power 0-25%'], dtype='<U25'), 0.0876, 0.285, 1.1394]
# [2, array(['global_active_power 0-25%', 'kitchen 50-75%'], dtype='<U25'), 0.0648, 0.2109, 0.8573]
# [2, array(['global_active_power 0-25%', 'laundry 0-25%'], dtype='<U25'), 0.1231, 0.4004, 1.5]
# [2, array(['laundry 25-50%', 'global_active_power 0-25%'], dtype='<U25'), 0.0756, 0.246, 0.9799]
# [2, array(['laundry 50-75%', 'global_active_power 0-25%'], dtype='<U25'), 0.0765, 0.2488, 1.0178]
# [2, array(['other 0-25%', 'global_active_power 0-25%'], dtype='<U25'), 0.1868, 0.6077, 2.3229]
# [2, array(['other 25-50%', 'global_active_power 0-25%'], dtype='<U25'), 0.1206, 0.3923, 1.3525]
# [2, array(['spring', 'global_active_power 0-25%'], dtype='<U25'), 0.0577, 0.2388, 0.7768]
# [2, array(['summer', 'global_active_power 0-25%'], dtype='<U25'), 0.1075, 0.3497, 1.4399]
# [2, array(['voltage 25-50%', 'global_active_power 0-25%'], dtype='<U25'), 0.059, 0.2598, 0.8451]
# [2, array(['voltage 50-75%', 'global_active_power 0-25%'], dtype='<U25'), 0.0794, 0.2583, 1.1063]
# [2, array(['global_active_power 0-25%', 'voltage 75-100%'], dtype='<U25'), 0.1214, 0.395, 1.309]
# [2, array(['weekday', 'global_active_power 0-25%'], dtype='<U25'), 0.2269, 0.2269, 1.0]
# [2, array(['global_active_power 0-25%', 'weekend'], dtype='<U25'), 0.0804, 0.2617, 0.9076]
# [2, array(['global_active_power 0-25%', 'winter'], dtype='<U25'), 0.0753, 0.245, 0.9105]
# [2, array(['global_intensity 25-50%', 'global_active_power 25-50%'],
#       dtype='<U26'), 0.2415, 0.2415, 1.0]
# [2, array(['global_active_power 25-50%', 'global_reactive_power 25-50%'],
#       dtype='<U28'), 0.0611, 0.2281, 0.9048]
# [2, array(['global_reactive_power 50-75%', 'global_active_power 25-50%'],
#       dtype='<U28'), 0.0905, 0.3379, 1.3885]
# [2, array(['global_active_power 25-50%', 'global_reactive_power 75-100%'],
#       dtype='<U29'), 0.0798, 0.2979, 1.2532]
# [2, array(['global_active_power 25-50%', 'kitchen 0-25%'], dtype='<U26'), 0.0619, 0.2312, 0.8223]
# [2, array(['global_active_power 25-50%', 'kitchen 25-50%'], dtype='<U26'), 0.0718, 0.2683, 1.0725]
# [2, array(['global_active_power 25-50%', 'kitchen 50-75%'], dtype='<U26'), 0.0855, 0.3192, 1.2973]
# [2, array(['global_active_power 25-50%', 'laundry 25-50%'], dtype='<U26'), 0.0685, 0.2559, 1.0197]
# [2, array(['global_active_power 25-50%', 'laundry 50-75%'], dtype='<U26'), 0.0677, 0.253, 1.0349]
# [2, array(['global_active_power 25-50%', 'laundry 75-100%'], dtype='<U26'), 0.0808, 0.3019, 1.2704]
# [2, array(['global_active_power 25-50%', 'other 25-50%'], dtype='<U26'), 0.1065, 0.3979, 1.3718]
# [2, array(['global_active_power 25-50%', 'other 50-75%'], dtype='<U26'), 0.1247, 0.4658, 1.9941]
# [2, array(['global_active_power 25-50%', 'spring'], dtype='<U26'), 0.0731, 0.2729, 1.1291]
# [2, array(['global_active_power 25-50%', 'summer'], dtype='<U26'), 0.0535, 0.2204, 0.8231]
# [2, array(['global_active_power 25-50%', 'voltage 50-75%'], dtype='<U26'), 0.0724, 0.2703, 1.1574]
# [2, array(['global_active_power 25-50%', 'voltage 75-100%'], dtype='<U26'), 0.122, 0.4556, 1.51]
# [2, array(['global_active_power 25-50%', 'weekday'], dtype='<U26'), 0.1882, 0.703, 0.9878]
# [2, array(['global_active_power 25-50%', 'weekend'], dtype='<U26'), 0.0795, 0.297, 1.0301]
# [2, array(['global_active_power 25-50%', 'winter'], dtype='<U26'), 0.0775, 0.2894, 1.0757]
# [2, array(['global_active_power 50-75%', 'global_intensity 50-75%'],
#       dtype='<U26'), 0.1995, 0.968, 4.7019]
# [2, array(['global_active_power 50-75%', 'global_reactive_power 0-25%'],
#       dtype='<U27'), 0.0536, 0.2601, 0.9746]
# [2, array(['global_active_power 50-75%', 'global_reactive_power 25-50%'],
#       dtype='<U28'), 0.0572, 0.2776, 1.1012]
# [2, array(['kitchen 0-25%', 'global_active_power 50-75%'], dtype='<U26'), 0.0514, 0.2494, 0.8872]
# [2, array(['global_active_power 50-75%', 'kitchen 50-75%'], dtype='<U26'), 0.0533, 0.2585, 1.0506]
# [2, array(['kitchen 75-100%', 'global_active_power 50-75%'], dtype='<U26'), 0.0528, 0.2561, 1.1498]
# [2, array(['laundry 25-50%', 'global_active_power 50-75%'], dtype='<U26'), 0.0556, 0.2698, 1.075]
# [2, array(['laundry 50-75%', 'global_active_power 50-75%'], dtype='<U26'), 0.0534, 0.2591, 1.0602]
# [2, array(['other 25-50%', 'global_active_power 50-75%'], dtype='<U26'), 0.0526, 0.2553, 0.8801]
# [2, array(['other 50-75%', 'global_active_power 50-75%'], dtype='<U26'), 0.0544, 0.2642, 1.1308]
# [2, array(['other 75-100%', 'global_active_power 50-75%'], dtype='<U26'), 0.0646, 0.3133, 1.4592]
# [2, array(['spring', 'global_active_power 50-75%'], dtype='<U26'), 0.0552, 0.268, 1.1091]
# [2, array(['summer', 'global_active_power 50-75%'], dtype='<U26'), 0.0519, 0.2519, 1.0369]
# [2, array(['voltage 0-25%', 'global_active_power 50-75%'], dtype='<U26'), 0.0582, 0.2823, 1.1885]
# [2, array(['voltage 25-50%', 'global_active_power 50-75%'], dtype='<U26'), 0.0584, 0.2832, 1.2463]
# [2, array(['voltage 50-75%', 'global_active_power 50-75%'], dtype='<U26'), 0.0502, 0.2438, 1.044]
# [2, array(['weekday', 'global_active_power 50-75%'], dtype='<U26'), 0.1538, 0.7462, 1.0485]
# [2, array(['weekend', 'global_active_power 50-75%'], dtype='<U26'), 0.0523, 0.2538, 0.8802]
# [2, array(['global_intensity 75-100%', 'global_active_power 75-100%'],
#       dtype='<U27'), 0.2158, 0.2158, 1.0]
# [2, array(['global_reactive_power 50-75%', 'global_active_power 75-100%'],
#       dtype='<U28'), 0.0501, 0.2291, 0.9416]
# [2, array(['global_reactive_power 75-100%', 'global_active_power 75-100%'],
#       dtype='<U29'), 0.0863, 0.3944, 1.6593]
# [2, array(['kitchen 75-100%', 'global_active_power 75-100%'], dtype='<U27'), 0.0891, 0.4074, 1.8292]
# [2, array(['laundry 25-50%', 'global_active_power 75-100%'], dtype='<U27'), 0.0513, 0.2343, 0.9335]
# [2, array(['laundry 75-100%', 'global_active_power 75-100%'], dtype='<U27'), 0.076, 0.3475, 1.4623]
# [2, array(['other 50-75%', 'global_active_power 75-100%'], dtype='<U27'), 0.0544, 0.2488, 1.065]
# [2, array(['other 75-100%', 'global_active_power 75-100%'], dtype='<U27'), 0.1501, 0.6862, 3.1954]
# [2, array(['spring', 'global_active_power 75-100%'], dtype='<U27'), 0.0557, 0.2544, 1.0528]
# [2, array(['voltage 0-25%', 'global_active_power 75-100%'], dtype='<U27'), 0.1082, 0.4947, 2.0828]
# [2, array(['voltage 25-50%', 'global_active_power 75-100%'], dtype='<U27'), 0.06, 0.2744, 1.2073]
# [2, array(['weekday', 'global_active_power 75-100%'], dtype='<U27'), 0.1427, 0.6523, 0.9166]
# [2, array(['global_active_power 75-100%', 'weekend'], dtype='<U27'), 0.0761, 0.3477, 1.2057]
# [2, array(['global_active_power 75-100%', 'winter'], dtype='<U27'), 0.0711, 0.3251, 1.2083]
# [2, array(['global_intensity 0-25%', 'global_reactive_power 0-25%'],
#       dtype='<U27'), 0.1437, 0.4572, 1.7131]
# [2, array(['global_intensity 0-25%', 'global_reactive_power 25-50%'],
#       dtype='<U28'), 0.0997, 0.317, 1.2578]
# [2, array(['global_reactive_power 50-75%', 'global_intensity 0-25%'],
#       dtype='<U28'), 0.0583, 0.2397, 0.7626]
# [2, array(['kitchen 0-25%', 'global_intensity 0-25%'], dtype='<U22'), 0.1204, 0.383, 1.3623]
# [2, array(['kitchen 25-50%', 'global_intensity 0-25%'], dtype='<U22'), 0.0917, 0.2917, 1.1662]
# [2, array(['global_intensity 0-25%', 'kitchen 50-75%'], dtype='<U22'), 0.0691, 0.2199, 0.8938]
# [2, array(['global_intensity 0-25%', 'laundry 0-25%'], dtype='<U22'), 0.1257, 0.4, 1.4983]
# [2, array(['laundry 25-50%', 'global_intensity 0-25%'], dtype='<U22'), 0.0847, 0.2695, 1.0739]
# [2, array(['laundry 50-75%', 'global_intensity 0-25%'], dtype='<U22'), 0.0772, 0.2457, 1.0051]
# [2, array(['other 0-25%', 'global_intensity 0-25%'], dtype='<U22'), 0.179, 0.5694, 2.1763]
# [2, array(['other 25-50%', 'global_intensity 0-25%'], dtype='<U22'), 0.1327, 0.4221, 1.4554]
# [2, array(['spring', 'global_intensity 0-25%'], dtype='<U22'), 0.0629, 0.2001, 0.8279]
# [2, array(['summer', 'global_intensity 0-25%'], dtype='<U22'), 0.0977, 0.3109, 1.2799]
# [2, array(['voltage 25-50%', 'global_intensity 0-25%'], dtype='<U22'), 0.0566, 0.2492, 0.7927]
# [2, array(['voltage 50-75%', 'global_intensity 0-25%'], dtype='<U22'), 0.0779, 0.2477, 1.0608]
# [2, array(['global_intensity 0-25%', 'voltage 75-100%'], dtype='<U22'), 0.1342, 0.4269, 1.4148]
# [2, array(['weekday', 'global_intensity 0-25%'], dtype='<U22'), 0.2309, 0.2309, 1.0]
# [2, array(['global_intensity 0-25%', 'weekend'], dtype='<U22'), 0.0835, 0.2655, 0.9208]
# [2, array(['global_intensity 0-25%', 'winter'], dtype='<U22'), 0.084, 0.2671, 0.9927]
# [2, array(['global_intensity 25-50%', 'global_reactive_power 25-50%'],
#       dtype='<U28'), 0.0515, 0.2044, 0.7855]
# [2, array(['global_intensity 25-50%', 'global_reactive_power 50-75%'],
#       dtype='<U28'), 0.0879, 0.3377, 1.3879]
# [2, array(['global_intensity 25-50%', 'global_reactive_power 75-100%'],
#       dtype='<U29'), 0.0884, 0.3398, 1.4294]
# [2, array(['global_intensity 25-50%', 'kitchen 0-25%'], dtype='<U23'), 0.064, 0.246, 0.8751]
# [2, array(['global_intensity 25-50%', 'kitchen 25-50%'], dtype='<U23'), 0.0678, 0.2605, 1.0415]
# [2, array(['global_intensity 25-50%', 'kitchen 50-75%'], dtype='<U23'), 0.0811, 0.3115, 1.266]
# [2, array(['global_intensity 25-50%', 'laundry 25-50%'], dtype='<U23'), 0.0602, 0.2314, 0.922]
# [2, array(['global_intensity 25-50%', 'laundry 50-75%'], dtype='<U23'), 0.0669, 0.2572, 1.0521]
# [2, array(['global_intensity 25-50%', 'laundry 75-100%'], dtype='<U23'), 0.0849, 0.3262, 1.3727]
# [2, array(['global_intensity 25-50%', 'other 25-50%'], dtype='<U23'), 0.0937, 0.36, 1.2413]
# [2, array(['global_intensity 25-50%', 'other 50-75%'], dtype='<U23'), 0.1213, 0.4661, 1.9951]
# [2, array(['global_intensity 25-50%', 'spring'], dtype='<U23'), 0.068, 0.2613, 1.0811]
# [2, array(['global_intensity 25-50%', 'summer'], dtype='<U23'), 0.0617, 0.2371, 0.976]
# [2, array(['global_intensity 25-50%', 'voltage 25-50%'], dtype='<U23'), 0.0516, 0.227, 0.8724]
# [2, array(['global_intensity 25-50%', 'voltage 50-75%'], dtype='<U23'), 0.0735, 0.2824, 1.2094]
# [2, array(['global_intensity 25-50%', 'voltage 75-100%'], dtype='<U23'), 0.1101, 0.423, 1.402]
# [2, array(['global_intensity 25-50%', 'weekday'], dtype='<U23'), 0.184, 0.7071, 0.9936]
# [2, array(['global_intensity 25-50%', 'weekend'], dtype='<U23'), 0.0762, 0.2929, 1.0159]
# [2, array(['global_intensity 25-50%', 'winter'], dtype='<U23'), 0.0694, 0.2668, 0.9915]
# [2, array(['global_reactive_power 0-25%', 'global_intensity 50-75%'],
#       dtype='<U27'), 0.0531, 0.2579, 0.9664]
# [2, array(['global_reactive_power 25-50%', 'global_intensity 50-75%'],
#       dtype='<U28'), 0.0567, 0.2756, 1.0933]
# [2, array(['kitchen 0-25%', 'global_intensity 50-75%'], dtype='<U23'), 0.0506, 0.246, 0.8749]
# [2, array(['kitchen 50-75%', 'global_intensity 50-75%'], dtype='<U23'), 0.054, 0.2621, 1.0655]
# [2, array(['kitchen 75-100%', 'global_intensity 50-75%'], dtype='<U23'), 0.0528, 0.2565, 1.1517]
# [2, array(['laundry 25-50%', 'global_intensity 50-75%'], dtype='<U23'), 0.0555, 0.2696, 1.0741]
# [2, array(['laundry 50-75%', 'global_intensity 50-75%'], dtype='<U23'), 0.0533, 0.2591, 1.0599]
# [2, array(['other 25-50%', 'global_intensity 50-75%'], dtype='<U23'), 0.0534, 0.2594, 0.8943]
# [2, array(['other 50-75%', 'global_intensity 50-75%'], dtype='<U23'), 0.0555, 0.2694, 1.1534]
# [2, array(['other 75-100%', 'global_intensity 50-75%'], dtype='<U23'), 0.0627, 0.3044, 1.4176]
# [2, array(['spring', 'global_intensity 50-75%'], dtype='<U23'), 0.055, 0.2672, 1.1055]
# [2, array(['summer', 'global_intensity 50-75%'], dtype='<U23'), 0.0519, 0.2521, 1.0379]
# [2, array(['voltage 0-25%', 'global_intensity 50-75%'], dtype='<U23'), 0.0567, 0.2753, 1.159]
# [2, array(['voltage 25-50%', 'global_intensity 50-75%'], dtype='<U23'), 0.0586, 0.2845, 1.2518]
# [2, array(['voltage 50-75%', 'global_intensity 50-75%'], dtype='<U23'), 0.051, 0.2476, 1.0603]
# [2, array(['weekday', 'global_intensity 50-75%'], dtype='<U23'), 0.1538, 0.7469, 1.0495]
# [2, array(['weekend', 'global_intensity 50-75%'], dtype='<U23'), 0.0521, 0.2531, 0.8777]
# [2, array(['global_reactive_power 50-75%', 'global_intensity 75-100%'],
#       dtype='<U28'), 0.0502, 0.2285, 0.9392]
# [2, array(['global_intensity 75-100%', 'global_reactive_power 75-100%'],
#       dtype='<U29'), 0.0875, 0.3988, 1.6777]
# [2, array(['global_intensity 75-100%', 'kitchen 75-100%'], dtype='<U24'), 0.0894, 0.4073, 1.8289]
# [2, array(['global_intensity 75-100%', 'laundry 25-50%'], dtype='<U24'), 0.0505, 0.2302, 0.9172]
# [2, array(['global_intensity 75-100%', 'laundry 75-100%'], dtype='<U24'), 0.0768, 0.3497, 1.4717]
# [2, array(['global_intensity 75-100%', 'other 50-75%'], dtype='<U24'), 0.0542, 0.2468, 1.0564]
# [2, array(['global_intensity 75-100%', 'other 75-100%'], dtype='<U24'), 0.1511, 0.6882, 3.205]
# [2, array(['global_intensity 75-100%', 'spring'], dtype='<U24'), 0.0558, 0.2541, 1.0513]
# [2, array(['global_intensity 75-100%', 'voltage 0-25%'], dtype='<U24'), 0.1101, 0.5016, 2.112]
# [2, array(['global_intensity 75-100%', 'voltage 25-50%'], dtype='<U24'), 0.0605, 0.2755, 1.2121]
# [2, array(['global_intensity 75-100%', 'weekday'], dtype='<U24'), 0.143, 0.6513, 0.9152]
# [2, array(['global_intensity 75-100%', 'weekend'], dtype='<U24'), 0.0765, 0.3487, 1.2093]
# [2, array(['global_intensity 75-100%', 'winter'], dtype='<U24'), 0.0703, 0.3204, 1.1909]
# [2, array(['kitchen 0-25%', 'global_reactive_power 0-25%'], dtype='<U27'), 0.0876, 0.3281, 1.167]
# [2, array(['kitchen 25-50%', 'global_reactive_power 0-25%'], dtype='<U27'), 0.08, 0.2999, 1.1988]
# [2, array(['kitchen 50-75%', 'global_reactive_power 0-25%'], dtype='<U27'), 0.0602, 0.2256, 0.9168]
# [2, array(['laundry 0-25%', 'global_reactive_power 0-25%'], dtype='<U27'), 0.1074, 0.4024, 1.5075]
# [2, array(['laundry 25-50%', 'global_reactive_power 0-25%'], dtype='<U27'), 0.0922, 0.3454, 1.3763]
# [2, array(['laundry 50-75%', 'global_reactive_power 0-25%'], dtype='<U27'), 0.0584, 0.2189, 0.8957]
# [2, array(['other 0-25%', 'global_reactive_power 0-25%'], dtype='<U27'), 0.1019, 0.3817, 1.4588]
# [2, array(['other 25-50%', 'global_reactive_power 0-25%'], dtype='<U27'), 0.0846, 0.317, 1.0929]
# [2, array(['spring', 'global_reactive_power 0-25%'], dtype='<U27'), 0.0646, 0.242, 1.0015]
# [2, array(['voltage 0-25%', 'global_reactive_power 0-25%'], dtype='<U27'), 0.0565, 0.2117, 0.8913]
# [2, array(['voltage 25-50%', 'global_reactive_power 0-25%'], dtype='<U27'), 0.0503, 0.2212, 0.8287]
# [2, array(['voltage 50-75%', 'global_reactive_power 0-25%'], dtype='<U27'), 0.0597, 0.2237, 0.9579]
# [2, array(['voltage 75-100%', 'global_reactive_power 0-25%'], dtype='<U27'), 0.1004, 0.3763, 1.2471]
# [2, array(['weekday', 'global_reactive_power 0-25%'], dtype='<U27'), 0.1966, 0.7365, 1.0349]
# [2, array(['weekend', 'global_reactive_power 0-25%'], dtype='<U27'), 0.0703, 0.2635, 0.9139]
# [2, array(['winter', 'global_reactive_power 0-25%'], dtype='<U27'), 0.0943, 0.3533, 1.3131]
# [2, array(['kitchen 0-25%', 'global_reactive_power 25-50%'], dtype='<U28'), 0.0706, 0.2802, 0.9967]
# [2, array(['kitchen 25-50%', 'global_reactive_power 25-50%'], dtype='<U28'), 0.0675, 0.2678, 1.0706]
# [2, array(['global_reactive_power 25-50%', 'kitchen 50-75%'], dtype='<U28'), 0.0612, 0.2427, 0.9863]
# [2, array(['kitchen 75-100%', 'global_reactive_power 25-50%'], dtype='<U28'), 0.0528, 0.2093, 0.94]
# [2, array(['laundry 0-25%', 'global_reactive_power 25-50%'], dtype='<U28'), 0.0737, 0.2925, 1.0958]
# [2, array(['laundry 25-50%', 'global_reactive_power 25-50%'], dtype='<U28'), 0.0822, 0.3261, 1.2992]
# [2, array(['laundry 50-75%', 'global_reactive_power 25-50%'], dtype='<U28'), 0.0702, 0.2785, 1.1394]
# [2, array(['other 0-25%', 'global_reactive_power 25-50%'], dtype='<U28'), 0.0594, 0.2358, 0.9012]
# [2, array(['other 25-50%', 'global_reactive_power 25-50%'], dtype='<U28'), 0.0883, 0.3504, 1.2083]
# [2, array(['other 50-75%', 'global_reactive_power 25-50%'], dtype='<U28'), 0.0574, 0.2278, 0.9754]
# [2, array(['spring', 'global_reactive_power 25-50%'], dtype='<U28'), 0.064, 0.2539, 1.0506]
# [2, array(['voltage 0-25%', 'global_reactive_power 25-50%'], dtype='<U28'), 0.0555, 0.22, 0.9265]
# [2, array(['voltage 25-50%', 'global_reactive_power 25-50%'], dtype='<U28'), 0.0551, 0.2186, 0.9618]
# [2, array(['voltage 50-75%', 'global_reactive_power 25-50%'], dtype='<U28'), 0.0585, 0.2322, 0.9945]
# [2, array(['voltage 75-100%', 'global_reactive_power 25-50%'], dtype='<U28'), 0.083, 0.3291, 1.0908]
# [2, array(['weekday', 'global_reactive_power 25-50%'], dtype='<U28'), 0.1862, 0.7388, 1.0382]
# [2, array(['weekend', 'global_reactive_power 25-50%'], dtype='<U28'), 0.0658, 0.2612, 0.9058]
# [2, array(['global_reactive_power 25-50%', 'winter'], dtype='<U28'), 0.0703, 0.279, 1.037]
# [2, array(['global_reactive_power 50-75%', 'kitchen 0-25%'], dtype='<U28'), 0.0692, 0.2845, 1.012]
# [2, array(['global_reactive_power 50-75%', 'kitchen 25-50%'], dtype='<U28'), 0.0572, 0.2351, 0.9398]
# [2, array(['global_reactive_power 50-75%', 'kitchen 50-75%'], dtype='<U28'), 0.0616, 0.2532, 1.0289]
# [2, array(['global_reactive_power 50-75%', 'kitchen 75-100%'], dtype='<U28'), 0.0553, 0.2273, 1.0205]
# [2, array(['global_reactive_power 50-75%', 'laundry 0-25%'], dtype='<U28'), 0.0575, 0.2364, 0.8858]
# [2, array(['global_reactive_power 50-75%', 'laundry 25-50%'], dtype='<U28'), 0.0504, 0.207, 0.8246]
# [2, array(['global_reactive_power 50-75%', 'laundry 50-75%'], dtype='<U28'), 0.0676, 0.2778, 1.1365]
# [2, array(['global_reactive_power 50-75%', 'laundry 75-100%'], dtype='<U28'), 0.0678, 0.2788, 1.1731]
# [2, array(['global_reactive_power 50-75%', 'other 0-25%'], dtype='<U28'), 0.0618, 0.2541, 0.9712]
# [2, array(['global_reactive_power 50-75%', 'other 25-50%'], dtype='<U28'), 0.0678, 0.2785, 0.9602]
# [2, array(['global_reactive_power 50-75%', 'other 50-75%'], dtype='<U28'), 0.066, 0.2712, 1.1611]
# [2, array(['global_reactive_power 50-75%', 'spring'], dtype='<U28'), 0.0583, 0.2395, 0.9908]
# [2, array(['global_reactive_power 50-75%', 'summer'], dtype='<U28'), 0.0677, 0.2781, 1.1448]
# [2, array(['global_reactive_power 50-75%', 'voltage 0-25%'], dtype='<U28'), 0.0549, 0.2255, 0.9494]
# [2, array(['global_reactive_power 50-75%', 'voltage 25-50%'], dtype='<U28'), 0.0604, 0.2482, 1.0922]
# [2, array(['global_reactive_power 50-75%', 'voltage 50-75%'], dtype='<U28'), 0.0583, 0.2397, 1.0267]
# [2, array(['global_reactive_power 50-75%', 'voltage 75-100%'], dtype='<U28'), 0.0697, 0.2866, 0.9498]
# [2, array(['global_reactive_power 50-75%', 'weekday'], dtype='<U28'), 0.1748, 0.7184, 1.0094]
# [2, array(['global_reactive_power 50-75%', 'weekend'], dtype='<U28'), 0.0685, 0.2816, 0.9768]
# [2, array(['global_reactive_power 50-75%', 'winter'], dtype='<U28'), 0.0582, 0.239, 0.8884]
# [2, array(['kitchen 0-25%', 'global_reactive_power 75-100%'], dtype='<U29'), 0.0537, 0.2259, 0.8036]
# [2, array(['global_reactive_power 75-100%', 'kitchen 50-75%'], dtype='<U29'), 0.0631, 0.2653, 1.0784]
# [2, array(['global_reactive_power 75-100%', 'kitchen 75-100%'], dtype='<U29'), 0.0755, 0.3178, 1.4269]
# [2, array(['global_reactive_power 75-100%', 'laundry 75-100%'], dtype='<U29'), 0.135, 0.5679, 2.39]
# [2, array(['global_reactive_power 75-100%', 'other 50-75%'], dtype='<U29'), 0.0704, 0.296, 1.2673]
# [2, array(['global_reactive_power 75-100%', 'other 75-100%'], dtype='<U29'), 0.0795, 0.3345, 1.5575]
# [2, array(['global_reactive_power 75-100%', 'spring'], dtype='<U29'), 0.0548, 0.2305, 0.954]
# [2, array(['summer', 'global_reactive_power 75-100%'], dtype='<U29'), 0.0829, 0.3486, 1.4352]
# [2, array(['global_reactive_power 75-100%', 'voltage 0-25%'], dtype='<U29'), 0.0707, 0.2973, 1.2518]
# [2, array(['global_reactive_power 75-100%', 'voltage 25-50%'], dtype='<U29'), 0.0615, 0.2587, 1.1384]
# [2, array(['global_reactive_power 75-100%', 'voltage 50-75%'], dtype='<U29'), 0.0569, 0.2395, 1.0258]
# [2, array(['global_reactive_power 75-100%', 'weekday'], dtype='<U29'), 0.1541, 0.6482, 0.9108]
# [2, array(['global_reactive_power 75-100%', 'weekend'], dtype='<U29'), 0.0836, 0.3518, 1.2203]
# [2, array(['kitchen 0-25%', 'laundry 0-25%'], dtype='<U13'), 0.1615, 0.5745, 2.1521]
# [2, array(['kitchen 0-25%', 'laundry 50-75%'], dtype='<U14'), 0.0609, 0.2165, 0.8857]
# [2, array(['kitchen 0-25%', 'laundry 75-100%'], dtype='<U15'), 0.0588, 0.209, 0.8797]
# [2, array(['other 0-25%', 'kitchen 0-25%'], dtype='<U13'), 0.0825, 0.2933, 1.1212]
# [2, array(['kitchen 0-25%', 'other 25-50%'], dtype='<U13'), 0.0844, 0.3002, 1.0351]
# [2, array(['kitchen 0-25%', 'other 50-75%'], dtype='<U13'), 0.0607, 0.2158, 0.9238]
# [2, array(['kitchen 0-25%', 'other 75-100%'], dtype='<U13'), 0.0536, 0.2496, 0.8879]
# [2, array(['kitchen 0-25%', 'spring'], dtype='<U13'), 0.0587, 0.2089, 0.8645]
# [2, array(['kitchen 0-25%', 'summer'], dtype='<U13'), 0.0705, 0.2507, 1.0319]
# [2, array(['kitchen 0-25%', 'voltage 0-25%'], dtype='<U13'), 0.1013, 0.3603, 1.5172]
# [2, array(['kitchen 0-25%', 'voltage 25-50%'], dtype='<U14'), 0.057, 0.2028, 0.8921]
# [2, array(['kitchen 0-25%', 'voltage 50-75%'], dtype='<U14'), 0.057, 0.2029, 0.8688]
# [2, array(['kitchen 0-25%', 'voltage 75-100%'], dtype='<U15'), 0.0658, 0.2341, 0.7757]
# [2, array(['kitchen 0-25%', 'weekday'], dtype='<U13'), 0.2096, 0.2096, 1.0]
# [2, array(['kitchen 0-25%', 'weekend'], dtype='<U13'), 0.0715, 0.2544, 0.8825]
# [2, array(['kitchen 0-25%', 'winter'], dtype='<U13'), 0.0884, 0.3146, 1.1691]
# [2, array(['kitchen 25-50%', 'laundry 0-25%'], dtype='<U14'), 0.086, 0.3438, 1.288]
# [2, array(['laundry 25-50%', 'kitchen 25-50%'], dtype='<U14'), 0.0671, 0.2684, 1.0693]
# [2, array(['laundry 50-75%', 'kitchen 25-50%'], dtype='<U14'), 0.0512, 0.2048, 0.838]
# [2, array(['other 0-25%', 'kitchen 25-50%'], dtype='<U14'), 0.0678, 0.2712, 1.0365]
# [2, array(['other 25-50%', 'kitchen 25-50%'], dtype='<U14'), 0.0724, 0.2893, 0.9975]
# [2, array(['other 50-75%', 'kitchen 25-50%'], dtype='<U14'), 0.0615, 0.2459, 1.0525]
# [2, array(['spring', 'kitchen 25-50%'], dtype='<U14'), 0.0547, 0.2187, 0.9049]
# [2, array(['summer', 'kitchen 25-50%'], dtype='<U14'), 0.0519, 0.2075, 0.8542]
# [2, array(['voltage 25-50%', 'kitchen 25-50%'], dtype='<U14'), 0.0627, 0.2508, 1.1035]
# [2, array(['voltage 50-75%', 'kitchen 25-50%'], dtype='<U14'), 0.0538, 0.2151, 0.9211]
# [2, array(['kitchen 25-50%', 'voltage 75-100%'], dtype='<U15'), 0.087, 0.3478, 1.1527]
# [2, array(['weekday', 'kitchen 25-50%'], dtype='<U14'), 0.1776, 0.71, 0.9977]
# [2, array(['kitchen 25-50%', 'weekend'], dtype='<U14'), 0.0725, 0.29, 1.0057]
# [2, array(['kitchen 25-50%', 'winter'], dtype='<U14'), 0.0903, 0.3609, 1.3412]
# [2, array(['laundry 25-50%', 'kitchen 50-75%'], dtype='<U14'), 0.1463, 0.5945, 2.3685]
# [2, array(['laundry 75-100%', 'kitchen 50-75%'], dtype='<U15'), 0.0603, 0.2452, 1.0319]
# [2, array(['other 0-25%', 'kitchen 50-75%'], dtype='<U14'), 0.0629, 0.2558, 0.9777]
# [2, array(['other 25-50%', 'kitchen 50-75%'], dtype='<U14'), 0.0815, 0.3313, 1.1421]
# [2, array(['other 50-75%', 'kitchen 50-75%'], dtype='<U14'), 0.0593, 0.2409, 1.0312]
# [2, array(['spring', 'kitchen 50-75%'], dtype='<U14'), 0.0735, 0.2989, 1.2367]
# [2, array(['summer', 'kitchen 50-75%'], dtype='<U14'), 0.0503, 0.2046, 0.8422]
# [2, array(['voltage 50-75%', 'kitchen 50-75%'], dtype='<U14'), 0.0657, 0.2669, 1.143]
# [2, array(['voltage 75-100%', 'kitchen 50-75%'], dtype='<U15'), 0.1098, 0.4464, 1.4795]
# [2, array(['weekday', 'kitchen 50-75%'], dtype='<U14'), 0.1769, 0.719, 1.0103]
# [2, array(['weekend', 'kitchen 50-75%'], dtype='<U14'), 0.0691, 0.281, 0.9745]
# [2, array(['winter', 'kitchen 50-75%'], dtype='<U14'), 0.0684, 0.2781, 1.0337]
# [2, array(['laundry 50-75%', 'kitchen 75-100%'], dtype='<U15'), 0.0929, 0.4172, 1.7066]
# [2, array(['laundry 75-100%', 'kitchen 75-100%'], dtype='<U15'), 0.0728, 0.3267, 1.375]
# [2, array(['other 25-50%', 'kitchen 75-100%'], dtype='<U15'), 0.0518, 0.2325, 0.8015]
# [2, array(['other 50-75%', 'kitchen 75-100%'], dtype='<U15'), 0.0522, 0.2342, 1.0028]
# [2, array(['kitchen 75-100%', 'other 75-100%'], dtype='<U15'), 0.0704, 0.316, 1.4715]
# [2, array(['kitchen 75-100%', 'spring'], dtype='<U15'), 0.0547, 0.2456, 1.0164]
# [2, array(['summer', 'kitchen 75-100%'], dtype='<U15'), 0.0702, 0.3152, 1.2977]
# [2, array(['voltage 0-25%', 'kitchen 75-100%'], dtype='<U15'), 0.066, 0.2965, 1.2485]
# [2, array(['voltage 25-50%', 'kitchen 75-100%'], dtype='<U15'), 0.0606, 0.272, 1.1967]
# [2, array(['voltage 50-75%', 'kitchen 75-100%'], dtype='<U15'), 0.057, 0.2559, 1.0961]
# [2, array(['weekday', 'kitchen 75-100%'], dtype='<U15'), 0.1476, 0.6626, 0.9311]
# [2, array(['kitchen 75-100%', 'weekend'], dtype='<U15'), 0.0751, 0.3374, 1.1701]
# [2, array(['other 0-25%', 'laundry 0-25%'], dtype='<U13'), 0.0858, 0.3213, 1.2281]
# [2, array(['other 25-50%', 'laundry 0-25%'], dtype='<U13'), 0.0735, 0.2752, 0.9489]
# [2, array(['other 50-75%', 'laundry 0-25%'], dtype='<U13'), 0.0581, 0.2178, 0.9323]
# [2, array(['spring', 'laundry 0-25%'], dtype='<U13'), 0.0697, 0.261, 1.08]
# [2, array(['summer', 'laundry 0-25%'], dtype='<U13'), 0.076, 0.2847, 1.1722]
# [2, array(['voltage 0-25%', 'laundry 0-25%'], dtype='<U13'), 0.0893, 0.3344, 1.4081]
# [2, array(['voltage 25-50%', 'laundry 0-25%'], dtype='<U14'), 0.0594, 0.2225, 0.9791]
# [2, array(['voltage 50-75%', 'laundry 0-25%'], dtype='<U14'), 0.0546, 0.2047, 0.8765]
# [2, array(['voltage 75-100%', 'laundry 0-25%'], dtype='<U15'), 0.0636, 0.2384, 0.7901]
# [2, array(['weekday', 'laundry 0-25%'], dtype='<U13'), 0.1931, 0.7235, 1.0167]
# [2, array(['weekend', 'laundry 0-25%'], dtype='<U13'), 0.0738, 0.2765, 0.9589]
# [2, array(['laundry 0-25%', 'winter'], dtype='<U13'), 0.077, 0.2885, 1.0721]
# [2, array(['other 25-50%', 'laundry 25-50%'], dtype='<U14'), 0.0843, 0.3359, 1.158]
# [2, array(['laundry 25-50%', 'other 50-75%'], dtype='<U14'), 0.0643, 0.256, 1.0961]
# [2, array(['laundry 25-50%', 'other 75-100%'], dtype='<U14'), 0.0549, 0.2187, 1.0186]
# [2, array(['laundry 25-50%', 'spring'], dtype='<U14'), 0.0689, 0.2745, 1.1359]
# [2, array(['laundry 25-50%', 'voltage 50-75%'], dtype='<U14'), 0.0611, 0.2433, 1.0419]
# [2, array(['laundry 25-50%', 'voltage 75-100%'], dtype='<U15'), 0.1146, 0.4567, 1.5136]
# [2, array(['laundry 25-50%', 'weekday'], dtype='<U14'), 0.182, 0.725, 1.0187]
# [2, array(['laundry 25-50%', 'weekend'], dtype='<U14'), 0.069, 0.275, 0.9539]
# [2, array(['laundry 25-50%', 'winter'], dtype='<U14'), 0.0947, 0.3774, 1.4027]
# [2, array(['other 0-25%', 'laundry 50-75%'], dtype='<U14'), 0.0684, 0.2797, 1.069]
# [2, array(['other 25-50%', 'laundry 50-75%'], dtype='<U14'), 0.0714, 0.2921, 1.0071]
# [2, array(['other 50-75%', 'laundry 50-75%'], dtype='<U14'), 0.0532, 0.2175, 0.9311]
# [2, array(['laundry 50-75%', 'other 75-100%'], dtype='<U14'), 0.0515, 0.2107, 0.9812]
# [2, array(['summer', 'laundry 50-75%'], dtype='<U14'), 0.0707, 0.2892, 1.1908]
# [2, array(['voltage 25-50%', 'laundry 50-75%'], dtype='<U14'), 0.0621, 0.2539, 1.1173]
# [2, array(['voltage 50-75%', 'laundry 50-75%'], dtype='<U14'), 0.0627, 0.2565, 1.0986]
# [2, array(['laundry 50-75%', 'voltage 75-100%'], dtype='<U15'), 0.0702, 0.2871, 0.9514]
# [2, array(['weekday', 'laundry 50-75%'], dtype='<U14'), 0.1766, 0.7224, 1.015]
# [2, array(['laundry 50-75%', 'weekend'], dtype='<U14'), 0.0679, 0.2776, 0.9629]
# [2, array(['laundry 50-75%', 'winter'], dtype='<U14'), 0.0502, 0.2052, 0.7628]
# [2, array(['other 0-25%', 'laundry 75-100%'], dtype='<U15'), 0.06, 0.2523, 0.9645]
# [2, array(['other 25-50%', 'laundry 75-100%'], dtype='<U15'), 0.0609, 0.2561, 0.8831]
# [2, array(['other 50-75%', 'laundry 75-100%'], dtype='<U15'), 0.058, 0.2442, 1.0454]
# [2, array(['laundry 75-100%', 'other 75-100%'], dtype='<U15'), 0.0588, 0.2473, 1.1517]
# ...
#        'global_active_power 0-25%'], dtype='<U25'), 0.083, 0.2699, 2.8374]
# [4, array(['summer', 'global_intensity 0-25%', 'weekday',
#        'global_active_power 0-25%'], dtype='<U25'), 0.0729, 0.2373, 3.2313]
# [4, array(['global_intensity 0-25%', 'voltage 50-75%',
#        'global_active_power 0-25%', 'weekday'], dtype='<U25'), 0.0534, 0.2287, 1.0624]
# [4, array(['global_intensity 0-25%', 'weekday', 'global_active_power 0-25%',
#        'voltage 75-100%'], dtype='<U25'), 0.0858, 0.2791, 2.8877]
# [4, array(['global_intensity 0-25%', 'global_active_power 0-25%',
#        'voltage 75-100%', 'winter'], dtype='<U25'), 0.0601, 0.2234, 1.8849]
# [4, array(['global_intensity 0-25%', 'weekday', 'global_active_power 0-25%',
#        'winter'], dtype='<U25'), 0.0549, 0.204, 0.9478]
# [4, array(['other 0-25%', 'weekday', 'global_active_power 0-25%',
#        'global_reactive_power 0-25%'], dtype='<U27'), 0.0617, 0.2007, 2.6059]
# [4, array(['kitchen 0-25%', 'weekday', 'global_active_power 0-25%',
#        'laundry 0-25%'], dtype='<U25'), 0.0633, 0.2058, 1.7124]
# [4, array(['other 0-25%', 'kitchen 0-25%', 'weekday',
#        'global_active_power 0-25%'], dtype='<U25'), 0.0567, 0.2017, 1.443]
# [4, array(['other 0-25%', 'weekday', 'global_active_power 0-25%',
#        'laundry 0-25%'], dtype='<U25'), 0.0539, 0.2019, 1.4447]
# [4, array(['other 0-25%', 'summer', 'weekday', 'global_active_power 0-25%'],
#       dtype='<U25'), 0.0727, 0.2366, 2.3352]
# [4, array(['other 25-50%', 'weekday', 'global_active_power 0-25%',
#        'voltage 75-100%'], dtype='<U25'), 0.0505, 0.4191, 1.9259]
# [4, array(['global_intensity 25-50%', 'global_active_power 25-50%',
#        'global_reactive_power 50-75%', 'weekday'], dtype='<U28'), 0.0597, 0.2231, 3.5428]
# [4, array(['global_intensity 25-50%', 'global_active_power 25-50%',
#        'global_reactive_power 75-100%', 'weekday'], dtype='<U29'), 0.0526, 0.2021, 3.7128]
# [4, array(['global_intensity 25-50%', 'global_active_power 25-50%', 'weekday',
#        'kitchen 50-75%'], dtype='<U26'), 0.0538, 0.2008, 3.4921]
# [4, array(['global_intensity 25-50%', 'global_active_power 25-50%', 'weekday',
#        'laundry 75-100%'], dtype='<U26'), 0.052, 0.2187, 1.2844]
# [4, array(['global_intensity 25-50%', 'global_active_power 25-50%', 'weekday',
#        'other 25-50%'], dtype='<U26'), 0.0619, 0.2312, 3.4867]
# [4, array(['global_intensity 25-50%', 'global_active_power 25-50%',
#        'other 50-75%', 'voltage 75-100%'], dtype='<U26'), 0.0585, 0.2186, 3.6925]
# [4, array(['global_intensity 25-50%', 'global_active_power 25-50%',
#        'other 50-75%', 'weekday'], dtype='<U26'), 0.0843, 0.3147, 3.6894]
# [4, array(['global_intensity 25-50%', 'global_active_power 25-50%', 'weekday',
#        'voltage 75-100%'], dtype='<U26'), 0.0757, 0.2827, 3.5877]
# [4, array(['global_intensity 25-50%', 'global_active_power 25-50%',
#        'voltage 75-100%', 'winter'], dtype='<U26'), 0.0505, 0.2092, 1.3739]
# [4, array(['global_intensity 75-100%', 'other 75-100%',
#        'global_active_power 75-100%', 'global_reactive_power 75-100%'],
#       dtype='<U29'), 0.0587, 0.2681, 4.5114]
# [4, array(['global_intensity 75-100%', 'other 75-100%', 'kitchen 75-100%',
#        'global_active_power 75-100%'], dtype='<U27'), 0.0549, 0.2508, 4.5455]
# [4, array(['global_intensity 75-100%', 'weekday', 'kitchen 75-100%',
#        'global_active_power 75-100%'], dtype='<U27'), 0.0533, 0.2436, 4.5]
# [4, array(['voltage 0-25%', 'global_intensity 75-100%', 'other 75-100%',
#        'global_active_power 75-100%'], dtype='<U27'), 0.0811, 0.3707, 4.535]
# [4, array(['global_intensity 75-100%', 'weekday', 'other 75-100%',
#        'global_active_power 75-100%'], dtype='<U27'), 0.0979, 0.4474, 4.5303]
# [4, array(['global_intensity 75-100%', 'other 75-100%',
#        'global_active_power 75-100%', 'weekend'], dtype='<U27'), 0.0517, 0.2364, 4.5209]
# [4, array(['global_intensity 75-100%', 'other 75-100%',
#        'global_active_power 75-100%', 'winter'], dtype='<U27'), 0.0578, 0.2643, 4.552]
# [4, array(['global_intensity 75-100%', 'weekday', 'voltage 0-25%',
#        'global_active_power 75-100%'], dtype='<U27'), 0.0681, 0.3111, 4.474]
# [4, array(['voltage 0-25%', 'weekday', 'other 75-100%',
#        'global_active_power 75-100%'], dtype='<U27'), 0.0509, 0.2328, 3.7028]
# [4, array(['other 0-25%', 'weekday', 'global_intensity 0-25%',
#        'global_reactive_power 0-25%'], dtype='<U27'), 0.0619, 0.2319, 1.7312]
# [4, array(['weekday', 'global_intensity 0-25%', 'voltage 75-100%',
#        'global_reactive_power 0-25%'], dtype='<U27'), 0.0524, 0.3643, 1.6741]
# [4, array(['kitchen 0-25%', 'weekday', 'global_intensity 0-25%',
#        'laundry 0-25%'], dtype='<U22'), 0.0637, 0.2025, 1.6849]
# [4, array(['other 0-25%', 'kitchen 0-25%', 'weekday',
#        'global_intensity 0-25%'], dtype='<U22'), 0.0545, 0.2084, 2.2533]
# [4, array(['other 0-25%', 'weekday', 'global_intensity 0-25%',
#        'laundry 0-25%'], dtype='<U22'), 0.0539, 0.202, 1.5082]
# [4, array(['other 0-25%', 'summer', 'weekday', 'global_intensity 0-25%'],
#       dtype='<U22'), 0.0674, 0.2143, 2.1147]
# [4, array(['other 25-50%', 'weekday', 'global_intensity 0-25%',
#        'voltage 75-100%'], dtype='<U22'), 0.0587, 0.2023, 2.0925]
# [4, array(['weekday', 'global_intensity 0-25%', 'voltage 75-100%', 'winter'],
#       dtype='<U22'), 0.0503, 0.3751, 1.9406]
# [4, array(['global_intensity 75-100%', 'weekday', 'other 75-100%',
#        'voltage 0-25%'], dtype='<U24'), 0.0514, 0.234, 3.7224]
# [4, array(['kitchen 0-25%', 'weekday', 'laundry 0-25%',
#        'global_reactive_power 0-25%'], dtype='<U27'), 0.0511, 0.5836, 3.0215]
# [4, array(['laundry 25-50%', 'weekday', 'voltage 75-100%', 'kitchen 50-75%'],
#       dtype='<U15'), 0.051, 0.2072, 2.514]
# [4, array(['other 25-50%', 'weekday', 'voltage 75-100%', 'winter'],
#       dtype='<U15'), 0.0525, 0.3892, 2.0137]
# [5, array(['False', 'global_intensity 0-25%', 'global_active_power 0-25%',
#        'global_reactive_power 0-25%', 'climate_control 0-25%'],
#       dtype='<U27'), 0.0627, 0.2041, 3.1758]
# [5, array(['kitchen 0-25%', 'False', 'global_intensity 0-25%',
#        'global_active_power 0-25%', 'climate_control 0-25%'], dtype='<U25'), 0.0885, 0.2815, 3.1657]
# [5, array(['laundry 0-25%', 'False', 'global_intensity 0-25%',
#        'global_active_power 0-25%', 'climate_control 0-25%'], dtype='<U25'), 0.0735, 0.2337, 2.5845]
# [5, array(['other 0-25%', 'False', 'global_intensity 0-25%',
#        'global_active_power 0-25%', 'climate_control 0-25%'], dtype='<U25'), 0.0626, 0.2036, 3.2465]
# [5, array(['False', 'global_intensity 0-25%', 'global_active_power 0-25%',
#        'other 25-50%', 'climate_control 0-25%'], dtype='<U25'), 0.0619, 0.2015, 3.0119]
# [5, array(['False', 'global_intensity 0-25%', 'global_active_power 0-25%',
#        'climate_control 0-25%', 'voltage 75-100%'], dtype='<U25'), 0.0569, 0.2512, 2.12]
# [5, array(['weekday', 'False', 'global_intensity 0-25%',
#        'global_active_power 0-25%', 'climate_control 0-25%'], dtype='<U25'), 0.0929, 0.2954, 1.9448]
# [5, array(['laundry 0-25%', 'kitchen 0-25%', 'False',
#        'global_active_power 0-25%', 'climate_control 0-25%'], dtype='<U25'), 0.0636, 0.2024, 3.1667]
# [5, array(['kitchen 0-25%', 'other 0-25%', 'False',
#        'global_active_power 0-25%', 'climate_control 0-25%'], dtype='<U25'), 0.0533, 0.2036, 2.2034]
# [5, array(['kitchen 0-25%', 'weekday', 'False', 'global_active_power 0-25%',
#        'climate_control 0-25%'], dtype='<U25'), 0.072, 0.2289, 3.1653]
# [5, array(['laundry 0-25%', 'weekday', 'False', 'global_active_power 0-25%',
#        'climate_control 0-25%'], dtype='<U25'), 0.0556, 0.2082, 2.1646]
# [5, array(['laundry 0-25%', 'kitchen 0-25%', 'False',
#        'global_intensity 0-25%', 'climate_control 0-25%'], dtype='<U22'), 0.0644, 0.2047, 3.1652]
# [5, array(['kitchen 0-25%', 'other 0-25%', 'False', 'global_intensity 0-25%',
#        'climate_control 0-25%'], dtype='<U22'), 0.0516, 0.2278, 3.3111]
# [5, array(['kitchen 0-25%', 'weekday', 'False', 'global_intensity 0-25%',
#        'climate_control 0-25%'], dtype='<U22'), 0.0707, 0.2247, 3.1665]
# [5, array(['laundry 0-25%', 'weekday', 'False', 'global_intensity 0-25%',
#        'climate_control 0-25%'], dtype='<U22'), 0.0564, 0.2113, 2.1678]
# [5, array(['laundry 0-25%', 'kitchen 0-25%', 'weekday', 'False',
#        'climate_control 0-25%'], dtype='<U21'), 0.0674, 0.2144, 2.4526]
# [5, array(['winter', 'weekday', 'False', 'climate_control 0-25%',
#        'voltage 75-100%'], dtype='<U21'), 0.0516, 0.2281, 2.0457]
# [5, array(['climate_control 75-100%', 'other 75-100%', 'False',
#        'global_intensity 75-100%', 'global_active_power 75-100%'],
#       dtype='<U27'), 0.0605, 0.2856, 2.4557]
# [5, array(['climate_control 75-100%', 'weekday', 'False',
#        'global_intensity 75-100%', 'global_active_power 75-100%'],
#       dtype='<U27'), 0.063, 0.2976, 2.7509]
# [5, array(['other 0-25%', 'False', 'global_intensity 0-25%',
#        'global_active_power 0-25%', 'global_reactive_power 0-25%'],
#       dtype='<U27'), 0.0591, 0.2214, 1.8125]
# [5, array(['False', 'global_intensity 0-25%', 'global_active_power 0-25%',
#        'global_reactive_power 0-25%', 'voltage 75-100%'], dtype='<U27'), 0.0561, 0.2103, 2.2123]
# [5, array(['weekday', 'False', 'global_intensity 0-25%',
#        'global_active_power 0-25%', 'global_reactive_power 0-25%'],
#       dtype='<U27'), 0.0728, 0.2369, 3.1622]
# [5, array(['laundry 0-25%', 'kitchen 0-25%', 'False',
#        'global_intensity 0-25%', 'global_active_power 0-25%'],
#       dtype='<U25'), 0.063, 0.205, 3.1696]
# [5, array(['kitchen 0-25%', 'other 0-25%', 'False', 'global_intensity 0-25%',
#        'global_active_power 0-25%'], dtype='<U25'), 0.0518, 0.2365, 3.4369]
# [5, array(['kitchen 0-25%', 'weekday', 'False', 'global_intensity 0-25%',
#        'global_active_power 0-25%'], dtype='<U25'), 0.0691, 0.2247, 3.1663]
# [5, array(['laundry 0-25%', 'other 0-25%', 'False', 'global_intensity 0-25%',
#        'global_active_power 0-25%'], dtype='<U25'), 0.0533, 0.2037, 2.2527]
# [5, array(['laundry 0-25%', 'weekday', 'False', 'global_intensity 0-25%',
#        'global_active_power 0-25%'], dtype='<U25'), 0.0659, 0.2143, 3.156]
# [5, array(['summer', 'other 0-25%', 'False', 'global_intensity 0-25%',
#        'global_active_power 0-25%'], dtype='<U25'), 0.062, 0.2018, 3.2482]
# [5, array(['other 0-25%', 'weekday', 'False', 'global_intensity 0-25%',
#        'global_active_power 0-25%'], dtype='<U25'), 0.0897, 0.2918, 3.2105]
# [5, array(['False', 'global_intensity 0-25%', 'global_active_power 0-25%',
#        'other 25-50%', 'voltage 75-100%'], dtype='<U25'), 0.057, 0.2603, 3.2023]
# [5, array(['weekday', 'False', 'global_intensity 0-25%',
#        'global_active_power 0-25%', 'other 25-50%'], dtype='<U25'), 0.0622, 0.2024, 2.8596]
# [5, array(['weekday', 'False', 'global_intensity 0-25%',
#        'global_active_power 0-25%', 'voltage 75-100%'], dtype='<U25'), 0.0678, 0.2205, 2.9163]
# [5, array(['winter', 'False', 'global_intensity 0-25%',
#        'global_active_power 0-25%', 'voltage 75-100%'], dtype='<U25'), 0.0542, 0.2016, 2.1202]
# [5, array(['voltage 0-25%', 'other 75-100%', 'False',
#        'global_intensity 75-100%', 'global_active_power 75-100%'],
#       dtype='<U27'), 0.0681, 0.3111, 4.5349]
# [5, array(['weekday', 'other 75-100%', 'False', 'global_intensity 75-100%',
#        'global_active_power 75-100%'], dtype='<U27'), 0.0775, 0.3542, 4.543]
# [5, array(['voltage 0-25%', 'weekday', 'False', 'global_intensity 75-100%',
#        'global_active_power 75-100%'], dtype='<U27'), 0.0571, 0.261, 4.4814]
# [5, array(['kitchen 0-25%', 'global_intensity 0-25%',
#        'global_active_power 0-25%', 'global_reactive_power 0-25%',
#        'climate_control 0-25%'], dtype='<U27'), 0.0523, 0.3146, 5.8588]
# [5, array(['laundry 0-25%', 'global_intensity 0-25%',
#        'global_active_power 0-25%', 'global_reactive_power 0-25%',
#        'climate_control 0-25%'], dtype='<U27'), 0.0529, 0.3182, 4.9749]
# [5, array(['weekday', 'global_intensity 0-25%', 'global_active_power 0-25%',
#        'global_reactive_power 0-25%', 'climate_control 0-25%'],
#       dtype='<U27'), 0.0593, 0.2222, 1.8484]
# [5, array(['laundry 0-25%', 'kitchen 0-25%', 'global_intensity 0-25%',
#        'global_active_power 0-25%', 'climate_control 0-25%'], dtype='<U25'), 0.0821, 0.261, 3.1658]
# [5, array(['kitchen 0-25%', 'other 0-25%', 'global_intensity 0-25%',
#        'global_active_power 0-25%', 'climate_control 0-25%'], dtype='<U25'), 0.0682, 0.2168, 3.1568]
# [5, array(['kitchen 0-25%', 'weekday', 'global_intensity 0-25%',
#        'global_active_power 0-25%', 'climate_control 0-25%'], dtype='<U25'), 0.0896, 0.2848, 3.1647]
# [5, array(['laundry 0-25%', 'weekday', 'global_intensity 0-25%',
#        'global_active_power 0-25%', 'climate_control 0-25%'], dtype='<U25'), 0.0719, 0.2285, 2.5573]
# [5, array(['other 0-25%', 'weekday', 'global_intensity 0-25%',
#        'global_active_power 0-25%', 'climate_control 0-25%'], dtype='<U25'), 0.0634, 0.2015, 1.5231]
# [5, array(['weekday', 'global_intensity 0-25%', 'global_active_power 0-25%',
#        'other 25-50%', 'climate_control 0-25%'], dtype='<U25'), 0.0568, 0.3419, 3.5938]
# [5, array(['laundry 0-25%', 'kitchen 0-25%', 'weekday',
#        'global_active_power 0-25%', 'climate_control 0-25%'], dtype='<U25'), 0.063, 0.2002, 3.1649]
# [5, array(['kitchen 0-25%', 'other 0-25%', 'weekday',
#        'global_active_power 0-25%', 'climate_control 0-25%'], dtype='<U25'), 0.0563, 0.2003, 3.0512]
# [5, array(['laundry 0-25%', 'kitchen 0-25%', 'weekday',
#        'global_intensity 0-25%', 'climate_control 0-25%'], dtype='<U22'), 0.0634, 0.2015, 3.165]
# [5, array(['kitchen 0-25%', 'other 0-25%', 'weekday',
#        'global_intensity 0-25%', 'climate_control 0-25%'], dtype='<U22'), 0.0542, 0.207, 2.2487]
# [5, array(['other 0-25%', 'weekday', 'global_intensity 0-25%',
#        'global_active_power 0-25%', 'climate_control 25-50%'],
#       dtype='<U25'), 0.0528, 0.2131, 1.611]
# [5, array(['climate_control 75-100%', 'weekday', 'other 75-100%',
#        'global_intensity 75-100%', 'global_active_power 75-100%'],
#       dtype='<U27'), 0.0506, 0.239, 2.4415]
# [5, array(['other 0-25%', 'weekday', 'global_intensity 0-25%',
#        'global_active_power 0-25%', 'global_reactive_power 0-25%'],
#       dtype='<U27'), 0.0617, 0.2006, 3.2412]
# [5, array(['laundry 0-25%', 'kitchen 0-25%', 'weekday',
#        'global_intensity 0-25%', 'global_active_power 0-25%'],
#       dtype='<U25'), 0.0622, 0.2025, 3.1802]
# [5, array(['kitchen 0-25%', 'other 0-25%', 'weekday',
#        'global_intensity 0-25%', 'global_active_power 0-25%'],
#       dtype='<U25'), 0.0544, 0.2081, 2.3117]
# [5, array(['laundry 0-25%', 'other 0-25%', 'weekday',
#        'global_intensity 0-25%', 'global_active_power 0-25%'],
#       dtype='<U25'), 0.0539, 0.2019, 1.5263]
# [5, array(['summer', 'other 0-25%', 'weekday', 'global_intensity 0-25%',
#        'global_active_power 0-25%'], dtype='<U25'), 0.0672, 0.2186, 3.2454]
# [5, array(['voltage 0-25%', 'weekday', 'other 75-100%',
#        'global_intensity 75-100%', 'global_active_power 75-100%'],
#       dtype='<U27'), 0.0509, 0.2328, 4.5318]
# [6, array(['laundry 0-25%', 'kitchen 0-25%', 'False',
#        'global_intensity 0-25%', 'global_active_power 0-25%',
#        'climate_control 0-25%'], dtype='<U25'), 0.0627, 0.2041, 3.1709]
# [6, array(['kitchen 0-25%', 'other 0-25%', 'False', 'global_intensity 0-25%',
#        'global_active_power 0-25%', 'climate_control 0-25%'], dtype='<U25'), 0.0514, 0.2272, 3.3089]
# [6, array(['kitchen 0-25%', 'weekday', 'False', 'global_intensity 0-25%',
#        'global_active_power 0-25%', 'climate_control 0-25%'], dtype='<U25'), 0.0688, 0.2187, 3.1662]
# [6, array(['laundry 0-25%', 'weekday', 'False', 'global_intensity 0-25%',
#        'global_active_power 0-25%', 'climate_control 0-25%'], dtype='<U25'), 0.0548, 0.2052, 2.2085]
# [6, array(['laundry 0-25%', 'kitchen 0-25%', 'weekday',
#        'global_intensity 0-25%', 'global_active_power 0-25%',
#        'climate_control 0-25%'], dtype='<U25'), 0.0619, 0.2015, 3.1799]
# [6, array(['kitchen 0-25%', 'other 0-25%', 'weekday',
#        'global_intensity 0-25%', 'global_active_power 0-25%',
#        'climate_control 0-25%'], dtype='<U25'), 0.0541, 0.2067, 2.3072]

# %%
# Filter by rhs=='Power Pattern *'
filter_RHS_ECP = True
if(filter_RHS_ECP):
    association_rules_np_rhs = []
    for r in range(len(association_rules_np)):
        # rhs = association_rules_np[r, 1][-1] # old
        rhs = association_rules_np[r][1][-1]
        if(rhs=='True' or rhs=='False'):
            association_rules_np_rhs.append(association_rules_np[r])
    association_rules_np_rhs = np.array(association_rules_np_rhs, dtype=object)
else:
    association_rules_np_rhs = association_rules_np
print('Rule Filtered: %d' %(len(association_rules_np_rhs)))
# Out:
# Rule Filtered: 104

# %%
# Sort rules by confidence
association_rules_np_rhs_sorted = association_rules_np_rhs[association_rules_np_rhs[:, 3].argsort()][::-1]
print(len(association_rules_np_rhs_sorted))
print(association_rules_np_rhs_sorted[:10])

# Length, Rule, Support, Confidence, Lift
# Out:
# 104
# [[1 array(['False'], dtype='<U5') 0.666 0.666 1.0]
#  [3 array(['voltage 0-25%', 'weekday', 'False'], dtype='<U13') 0.1229
#   0.5173 1.1079]
#  [3 array(['global_intensity 75-100%', 'weekday', 'False'], dtype='<U24')
#   0.1099 0.5007 1.0722]
#  [3 array(['summer', 'weekday', 'False'], dtype='<U7') 0.1215 0.5003
#   1.0715]
#  [3 array(['other 0-25%', 'weekday', 'False'], dtype='<U11') 0.1307
#   0.4997 1.0701]
#  [3
#   array(['global_reactive_power 50-75%', 'weekday', 'False'], dtype='<U28')
#   0.1149 0.4723 1.0115]
#  [2 array(['weekday', 'False'], dtype='<U7') 0.467 0.467 1.0]
#  [3 array(['laundry 25-50%', 'weekday', 'False'], dtype='<U14') 0.1146
#   0.4566 0.9777]
#  [3 array(['voltage 25-50%', 'weekday', 'False'], dtype='<U14') 0.1032
#   0.4539 0.9721]
#  [3 array(['laundry 50-75%', 'weekday', 'False'], dtype='<U14') 0.1103
#   0.4511 0.966]]

# %%
# Filter by rhs=='No change - True'
top_k = 10
filtered_rules = []
association_rules_np_rhs_buffer = []
for r in range(len(association_rules_np_rhs_sorted)):
    rhs = association_rules_np_rhs_sorted[r, 1][-1]
    if(rhs=='True' and association_rules_np_rhs_sorted[r, 0]>1):
        association_rules_np_rhs_buffer.append(association_rules_np_rhs_sorted[r])
association_rules_np_rhs_buffer = np.array(association_rules_np_rhs_buffer)
# print(association_rules_np_rhs_buffer[:top_k])
for rule in association_rules_np_rhs_buffer:
    # print(rule)
    if top_k < 1:
        break
    if rule[0] == 0 or rule[-1] < 1.1:
        # print(rule)
        # print(rule)
        continue
    else:
        print(rule)
        filtered_rules.extend(rule[1].tolist())
        top_k = top_k - 1

print('unique vars')
set(filtered_rules) - {'True'}
# Out:
# [2 array(['global_active_power 25-50%', 'True'], dtype='<U26') 0.1059
#  0.317 1.184]
# [2 array(['global_intensity 25-50%', 'True'], dtype='<U23') 0.1059 0.317
#  1.2181]
# [3
#  array(['global_intensity 25-50%', 'global_active_power 25-50%', 'True'],
#        dtype='<U26')
#  0.0977 0.2925 1.2111]
# [2 array(['voltage 50-75%', 'True'], dtype='<U14') 0.0943 0.2823 1.209]
# [3 array(['other 50-75%', 'weekday', 'True'], dtype='<U12') 0.0645 0.2763
#  1.129]
# [3 array(['laundry 50-75%', 'weekday', 'True'], dtype='<U14') 0.0663
#  0.2712 1.1085]
# [2 array(['other 50-75%', 'True'], dtype='<U12') 0.0903 0.2704 1.1577]
# [2 array(['climate_control 50-75%', 'True'], dtype='<U22') 0.0859 0.2571
#  1.1368]
# [3 array(['global_intensity 25-50%', 'weekday', 'True'], dtype='<U23')
#  0.0786 0.2353 1.2786]
# [3 array(['global_active_power 25-50%', 'weekday', 'True'], dtype='<U26')
#  0.0784 0.2348 1.2474]
# unique vars
# {'climate_control 50-75%',
#  'global_active_power 25-50%',
#  'global_intensity 25-50%',
#  'laundry 50-75%',
#  'other 50-75%',
#  'voltage 50-75%',
#  'weekday'}

# %%
association_rules_np_rhs_buffer
# Out:
# array([[2, array(['global_intensity 75-100%', 'True'], dtype='<U24'),
#         0.1625, 0.489, 2.2276],
#        [2, array(['climate_control 75-100%', 'True'], dtype='<U23'),
#         0.1426, 0.4293, 2.0265],
#        [2, array(['other 75-100%', 'True'], dtype='<U13'), 0.1405,
#         0.4228, 1.9687],
#        [2, array(['voltage 0-25%', 'True'], dtype='<U13'), 0.1361,
#         0.4095, 1.7243],
#        [2, array(['summer', 'True'], dtype='<U6'), 0.1168, 0.3516,
#         1.4476],
#        [3,
#         array(['global_intensity 75-100%', 'other 75-100%', 'True'], dtype='<U24'),
#         0.1151, 0.3463, 2.2924],
#        [2, array(['kitchen 75-100%', 'True'], dtype='<U15'), 0.1129,
#         0.3398, 1.5258],
#        [2,
#         array(['global_reactive_power 75-100%', 'True'], dtype='<U29'),
#         0.1106, 0.3329, 1.4004],
#        [2, array(['voltage 25-50%', 'True'], dtype='<U14'), 0.1018,
#         0.3064, 1.3481],
#        [2, array(['weekend', 'True'], dtype='<U7'), 0.1016, 0.3059,
#         1.0609],
#        [2, array(['laundry 75-100%', 'True'], dtype='<U15'), 0.0993,
#         0.2989, 1.2576],
#        [2, array(['global_active_power 50-75%', 'True'], dtype='<U26'),
#         0.0984, 0.2962, 1.4376],
#        [2, array(['global_intensity 50-75%', 'True'], dtype='<U23'),
#         0.0978, 0.2944, 1.4303],
#        [3,
#         array(['global_active_power 50-75%', 'global_intensity 50-75%', 'True'],
#               dtype='<U26')                                                     ,
#         0.0955, 0.2874, 1.4409],
#        [4, array(['climate_control 75-100%', 'global_intensity 75-100%',
#                   'other 75-100%', 'True'], dtype='<U24')               ,
#         0.0601, 0.2839, 2.467],
#        [3,
#         array(['climate_control 75-100%', 'other 75-100%', 'True'], dtype='<U23'),
#         0.0601, 0.2839, 2.0209],
#        [2, array(['voltage 50-75%', 'True'], dtype='<U14'), 0.0662,
#         0.2835, 0.8533],
#        [3,
#         array(['climate_control 75-100%', 'global_intensity 75-100%', 'True'],
#               dtype='<U24')                                                   ,
#         0.094, 0.2828, 2.2764],
#        [2, array(['climate_control 50-75%', 'True'], dtype='<U22'),
#         0.0916, 0.2758, 1.2196],
#        [3,
#         array(['voltage 0-25%', 'global_intensity 75-100%', 'True'], dtype='<U24'),
#         0.0896, 0.2698, 2.4502],
#        [3,
#         array(['global_intensity 75-100%', 'laundry 75-100%', 'True'],
#               dtype='<U24')                                           ,
#         0.0592, 0.2696, 2.7145],
#        [3,
#         array(['climate_control 75-100%', 'kitchen 75-100%', 'True'], dtype='<U23'),
#         0.0558, 0.2633, 2.3318],
#        [3,
#         array(['voltage 0-25%', 'climate_control 75-100%', 'True'], dtype='<U23'),
#         0.0538, 0.254, 1.8665],
#        [2, array(['laundry 0-25%', 'True'], dtype='<U13'), 0.0839,
#         0.2526, 0.9463],
#        [3,
#         array(['global_intensity 75-100%', 'weekend', 'True'], dtype='<U24'),
#         0.0554, 0.2522, 2.4819],
#        [3,
#         array(['laundry 75-100%', 'global_reactive_power 75-100%', 'True'],
#               dtype='<U29')                                                ,
#         0.0591, 0.2485, 2.5024],
#        [3,
#         array(['voltage 25-50%', 'climate_control 75-100%', 'True'], dtype='<U23'),
#         0.0526, 0.2482, 2.4376],
#        [2, array(['autumn', 'True'], dtype='<U6'), 0.0816, 0.2455,
#         0.9964],
#        [3,
#         array(['other 75-100%', 'global_reactive_power 75-100%', 'True'],
#               dtype='<U29')                                              ,
#         0.0568, 0.2391, 1.7022],
#        [2, array(['global_reactive_power 50-75%', 'True'], dtype='<U28'),
#         0.079, 0.2377, 0.9767],
#        [3,
#         array(['other 75-100%', 'kitchen 75-100%', 'True'], dtype='<U15'),
#         0.0529, 0.2375, 1.6911],
#        [2, array(['kitchen 25-50%', 'True'], dtype='<U14'), 0.0782,
#         0.2354, 0.9409],
#        [2, array(['spring', 'True'], dtype='<U6'), 0.0781, 0.2352, 0.973],
#        [3,
#         array(['voltage 0-25%', 'other 75-100%', 'True'], dtype='<U13'),
#         0.0759, 0.2284, 2.3333],
#        [2, array(['other 50-75%', 'True'], dtype='<U12'), 0.0751, 0.2261,
#         0.968],
#        [2, array(['climate_control 25-50%', 'True'], dtype='<U22'),
#         0.0552, 0.223, 0.6711],
#        [2, array(['other 0-25%', 'True'], dtype='<U11'), 0.0727, 0.2187,
#         0.8359],
#        [3, array(['other 0-25%', 'summer', 'True'], dtype='<U11'),
#         0.0566, 0.2162, 1.8505],
#        [2, array(['laundry 25-50%', 'True'], dtype='<U14'), 0.0711,
#         0.2139, 0.8521],
#        [3,
#         array(['global_intensity 75-100%', 'kitchen 75-100%', 'True'],
#               dtype='<U24')                                           ,
#         0.0707, 0.2127, 2.379],
#        [2, array(['kitchen 50-75%', 'True'], dtype='<U14'), 0.0701,
#         0.2109, 0.8571],
#        [2, array(['winter', 'True'], dtype='<U6'), 0.0557, 0.2071,
#         0.6234],
#        [2, array(['global_reactive_power 0-25%', 'True'], dtype='<U27'),
#         0.0686, 0.2066, 0.7739],
#        [3,
#         array(['global_intensity 75-100%', 'global_reactive_power 75-100%',
#                'True'], dtype='<U29')                                      ,
#         0.0683, 0.2057, 2.3495],
#        [4,
#         array(['voltage 0-25%', 'global_intensity 75-100%', 'other 75-100%',
#                'True'], dtype='<U24')                                       ,
#         0.0676, 0.2035, 2.4892]], dtype=object)

# %%
hc_csv_raw['peak_warning'] = hc_csv_raw['peak_label_pred'].apply(lambda x: 'true' if x == 'peak_warning' else 'false')
hc_csv_raw['no_significant_change'] = hc_csv_raw['peak_label_pred'].apply(lambda x: 'true' if x == 'no_significant_change' else 'false')
hc_csv_raw['lower_than_usual'] = hc_csv_raw['peak_label_pred'].apply(lambda x: 'true' if x == 'lower_than_usual' else 'false')
hc_csv_raw
# Out:
#       global_active_power global_reactive_power    voltage global_intensity  \
# 0               Very High                   Low        Low        Very High
# 1                    High                   Low       High             High
# 2               Very High                  High       High        Very High
# 3                     Low                   Low        Low              Low
# 4               Very High                   Low  Very High        Very High
# ...                   ...                   ...        ...              ...
# 41668                 Low                   Low  Very High              Low
# 41669              Medium                Medium  Very High           Medium
# 41670              Medium             Very High       High           Medium
# 41671                 Low                   Low  Very High              Low
# 41672                 Low                   Low       High              Low
#
#       kitchen laundry climate_control      other  weekend month_name  \
# 0        High  Medium            High  Very High     True      march
# 1         Low     Low            High       High    False    january
# 2      Medium  Medium       Very High  Very High    False    january
# 3      Medium     Low             Low     Medium    False   february
# 4         Low     Low             Low  Very High     True   december
# ...       ...     ...             ...        ...      ...        ...
# 41668     Low     Low             Low     Medium     True    january
# 41669    High  Medium          Medium       High    False   february
# 41670     Low    High             Low       High    False      april
# 41671    High    High          Medium        Low     True    january
# 41672     Low     Low             Low        Low    False  september
#
#       season_name  day_name        peak_label_pred peak_warning  \
# 0          spring  saturday  no_significant_change        false
# 1          winter  thursday  no_significant_change        false
# 2          winter    friday  no_significant_change        false
# 3          winter    friday  no_significant_change        false
# 4          winter  saturday  no_significant_change        false
# ...           ...       ...                    ...          ...
# 41668      winter  saturday       lower_than_usual        false
# 41669      winter   tuesday       lower_than_usual        false
# 41670      spring   tuesday       lower_than_usual        false
# 41671      winter  saturday       lower_than_usual        false
# 41672      autumn   tuesday       lower_than_usual        false
#
#       no_significant_change lower_than_usual
# 0                      true            false
# 1                      true            false
# 2                      true            false
# 3                      true            false
# 4                      true            false
# ...                     ...              ...
# 41668                 false             true
# 41669                 false             true
# 41670                 false             true
# 41671                 false             true
# 41672                 false             true
#
# [41673 rows x 16 columns]

# %% [markdown]
# save

# %%
# hc_csv_raw.to_csv('./datasets/2.0-discretized-v2-3-peak-label-encoded.csv', index=False)
